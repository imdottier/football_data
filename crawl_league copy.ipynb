# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from bs4 import BeautifulSoup
import re
import json
from datetime import date, timedelta
import datetime
import os

# %% [markdown]
# Set up selenium driver

# %%
# Chrome options
options = Options()
# comment out this line to run with browser open
# options.add_argument("--headless=new")

options.add_argument("--disable-blink-features=AutomationControlled") # bypass bot detection
options.add_argument("--no-sandbox") # for wsl
options.add_argument("--disable-dev-shm-usage") # or container
options.add_argument("--window-size=1920,1080")
options.add_experimental_option("excludeSwitches", ["enable-automation"]) # anti-detection settings
options.add_experimental_option("useAutomationExtension", False)
options.binary_location = "/usr/bin/google-chrome"

prefs = {
    "profile.managed_default_content_settings.javascript": 2,
    "profile.managed_default_settings.images": 2
}
options.add_experimental_option("prefs", prefs)

# %% [markdown]
# # Ubuntu example
# wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# sudo apt install ./google-chrome-stable_current_amd64.deb

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# %%
driver.quit()

# %%
import os, json
from hdfs import InsecureClient

HDFS_PATH = "/user/dottier/"
client = InsecureClient("http://localhost:9870", user="dottier")

def write_json_to_bronze(file_path: str, is_hdfs: bool, content: dict, overwrite: bool = False) -> bool:
    try:
        if is_hdfs:
            hdfs_path = os.path.join(HDFS_PATH, file_path)
            parent = os.path.dirname(hdfs_path)
            client.makedirs(parent)

            if not overwrite and client.status(hdfs_path, strict=False):
                print(f"SKIP: {hdfs_path} already exists (HDFS)")
                return

            with client.write(hdfs_path, encoding="utf-8", overwrite=True) as f:
                json.dump(content, f, ensure_ascii=False)

        else:
            os.makedirs(os.path.dirname(file_path), exist_ok=True)

            if not overwrite and os.path.exists(file_path):
                print(f"SKIP: {file_path} already exists (local)")
                return

            with open(file_path, "w", encoding="utf-8") as f:
                json.dump(content, f, ensure_ascii=False)

    except Exception as e:
        print(f"FATAL ERROR: Could not write {file_path}. Details: {e}")

# %% [markdown]
# Crawling: Getting match info

# %% [markdown]
# - Get unique season id of a selected unique (region_id, tournament_id)

# %%
import time, random

def reset_driver(driver: webdriver.Chrome):
    if driver:
        driver.quit()
        
    time.sleep(random.uniform(10, 20))
    print("INFO: Starting a new browser session...")
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

    return driver

# %%
# Out:
# bronze/match_data/league=international-fifa-world-cup/season=2018/stage_id=12757/match_id=1249924: match_id=1249924, startTimeUtc=2018-06-28T18:00:00Z

# %%
# Get the latest 3 season ids of selected league
def get_season_ids(region_id, tournament_id, start_year_after, driver: webdriver.Chrome):
    league_url = f"https://www.whoscored.com/regions/{region_id}/tournaments/{tournament_id}"
    # driver.get(league_url)
    
    # soup = BeautifulSoup(driver.page_source, "html.parser")

    # season_ids = []
    # season_options = soup.select('select#seasons option')
    # if not season_options:
    #     print(f"WARNING: Could not find season dropdown for tournament {tournament_id}. Retrying")
    #     driver = reset_driver(driver)
    
    #     # 2nd attempt
    #     season_options = fetch_options(driver)
    #     if not season_options:
    #         print(f"ERROR: Still could not find season dropdown for tournament {tournament_id}.")
    #         return [], driver   # fail case
    
    driver.get(league_url)
    soup = BeautifulSoup(driver.page_source, "html.parser")
    season_options = soup.select('select#seasons option')

    if not season_options:
        print(f"WARNING: Could not find season dropdown for tournament {tournament_id}. Retrying")
        driver = reset_driver(driver)

        driver.get(league_url)
        soup = BeautifulSoup(driver.page_source, "html.parser")
        season_options = soup.select('select#seasons option')

    if not season_options:
        print(f"WARNING: Could not find season dropdown for tournament {tournament_id}. Skipping")
        return [], driver
    
    season_ids = []

    for season_option in season_options:
        value_attr = season_option.get("value")
        display_name = season_option.string
        if value_attr:
            try:
                parts = display_name.split('/')
                start_year = int(parts[0])

                if start_year_after > start_year:
                    continue

                season_id = value_attr.split('/')[6]
                season_ids.append(season_id)
            except IndexError:
                print(f"WARNING: Could not parse season_id from value: {value_attr}")

    return season_ids, driver

# %%
season_id, _ = get_season_ids(81, 3, 2015, driver)

# %%
# League mapping: (region_id, tournament_id) -> short league name
league_mapping = {
    (81, 3, 2015): "germany-bundesliga",
    (252, 2, 2015): "england-premier-league",
    (247, 36, 2014): "international-fifa-world-cup",
    (250, 12, 2015): "europe-champions-league",
}

# %%
# def get_stage_ids(region_id, tournament_id, season_id, driver):
#     season_url = f"https://www.whoscored.com/regions/{region_id}/tournaments/{tournament_id}/seasons/{season_id}"
#     driver.get(season_url)
#     soup = BeautifulSoup(driver.page_source, "html.parser")

#     # Season has multiple stages
#     stage_options = soup.select('select#stages option')

#     if stage_options:
#         stage_ids = []

#         for stage_option in stage_options:
#             value_attr = stage_option.get("value")
#             if value_attr:
#                 try:
#                     stage_id = value_attr.split('/')[8]
#                     stage_ids.append(stage_id)
#                 except IndexError:
#                     print(f"WARNING: Could not parse stage_id from value: {value_attr}")

#         if stage_ids:
#             return stage_ids, driver


#     # season has 1 stage only
#     canonical_link_tag = soup.find('link', {'rel': 'canonical'})
    
#     if canonical_link_tag and canonical_link_tag.get('href'):
#         href = canonical_link_tag['href']
#         try:
#             stage_id = href.split('/stages/')[1].split('/')[0]
#             return [stage_id], driver
#         except IndexError:
#             print(f"ERROR: Could not parse stage_id from canonical URL: {href}")
#             return [], driver

# %%
def get_stage_ids(region_id, tournament_id, season_id, driver, retries=1):
    season_url = f"https://www.whoscored.com/regions/{region_id}/tournaments/{tournament_id}/seasons/{season_id}"

    for attempt in range(retries + 1):
        driver.get(season_url)
        soup = BeautifulSoup(driver.page_source, "html.parser")
        stage_options = soup.select('select#stages option')

        if stage_options:
            stage_ids = []
            for stage_option in stage_options:
                value_attr = stage_option.get("value")
                if value_attr:
                    try:
                        stage_id = value_attr.split('/')[8]
                        stage_ids.append(stage_id)
                    except IndexError:
                        print(f"WARNING: Could not parse stage_id from value: {value_attr}")
            if stage_ids:
                return stage_ids, driver

        # fallback to canonical link
        canonical_link_tag = soup.find('link', {'rel': 'canonical'})
        if canonical_link_tag and canonical_link_tag.get('href'):
            href = canonical_link_tag['href']
            try:
                stage_id = href.split('/stages/')[1].split('/')[0]
                return [stage_id], driver
            except IndexError:
                print(f"ERROR: Could not parse stage_id from canonical URL: {href}")

        # If nothing found and we have retries left, reset driver and try again
        if attempt < retries:
            print(f"WARNING: No stages found, retrying... (attempt {attempt + 1})")
            driver = reset_driver(driver)

    # If all retries failed
    return [], driver

# %%
print(f"Stage ids of Bundesliga 2022/2023: {get_stage_ids(81, 3, 9120, driver)}")
print(f"Stage ids of FIFA World Cup 2022: {get_stage_ids(247, 36, 8213, driver)}")
# Out:
# Stage ids of Bundesliga 2022/2023: (['21026'], <selenium.webdriver.chrome.webdriver.WebDriver (session="f76e0335ec76652ba434da79b0e9b585")>)
# Stage ids of FIFA World Cup 2022: (['18657', '18649', '18650', '18651', '18652', '18653', '18656', '18655', '18654'], <selenium.webdriver.chrome.webdriver.WebDriver (session="f76e0335ec76652ba434da79b0e9b585")>)

# %%
# Write stage data into file
# And returns derived metadata about the stage
def process_season_stages(region_id, tournament_id, season_id, stage_id, league_name, driver: webdriver.Chrome, is_hdfs):
    stage_url = f"https://www.whoscored.com/regions/{region_id}/tournaments/{tournament_id}/seasons/{season_id}/stages/{stage_id}"
    driver.get(stage_url)

    soup = BeautifulSoup(driver.page_source, "html.parser")
    script_tag = soup.select_one('script[data-hypernova-key="tournamentfixtures"]')
    if not script_tag:
        print(f"ERROR: Could not find the data script tag on page: {stage_url}")
        return None

    raw_json = script_tag.string.strip().removeprefix("<!--").removesuffix("-->")

    print(f"Start writing stage data for stage {stage_id}")

    try:
        data = json.loads(raw_json)
        stage_data = data["tournaments"][0]
        if not stage_data:
            print(f"ERROR: Could not find stage data block in JSON for stage {stage_id}")
            return None
    except (json.JSONDecodeError, KeyError, IndexError, TypeError) as e:
        print(f"ERROR: Failed to parse or access key data for stage {stage_id}. Details: {e}")
        return None

    # Get season partition (2023/2024)
    season_partition = stage_data.get("seasonName").replace('/', '-')
    parts = season_partition.split('-')
    
    # And starting + ending year for fixtures fetching
    start_year, end_year = None, None
    if len(parts) == 1 and parts[0].isdigit():
        start_year = end_year = int(parts[0])
    elif len(parts) == 2 and parts[0].isdigit() and parts[1].isdigit():
        start_year, end_year = int(parts[0]), int(parts[1])

    stage_name = stage_data.get("stageName")

    stage_path = os.path.join(f"league={league_name}", f"season={season_partition}", f"stage_id={stage_id}")
    output_dir = os.path.join("bronze", "stage_data", stage_path)
    output_file = os.path.join(output_dir, "stage_info.json")

    output = {
        "metadata": {
            "stage_id": stage_id,
            "crawled_at": time.strftime("%Y-%m-%d %H:%M:%S", time.gmtime()),
            "source_url": stage_url,
        },
        "data": stage_data
    }

    # Funny fix for EURO 2020 played in 2021 cuz I'm too lazy to think of something else
    if league_name == "international-european-championship" and start_year == 2020:
        start_year = 2021
        end_year = 2021
    
    try:
        if not is_hdfs:
            os.makedirs(output_dir, exist_ok=True)

        write_json_to_bronze(output_file, is_hdfs, output, overwrite=True)

        print(f"SUCCESS: Wrote data for stage {stage_id} to "
              f"{'HDFS' if is_hdfs else 'local'} {output_file}")

        return {
            "season_id": season_id,
            "stage_id": stage_id,
            "stage_name": stage_name,
            "start_year": start_year,
            "end_year": end_year,
            "stage_path": stage_path
        }

    # try:
    #     os.makedirs(output_dir, exist_ok=True)
    #     with open(output_file, "w", encoding="utf-8") as f:
    #         json.dump(output, f, ensure_ascii=False)

    #     print(f"SUCCESS: Wrote data for stage {stage_id} to {output_file}")
    #     return {
    #         "season_id": season_id,
    #         "stage_id": stage_id,
    #         "start_year": start_year,
    #         "end_year": end_year,
    #         "stage_path": stage_path
    #     }
    
    except (IOError, OSError) as e:
        print(f"FATAL ERROR: Could not write file for stage {stage_id}. Details: {e}")
        return None

# %%
print(process_season_stages(247, 124, 7329, 16297, "international-european-championship", driver, False))
# Out:
# Start writing stage data for stage 16297
# Wrote to local FS: bronze/stage_data/league=international-european-championship/season=2020/stage_id=16297/stage_info.json
# SUCCESS: Wrote data for stage 16297 to local bronze/stage_data/league=international-european-championship/season=2020/stage_id=16297/stage_info.json
# {'season_id': 7329, 'stage_id': 16297, 'stage_name': 'EURO Grp. A', 'start_year': 2021, 'end_year': 2021, 'stage_path': 'league=international-european-championship/season=2020/stage_id=16297'}

# %%
# Create week keys in the format of {YYYY}W{WW}
def generate_week_keys(start_year, end_year):
    weeks = set()
    d = date(start_year, 1, 1)
    while d.year <= end_year:
        iso = d.isocalendar()  # (year, week, weekday)
        key = f"{iso[0]}W{iso[1]:02d}"
        weeks.add(key)
        d += timedelta(days=7)
    return sorted(weeks)

# %%
from datetime import date

def generate_month_keys(start_year, end_year):
    months = []
    for year in range(start_year, end_year + 1):
        for month in range(1, 13):
            key = f"{year}{month:02d}"
            months.append(key)
    return months

# Example usage:
print(generate_month_keys(2026, 2026))
# Out:
# ['202601', '202602', '202603', '202604', '202605', '202606', '202607', '202608', '202609', '202610', '202611', '202612']

# %%
# # Get all match_ids and start time (UTC) of selected season
# def get_match_configs(stage_config, driver: webdriver.Chrome):
#     stage_id = stage_config["stage_id"]
#     start_year = stage_config["start_year"]
#     end_year = stage_config["end_year"]
#     stage_path = stage_config["stage_path"]

#     if not all([stage_id, start_year, end_year, stage_path]):
#         print(f"ERROR: get_match_configs received invalid stage_metadata: {stage_config}")
#         return []

#     print(f"Start getting match_configs for stage {stage_id}")
    
#     match_configs_to_return = []
#     processed_match_ids = set()

#     week_keys = generate_week_keys(start_year, end_year)
#     for week_key in week_keys:
#         weekly_data_url = f"https://www.whoscored.com/tournaments/{stage_id}/data/?d={week_key}&isAggregate=false"

#         try:
#             driver.get(weekly_data_url)
#             # Using execute_script is clever, but let's make it robust
#             json_text = driver.execute_script("return document.body.innerText || null;")
            
#             if not json_text:
#                 print(f"WARNING: No JSON text found for URL: {weekly_data_url}")
#                 continue

#             data = json.loads(json_text)
#             if not isinstance(data, dict) or not data.get("version"):
#                 continue

#             for stage in data.get("tournaments", []):
#                 for match in stage.get("matches", []):
#                     match_id = match.get("id")
#                     start_time_utc = match.get("startTimeUtc")

#                     if not match_id or not start_time_utc:
#                         continue
                    
#                     if match_id in processed_match_ids:
#                         continue

#                     match_output_dir = os.path.join("bronze", "match_data", stage_path, f"match_id={match_id}")
#                     os.makedirs(match_output_dir, exist_ok=True)
#                     preview_file_path = os.path.join(match_output_dir, "match_preview.json")

      - Overwrite only if start_time_utc within ±days_back from now
    """
    try:
        if is_hdfs:
            hdfs_path = os.path.join(HDFS_PATH, file_path)
            if not client.status(hdfs_path, strict=False):  # file doesn't exist
                return True
        else:
            if not os.path.exists(file_path):
                return True

        # If file exists, check time
        match_time = datetime.strptime(start_time_utc, "%Y-%m-%dT%H:%M:%SZ").replace(tzinfo=timezone.utc)
        now = datetime.now(timezone.utc)
        delta = abs((match_time - now).total_seconds())
        return delta <= days_back * 86400

    except Exception as e:
        print(f"WARNING: should_write_match fallback for {file_path}. Details: {e}")
        return True  # safer to overwrite

# %%
# Get all match_ids and start time (UTC) of selected season
def get_match_configs(stage_config, driver: webdriver.Chrome, is_hdfs):
    stage_id = stage_config["stage_id"]
    start_year = stage_config["start_year"]
    end_year = stage_config["end_year"]
    stage_path = stage_config["stage_path"]

    if not all([stage_id, start_year, end_year, stage_path]):
        print(f"ERROR: get_match_configs received invalid stage_metadata: {stage_config}")
        return [], driver

    print(f"Start getting match_configs for stage {stage_id}")
    
    match_configs_to_return = []
    processed_match_ids = set()

    month_keys = generate_month_keys(start_year, end_year)
    for month_key in month_keys:
        monthly_data_url = f"https://www.whoscored.com/tournaments/{stage_id}/data/?d={month_key}&isAggregate=false"

        try:
            driver.get(monthly_data_url)
            # Using execute_script is clever, but let's make it robust
            json_text = driver.execute_script("return document.body.innerText || null;")
            
            # retry once if failed
            if not json_text:
                print(f"WARNING: No JSON text found for URL: {monthly_data_url}, retrying once...")
                driver = reset_driver(driver)
                
                driver.get(monthly_data_url)
                json_text = driver.execute_script("return document.body.innerText || null;")

            if not json_text:
                print(f"ERROR: Still no JSON after retry for {monthly_data_url}")
                continue

            data = json.loads(json_text)
            if not isinstance(data, dict) or not data.get("version"):
                continue

            for stage in data.get("tournaments", []):
                for match in stage.get("matches", []):
                    match_id = match.get("id")
                    start_time_utc = match.get("startTimeUtc")

                    if not match_id or not start_time_utc:
                        continue
                    
                    if match_id in processed_match_ids:
                        continue

                    # match_output_dir = os.path.join("bronze", "match_data", stage_path, f"match_id={match_id}")
                    # os.makedirs(match_output_dir, exist_ok=True)
                    # preview_file_path = os.path.join(match_output_dir, "match_preview.json")

                    output = {
                        "metadata": {
                            "match_id": match_id,
                            "crawled_at": time.strftime("%Y-%m-%d %H:%M:%S", time.gmtime()),  # UTC time
                            "source_url": monthly_data_url,
                        },
                        "data": match
                    }

                    preview_file_path = os.path.join(
                        "bronze", "match_data", stage_path, f"match_id={match_id}", "match_preview.json"
                    )

                    if should_write_match(preview_file_path, start_time_utc, is_hdfs, days_back=3):
                        write_json_to_bronze(preview_file_path, is_hdfs, output)

                    # write_json_to_bronze(preview_file_path, is_hdfs, output)
                    # with open(preview_file_path, "w", encoding="utf-8") as f:
                    #     json.dump(output, f, ensure_ascii=False)
                    
                    match_configs_to_return.append([match_id, start_time_utc])
                    processed_match_ids.add(match_id)

            # print(f"Found {len(match_configs_to_return)} matches for month {month_key}")

        except json.JSONDecodeError as e:
            print(f"Failed to parse JSON for URL: {monthly_data_url}. Details: {e}")
        except Exception as e:
            print(f"ERROR: An unexpected error occurred for URL {monthly_data_url}. Details: {e}")

    print(f"Found {len(match_configs_to_return)} matches for stage {stage_id}")
    return match_configs_to_return, driver

# %%
# Get all match_ids and start time (UTC) of selected season
def get_match_configs(stage_config, driver: webdriver.Chrome, is_hdfs):
    stage_id = stage_config["stage_id"]
    start_year = stage_config["start_year"]
    end_year = stage_config["end_year"]
    stage_path = stage_config["stage_path"]

    if not all([stage_id, start_year, end_year, stage_path]):
        print(f"ERROR: get_match_configs received invalid stage_metadata: {stage_config}")
        return [], driver

    def fetch_matches(start_year, end_year, driver_obj):
        match_configs_to_return = []
        processed_match_ids = set()

        month_keys = generate_month_keys(start_year, end_year)
        for month_key in month_keys:
            monthly_data_url = f"https://www.whoscored.com/tournaments/{stage_id}/data/?d={month_key}&isAggregate=false"

            try:
                driver_obj.get(monthly_data_url)
                json_text = driver_obj.execute_script("return document.body.innerText || null;")
                
                # retry once if failed
                if not json_text:
                    print(f"WARNING: No JSON text found for URL: {monthly_data_url}, retrying once...")
                    driver_obj = reset_driver(driver_obj)
                    driver_obj.get(monthly_data_url)
                    json_text = driver_obj.execute_script("return document.body.innerText || null;")

                if not json_text:
                    print(f"ERROR: Still no JSON after retry for {monthly_data_url}")
                    continue

                data = json.loads(json_text)
                if not isinstance(data, dict) or not data.get("version"):
                    continue

                for stage in data.get("tournaments", []):
                    for match in stage.get("matches", []):
                        match_id = match.get("id")
                        start_time_utc = match.get("startTimeUtc")

                        if not match_id or not start_time_utc:
                            continue
                        
                        if match_id in processed_match_ids:
                            continue

                        output = {
                            "metadata": {
                                "match_id": match_id,
                                "crawled_at": time.strftime("%Y-%m-%d %H:%M:%S", time.gmtime()),  # UTC time
                                "source_url": monthly_data_url,
                            },
                            "data": match
                        }

                        preview_file_path = os.path.join(
                            "bronze", "match_data", stage_path, f"match_id={match_id}", "match_preview.json"
                        )
                        
                        if should_write_match(preview_file_path, start_time_utc, is_hdfs, days_back=3):
                            write_json_to_bronze(preview_file_path, is_hdfs, output)
                        
                        match_configs_to_return.append([match_id, start_time_utc])
                        processed_match_ids.add(match_id)

            except json.JSONDecodeError as e:
                print(f"Failed to parse JSON for URL: {monthly_data_url}. Details: {e}")
            except Exception as e:
                print(f"ERROR: An unexpected error occurred for URL {monthly_data_url}. Details: {e}")

        return match_configs_to_return, driver_obj

    print(f"Start getting match_configs for stage {stage_id}")
    
    # First attempt with given years
    match_configs_to_return, driver = fetch_matches(start_year, end_year, driver)

    # If no matches found, retry with end_year + 1
    if len(match_configs_to_return) == 0:
        print(f"WARNING: No matches found for {start_year}-{end_year}, retrying with {start_year + 1}-{end_year + 1}")
        match_configs_to_return, driver = fetch_matches(start_year + 1, end_year + 1, driver)

    print(f"Found {len(match_configs_to_return)} matches for stage {stage_id}")
    return match_configs_to_return, driver

# %%
stage_config = {
    "season_id": 6275,
    "stage_id":  14188,
    "start_year": 2016,
    "end_year": 2017,
    "stage_path": "league=europe-europa-league\\season=2016-2017\\stage_id=14188"
}

print(get_match_configs(stage_config, driver, False))
# Out:
# Start getting match_configs for stage 14188
# Wrote to local FS: bronze/match_data/league=europe-europa-league\season=2016-2017\stage_id=14188/match_id=1139064/match_preview.json
# Wrote to local FS: bronze/match_data/league=europe-europa-league\season=2016-2017\stage_id=14188/match_id=1139065/match_preview.json
# Wrote to local FS: bronze/match_data/league=europe-europa-league\season=2016-2017\stage_id=14188/match_id=1139066/match_preview.json
# Wrote to local FS: bronze/match_data/league=europe-europa-league\season=2016-2017\stage_id=14188/match_id=1139067/match_preview.json
# Wrote to local FS: bronze/match_data/league=europe-europa-league\season=2016-2017\stage_id=14188/match_id=1139068/match_preview.json
# Wrote to local FS: bronze/match_data/league=europe-europa-league\season=2016-2017\stage_id=14188/match_id=1139069/match_preview.json
# Wrote to local FS: bronze/match_data/league=europe-europa-league\season=2016-2017\stage_id=14188/match_id=1139070/match_preview.json
# Wrote to local FS: bronze/match_data/league=europe-europa-league\season=2016-2017\stage_id=14188/match_id=1139071/match_preview.json
# Wrote to local FS: bronze/match_data/league=europe-europa-league\season=2016-2017\stage_id=14188/match_id=1139073/match_preview.json
# Wrote to local FS: bronze/match_data/league=europe-europa-league\season=2016-2017\stage_id=14188/match_id=1139072/match_preview.json
# Wrote to local FS: bronze/match_data/league=europe-europa-league\season=2016-2017\stage_id=14188/match_id=1139074/match_preview.json
# Wrote to local FS: bronze/match_data/league=europe-europa-league\season=2016-2017\stage_id=14188/match_id=1139075/match_preview.json
# Found 12 matches for stage 14188
# ([[1139064, '2016-09-15T17:00:00Z'], [1139065, '2016-09-15T17:00:00Z'], [1139066, '2016-09-29T19:05:00Z'], [1139067, '2016-09-29T19:05:00Z'], [1139068, '2016-10-20T19:05:00Z'], [1139069, '2016-10-20T19:05:00Z'], [1139070, '2016-11-03T18:00:00Z'], [1139071, '2016-11-03T18:00:00Z'], [1139073, '2016-11-24T16:00:00Z'], [1139072, '2016-11-24T20:05:00Z'], [1139074, '2016-12-08T18:00:00Z'], [1139075, '2016-12-08T18:00:00Z']], <selenium.webdriver.chrome.webdriver.WebDriver (session="1ad3f893014b99180a93327572046264")>)

# %%
stage_config = {
    "season_id": 9120,
    "stage_id":  21026,
    "start_year": 2022,
    "end_year": 2023,
    "stage_path": "league=germany-bundesliga\\season=2022-2023\\stage_id=21026"
}

print(get_match_configs(stage_config, driver))

# %%
def extract_json_object(text, start_key):
    start_idx = text.find(start_key)
    if start_idx == -1:
        raise ValueError(f"Key '{start_key}' not found in text.")

    brace_start = text.find('{', start_idx)
    if brace_start == -1:
        raise ValueError(f"Opening '{{' not found after key '{start_key}'.")

    brace_count = 0
    for i in range(brace_start, len(text)):
        if text[i] == '{':
            brace_count += 1
        elif text[i] == '}':
            brace_count -= 1
            if brace_count == 0:
                return text[brace_start:i+1]

    raise ValueError(f"Could not find matching closing '}}' for key '{start_key}'.")

# %%
from enum import Enum

class MatchStatus(Enum):
    FETCHED = 1
    ALREADY_EXISTS = 2
    FAILED = 3
    FUTURE_MATCH = 4

# %%
def get_match_data(match_id, start_time_string, stage_path, driver: webdriver.Chrome, is_hdfs):
    output_dir = os.path.join("bronze", "match_data", stage_path, f"match_id={match_id}")
    output_file = os.path.join(output_dir, "match_data.json")
    
    # if os.path.exists(output_file):
    #     print(f"INFO: Data for match {match_id} already exists. Skipping.")
    #     return True

    if not should_write_match(output_file, start_time_string, is_hdfs, days_back=3):
        return MatchStatus.ALREADY_EXISTS

    # if is_hdfs:
    #     from hdfs.util import HdfsError
    #     try:
    #         client.status(os.path.join(HDFS_PATH, output_file))
    #         # print(f"INFO: Data for match {match_id} already exists on HDFS. Skipping.")
    #         return MatchStatus.ALREADY_EXISTS
    #     except HdfsError:
    #         pass  # file does not exist, continue
    # else:
    #     if os.path.exists(output_file):
    #         # print(f"INFO: Data for match {match_id} already exists. Skipping.")
    #         return MatchStatus.ALREADY_EXISTS
    
    start_time_UTC = datetime.strptime(start_time_string, '%Y-%m-%dT%H:%M:%SZ')
    if start_time_UTC > datetime.now():
        return MatchStatus.FUTURE_MATCH

    url = f"https://www.whoscored.com/matches/{match_id}/live"
    
    try:
        driver.get(url)
        soup = BeautifulSoup(driver.page_source, "html.parser")
        script_tags = soup.find_all("script")

        for script in script_tags:
            script_text = script.string
            if not script_text or not all(k in script_text for k in ["matchCentreData", "matchCentreEventTypeJson", "formationIdNameMappings"]):
                continue

            mcd_str = extract_json_object(script_text, "matchCentreData:")
            event_map_str = extract_json_object(script_text, "matchCentreEventTypeJson:")
            formation_map_str = extract_json_object(script_text, "formationIdNameMappings:")

            if not (mcd_str and event_map_str and formation_map_str):
                continue

            match_centre_data = json.loads(mcd_str)
            event_type_mapping = json.loads(event_map_str)
            formation_mapping = json.loads(formation_map_str)

            final_data_object = {
                "metadata": {
                    "match_id": match_id,
                    "crawled_at": time.strftime("%Y-%m-%d %H:%M:%S", time.gmtime()),  # UTC time
                    "source_url": url,
                },
                "matchId": match_id,
                "matchCentreData": match_centre_data,
                "matchCentreEventTypeJson": event_type_mapping,
                "formationIdNameMappings": formation_mapping
            }

            write_json_to_bronze(output_file, is_hdfs, final_data_object)
            print(f"SUCCESS: Wrote data for match {match_id}")
            
            # os.makedirs(output_dir, exist_ok=True)
            # with open(output_file, "w", encoding="utf-8") as f:
            #     json.dump(final_data_object, f, ensure_ascii=False)
            
            # print(f"SUCCESS: Wrote data for match {match_id}")
            return MatchStatus.FETCHED
        
    except json.JSONDecodeError as e:
        print(f"ERROR: Failed to parse JSON for match {match_id}. URL: {url}. Details: {e}")
        return MatchStatus.FAILED
    except (IOError, OSError) as e:
        print(f"FATAL ERROR: Could not write file for match {match_id}. Path: {output_file}. Details: {e}")
        return MatchStatus.FAILED
    except Exception as e:
        print(f"ERROR: An unexpected error occurred while processing match {match_id}. URL: {url}. Details: {e}")
        return MatchStatus.FAILED

    print(f"WARNING: Could not find a script containing all required data for match {match_id} on page {url}")
    return MatchStatus.FAILED

# %%
get_match_data(1643039, "2015-05-15T18:45:00Z", "league=germany-bundesliga/season=2022-2023/stage_id=21026", driver, True)
# Out:
# <MatchStatus.ALREADY_EXISTS: 2>

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# %%
import time
import random

driver = None

try: 
    for (region_id, tournament_id, start_year_after), league_name in league_mapping.items():
        print("="*50)
        print(f"STARTING LEAGUE: {league_name}")

        if driver:
            driver.quit()
        
        print("INFO: Starting a new browser session...")
        driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

        season_ids, driver = get_season_ids(region_id, tournament_id, start_year_after, driver)
        print(f"Season_ids of {league_name}:", season_ids)

        for season_id in season_ids:
            if driver:
                driver.quit()

            print("\n" + "-"*20)
            print(f"INFO: Starting new session for Season ID: {season_id}")
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

            stage_ids = get_stage_ids(region_id, tournament_id, season_id, driver)
            if not stage_ids:
                print(f"WARNING: No stages found for season {season_id}. Skipping.")
                continue

            for stage_id in stage_ids:
                stage_config = process_season_stages(region_id, tournament_id, season_id, stage_id, league_name, driver)
                if not stage_config:
                    print(f"WARNING: Failed to process metadata for stage {stage_id}. Skipping to next stage.")
                    continue

                stage_path = stage_config["stage_path"]

                match_configs, driver = get_match_configs(stage_config, driver)
                for match_id, start_time_string in match_configs:
                    get_match_data(match_id, start_time_string, stage_path, driver)

            time.sleep(random.uniform(10, 20))

finally:
    # Make sure the final driver is always closed, even if there's an error
    if driver:
        print("INFO: Closing final browser session.")
        driver.quit()
# Out:
# ==================================================
# STARTING LEAGUE: germany-bundesliga
# INFO: Starting a new browser session...
# Season_ids of germany-bundesliga: ['10720', '10365', '9649', '9120', '8667', '8279', '7872', '7405', '6902', '6392', '5870']
#
# --------------------
# INFO: Starting new session for Season ID: 10720
# Start writing stage data for stage 24478
# SUCCESS: Wrote data for stage 24478 to bronze\stage_data\league=germany-bundesliga\season=2025-2026\stage_id=24478\stage_info.json
# Start getting match_configs for stage 24478
# Found 18 matches for month 202508
# Found 45 matches for month 202509
# Found 72 matches for month 202510
# Found 108 matches for month 202511
# Found 135 matches for month 202512
# Found 180 matches for month 202601
# Found 216 matches for month 202602
# Found 243 matches for month 202603
# Found 279 matches for month 202604
# Found 306 matches for month 202605
# Found 306 matches for stage 24478
# SUCCESS: Wrote data for match 1908319
# SUCCESS: Wrote data for match 1910600
# SUCCESS: Wrote data for match 1910601
# SUCCESS: Wrote data for match 1910603
# SUCCESS: Wrote data for match 1910604
# SUCCESS: Wrote data for match 1910605
# SUCCESS: Wrote data for match 1910599
# SUCCESS: Wrote data for match 1910598
# SUCCESS: Wrote data for match 1910602
# SUCCESS: Wrote data for match 1910614
#
# --------------------
# INFO: Starting new session for Season ID: 10365
# Start writing stage data for stage 23471
# SUCCESS: Wrote data for stage 23471 to bronze\stage_data\league=germany-bundesliga\season=2024-2025\stage_id=23471\stage_info.json
# Start getting match_configs for stage 23471
# Found 16 matches for month 202408
# Found 45 matches for month 202409
# Found 72 matches for month 202410
# Found 106 matches for month 202411
# Found 135 matches for month 202412
# Found 172 matches for month 202501
# Found 208 matches for month 202502
# Found 243 matches for month 202503
# Found 279 matches for month 202504
# Found 306 matches for month 202505
# Found 306 matches for stage 23471
# SUCCESS: Wrote data for match 1834247
# SUCCESS: Wrote data for match 1017526
# SUCCESS: Wrote data for match 1017527
# SUCCESS: Wrote data for match 1017528
# SUCCESS: Wrote data for match 1017529
# SUCCESS: Wrote data for match 1017530
# SUCCESS: Wrote data for match 1017531
# SUCCESS: Wrote data for match 1017532
# SUCCESS: Wrote data for match 1017533
# SUCCESS: Wrote data for match 1017534
# SUCCESS: Wrote data for match 1017535
# Start writing stage data for stage 13185
# SUCCESS: Wrote data for stage 13185 to bronze\stage_data\league=europe-champions-league\season=2015-2016\stage_id=13185\stage_info.json
# Start getting match_configs for stage 13185
# Found 8 matches for month 201602
# Found 16 matches for month 201603
# Found 26 matches for month 201604
# Found 29 matches for month 201605
# Found 29 matches for stage 13185
# SUCCESS: Wrote data for match 1035323
# SUCCESS: Wrote data for match 1035327
# SUCCESS: Wrote data for match 1035321
# SUCCESS: Wrote data for match 1035322
# SUCCESS: Wrote data for match 1035324
# SUCCESS: Wrote data for match 1035325
# SUCCESS: Wrote data for match 1035326
# SUCCESS: Wrote data for match 1035328
# SUCCESS: Wrote data for match 1035329
# SUCCESS: Wrote data for match 1035331
# SUCCESS: Wrote data for match 1035334
# SUCCESS: Wrote data for match 1035330
# SUCCESS: Wrote data for match 1035335
# SUCCESS: Wrote data for match 1035336
# SUCCESS: Wrote data for match 1035332
# SUCCESS: Wrote data for match 1035333
# SUCCESS: Wrote data for match 1063404
# SUCCESS: Wrote data for match 1063405
# SUCCESS: Wrote data for match 1063406
# SUCCESS: Wrote data for match 1063403
# SUCCESS: Wrote data for match 1063410
# SUCCESS: Wrote data for match 1063407
# SUCCESS: Wrote data for match 1063408
# SUCCESS: Wrote data for match 1063409
# SUCCESS: Wrote data for match 1069215
# SUCCESS: Wrote data for match 1069216
# SUCCESS: Wrote data for match 1069214
# SUCCESS: Wrote data for match 1069213
# SUCCESS: Wrote data for match 1071396
# INFO: Closing final browser session.

# %%
league_mapping = {
    (206, 4, 2015): "spain-laliga",
    (247, 67, 2025): "international-fifa-club-world-cup"
}

import time
import random

driver = None

try: 
    for (region_id, tournament_id, start_year_after), league_name in league_mapping.items():
        print("="*50)
        print(f"STARTING LEAGUE: {league_name}")

        if driver:
            driver.quit()
        
        print("INFO: Starting a new browser session...")
        driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

        season_ids, driver = get_season_ids(region_id, tournament_id, start_year_after, driver)
        print(f"Season_ids of {league_name}:", season_ids)

        for season_id in season_ids:
            if driver:
                driver.quit()

            print("\n" + "-"*20)
            print(f"INFO: Starting new session for Season ID: {season_id}")
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

            stage_ids = get_stage_ids(region_id, tournament_id, season_id, driver)
            if not stage_ids:
                print(f"WARNING: No stages found for season {season_id}. Skipping.")
                continue

            for stage_id in stage_ids:
                stage_config = process_season_stages(region_id, tournament_id, season_id, stage_id, league_name, driver)
                if not stage_config:
                    print(f"WARNING: Failed to process metadata for stage {stage_id}. Skipping to next stage.")
                    continue

                stage_path = stage_config["stage_path"]

                match_configs, driver = get_match_configs(stage_config, driver)
                for match_id, start_time_string in match_configs:
                    get_match_data(match_id, start_time_string, stage_path, driver)

# SUCCESS: Wrote data for match 1873297
# SUCCESS: Wrote data for match 1873296
# SUCCESS: Wrote data for match 1873298
# SUCCESS: Wrote data for match 1873299
# Start writing stage data for stage 23867
# SUCCESS: Wrote data for stage 23867 to bronze\stage_data\league=international-fifa-club-world-cup\season=2025\stage_id=23867\stage_info.json
# Start getting match_configs for stage 23867
# Found 6 matches for month 202506
# Found 6 matches for stage 23867
# SUCCESS: Wrote data for match 1873300
# SUCCESS: Wrote data for match 1873302
# SUCCESS: Wrote data for match 1873303
# SUCCESS: Wrote data for match 1873301
# SUCCESS: Wrote data for match 1873304
# SUCCESS: Wrote data for match 1873305
# Start writing stage data for stage 23868
# SUCCESS: Wrote data for stage 23868 to bronze\stage_data\league=international-fifa-club-world-cup\season=2025\stage_id=23868\stage_info.json
# Start getting match_configs for stage 23868
# Found 6 matches for month 202506
# Found 6 matches for stage 23868
# SUCCESS: Wrote data for match 1873306
# SUCCESS: Wrote data for match 1873307
# SUCCESS: Wrote data for match 1873308
# SUCCESS: Wrote data for match 1873309
# SUCCESS: Wrote data for match 1873310
# SUCCESS: Wrote data for match 1873311
# INFO: Closing final browser session.

# %%
league_mapping = {
    (108, 5, 2015): "italy-serie-a",
    (74, 22, 2015): "france-ligue-1"
}

import time
import random

driver = None

try: 
    for (region_id, tournament_id, start_year_after), league_name in league_mapping.items():
        print("="*50)
        print(f"STARTING LEAGUE: {league_name}")

        if driver:
            driver.quit()
        
        print("INFO: Starting a new browser session...")
        driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

        season_ids, driver = get_season_ids(region_id, tournament_id, start_year_after, driver)
        print(f"Season_ids of {league_name}:", season_ids)

        for season_id in season_ids:
            if driver:
                driver.quit()

            print("\n" + "-"*20)
            print(f"INFO: Starting new session for Season ID: {season_id}")
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

            stage_ids = get_stage_ids(region_id, tournament_id, season_id, driver)
            if not stage_ids:
                print(f"WARNING: No stages found for season {season_id}. Skipping.")
                continue

            for stage_id in stage_ids:
                stage_config = process_season_stages(region_id, tournament_id, season_id, stage_id, league_name, driver)
                if not stage_config:
                    print(f"WARNING: Failed to process metadata for stage {stage_id}. Skipping to next stage.")
                    continue

                stage_path = stage_config["stage_path"]

                match_configs, driver = get_match_configs(stage_config, driver)
                for match_id, start_time_string in match_configs:
                    get_match_data(match_id, start_time_string, stage_path, driver)

            time.sleep(random.uniform(10, 20))

finally:
    # Make sure the final driver is always closed, even if there's an error
    if driver:
        print("INFO: Closing final browser session.")
        driver.quit()
# Out:
# ==================================================
# STARTING LEAGUE: italy-serie-a
# INFO: Starting a new browser session...
# Season_ids of italy-serie-a: ['10732', '10375', '9659', '9159', '8735', '8330', '7928', '7468', '6974', '6461', '5970']
#
# --------------------
# INFO: Starting new session for Season ID: 10732
# Start writing stage data for stage 24500
# SUCCESS: Wrote data for stage 24500 to bronze\stage_data\league=italy-serie-a\season=2025-2026\stage_id=24500\stage_info.json
# Start getting match_configs for stage 24500
# Found 20 matches for month 202508
# Found 50 matches for month 202509
# Found 90 matches for month 202510
# Found 130 matches for month 202511
# Found 170 matches for month 202512
#     752 sock: socket.socket | ssl.SSLSocket
# --> 753 self.sock = sock = self._new_conn()
#     754 server_hostname: str = self.host
#
# File d:\test_data\venv\Lib\site-packages\urllib3\connection.py:205, in HTTPConnection._new_conn(self)
#     204 except socket.gaierror as e:
# --> 205     raise NameResolutionError(self.host, self, e) from e
#     206 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x0000013FCB447E30>: Failed to resolve 'googlechromelabs.github.io' ([Errno 11002] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File d:\test_data\venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File d:\test_data\venv\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File d:\test_data\venv\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='googlechromelabs.github.io', port=443): Max retries exceeded with url: /chrome-for-testing/latest-patch-versions-per-build.json (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000013FCB447E30>: Failed to resolve 'googlechromelabs.github.io' ([Errno 11002] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File d:\test_data\venv\Lib\site-packages\webdriver_manager\core\http.py:32, in WDMHttpClient.get(self, url, **kwargs)
#      31 try:
# ---> 32     resp = requests.get(
#      33         url=url, verify=self._ssl_verify, stream=True, **kwargs)
#      34 except exceptions.ConnectionError:
#
# File d:\test_data\venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)     70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File d:\test_data\venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\test_data\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\test_data\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File d:\test_data\venv\Lib\site-packages\requests\adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='googlechromelabs.github.io', port=443): Max retries exceeded with url: /chrome-for-testing/latest-patch-versions-per-build.json (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000013FCB447E30>: Failed to resolve 'googlechromelabs.github.io' ([Errno 11002] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[12], line 31
#      30 print(f"INFO: Starting new session for Season ID: {season_id}")
# ---> 31 driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
#      33 stage_ids = get_stage_ids(region_id, tournament_id, season_id, driver)
#
# File d:\test_data\venv\Lib\site-packages\webdriver_manager\chrome.py:40, in ChromeDriverManager.install(self)
#      39 def install(self) -> str:
# ---> 40     driver_path = self._get_driver_binary_path(self.driver)
#      41     os.chmod(driver_path, 0o755)
#
# File d:\test_data\venv\Lib\site-packages\webdriver_manager\core\manager.py:35, in DriverManager._get_driver_binary_path(self, driver)
#      34 def _get_driver_binary_path(self, driver):
# ---> 35     binary_path = self._cache_manager.find_driver(driver)
#      36     if binary_path:
#
# File d:\test_data\venv\Lib\site-packages\webdriver_manager\core\driver_cache.py:107, in DriverCacheManager.find_driver(self, driver)
#     105     return None
# --> 107 driver_version = self.get_cache_key_driver_version(driver)
#     108 metadata = self.load_metadata_content()
#
# File d:\test_data\venv\Lib\site-packages\webdriver_manager\core\driver_cache.py:154, in DriverCacheManager.get_cache_key_driver_version(self, driver)
#     153     return self._cache_key_driver_version
# --> 154 return driver.get_driver_version_to_download()
#
# File d:\test_data\venv\Lib\site-packages\webdriver_manager\core\driver.py:48, in Driver.get_driver_version_to_download(self)
#      46     return self._driver_version_to_download
# ---> 48 return self.get_latest_release_version()
#
# File d:\test_data\venv\Lib\site-packages\webdriver_manager\drivers\chrome.py:59, in ChromeDriver.get_latest_release_version(self)
#      58 url = "https://googlechromelabs.github.io/chrome-for-testing/latest-patch-versions-per-build.json"
# ---> 59 response = self._http_client.get(url)
#      60 response_dict = json.loads(response.text)
#
# File d:\test_data\venv\Lib\site-packages\webdriver_manager\core\http.py:35, in WDMHttpClient.get(self, url, **kwargs)
#      34 except exceptions.ConnectionError:
# ---> 35     raise exceptions.ConnectionError(f"Could not reach host. Are you offline?")
#      36 self.validate_response(resp)
#
# ConnectionError: Could not reach host. Are you offline?
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# File d:\test_data\venv\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 56
#      54 if driver:
#      55     print("INFO: Closing final browser session.")
# ---> 56     driver.quit()
#
# File d:\test_data\venv\Lib\site-packages\selenium\webdriver\chromium\webdriver.py:219, in ChromiumDriver.quit(self)
#     217 """Closes the browser and shuts down the ChromiumDriver executable."""
#     218 try:
# --> 219     super().quit()
#     220 except Exception:
#     221     # We don't care about the message because something probably has gone wrong
#     222     pass
#
# File d:\test_data\venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:612, in WebDriver.quit(self)
#     605 """Quits the driver and closes every associated window.
#     606
#     607 Example:
#     608 --------
#     609 >>> driver.quit()
#     610 """
#     611 try:
# --> 612     self.execute(Command.QUIT)
#     613 finally:
#     614     self.stop_client()
#
# File d:\test_data\venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:451, in WebDriver.execute(self, driver_command, params)
#     448     elif "sessionId" not in params:
#     449         params["sessionId"] = self.session_id
# --> 451 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     453 if response:
#     454     self.error_handler.check_response(response)
#
# File d:\test_data\venv\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:404, in RemoteConnection.execute(self, command, params)
#     402 trimmed = self._trim_large_entries(params)
#     403 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 404 return self._request(command_info[0], url, body=data)
#
# File d:\test_data\venv\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:428, in RemoteConnection._request(self, method, url, body)
#     425     body = None
#     427 if self._client_config.keep_alive:
# --> 428     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     429     statuscode = response.status
#     430 else:
#
# File d:\test_data\venv\Lib\site-packages\urllib3\_request_methods.py:135, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     132     urlopen_kw["body"] = body
#     134 if method in self._encode_url_methods:
# --> 135     return self.request_encode_url(
#     136         method,
#     137         url,
#     138         fields=fields,  # type: ignore[arg-type]
#     139         headers=headers,
#     140         **urlopen_kw,
#     141     )
#     142 else:
#     143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File d:\test_data\venv\Lib\site-packages\urllib3\_request_methods.py:182, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#     179 if fields:
#     180     url += "?" + urlencode(fields)
# --> 182 return self.urlopen(method, url, **extra_kw)
#
# File d:\test_data\venv\Lib\site-packages\urllib3\poolmanager.py:459, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     457     response = conn.urlopen(method, url, **kw)
#     458 else:
# --> 459     response = conn.urlopen(method, u.request_uri, **kw)
#     461 redirect_location = redirect and response.get_redirect_location()
#     462 if not redirect_location:
#
# File d:\test_data\venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File d:\test_data\venv\Lib\site-packages\urllib3\connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#     507 except BrokenPipeError:
#
# File d:\test_data\venv\Lib\site-packages\urllib3\connection.py:494, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     492 for header, value in headers.items():
#     493     self.putheader(header, value)
# --> 494 self.endheaders()
#     496 # If we're given a body we start sending that in chunks.
#     497 if chunks is not None:
#
# File C:\Python312\Lib\http\client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1329 else:
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File C:\Python312\Lib\http\client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1089 msg = b"\r\n".join(self._buffer)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#    1096     if hasattr(message_body, 'read'):
#    1097         # Let file-like take precedence over byte-like.  This
#    1098         # is needed to allow the current position of mmap'ed
#    1099         # files to be taken into account.
#
# File C:\Python312\Lib\http\client.py:1035, in HTTPConnection.send(self, data)
#    1033 if self.sock is None:
#    1034     if self.auto_open:
# -> 1035         self.connect()
#    1036     else:
#    1037         raise NotConnected()
#
# File d:\test_data\venv\Lib\site-packages\urllib3\connection.py:325, in HTTPConnection.connect(self)
#     324 def connect(self) -> None:
# --> 325     self.sock = self._new_conn()
#     326     if self._tunnel_host:
#     327         # If we're tunneling it means we're connected to our proxy.
#     328         self._has_connected_to_proxy = True
#
# File d:\test_data\venv\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File d:\test_data\venv\Lib\site-packages\urllib3\util\connection.py:81, in create_connection(address, timeout, source_address, socket_options)
#      79         err = _
#      80         if sock is not None:
# ---> 81             sock.close()
#      83 if err is not None:
#      84     try:
#
# File C:\Python312\Lib\socket.py:501, in socket.close(self)
#     497 def _real_close(self, _ss=_socket.socket):
#     498     # This function should not reference any globals. See issue #808164.
#     499     _ss.close(self)
# --> 501 def close(self):
#     502     # This function should not reference any globals. See issue #808164.
#     503     self._closed = True
#     504     if self._io_refs <= 0:
#
# KeyboardInterrupt:

# %%
league_mapping = {
    (74, 22, 2015): "france-ligue-1"
}

import time
import random

driver = None

try: 
    for (region_id, tournament_id, start_year_after), league_name in league_mapping.items():
        print("="*50)
        print(f"STARTING LEAGUE: {league_name}")

        if driver:
            driver.quit()
        
        print("INFO: Starting a new browser session...")
        driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

        season_ids, driver = get_season_ids(region_id, tournament_id, start_year_after, driver)
        print(f"Season_ids of {league_name}:", season_ids)

        for season_id in season_ids:
            if driver:
                driver.quit()

            print("\n" + "-"*20)
            print(f"INFO: Starting new session for Season ID: {season_id}")
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

            stage_ids = get_stage_ids(region_id, tournament_id, season_id, driver)
            if not stage_ids:
                print(f"WARNING: No stages found for season {season_id}. Skipping.")
                continue

            for stage_id in stage_ids:
                stage_config = process_season_stages(region_id, tournament_id, season_id, stage_id, league_name, driver)
                if not stage_config:
                    print(f"WARNING: Failed to process metadata for stage {stage_id}. Skipping to next stage.")
                    continue

                stage_path = stage_config["stage_path"]

                match_configs, driver = get_match_configs(stage_config, driver)
                for match_id, start_time_string in match_configs:
                    get_match_data(match_id, start_time_string, stage_path, driver)

            time.sleep(random.uniform(10, 20))

finally:
    # Make sure the final driver is always closed, even if there's an error
    if driver:
        print("INFO: Closing final browser session.")
        driver.quit()
# Out:
# ==================================================
# STARTING LEAGUE: france-ligue-1
# INFO: Starting a new browser session...
# Season_ids of france-ligue-1: ['10792', '10329', '9635', '9129', '8671', '8185', '7814', '7344', '6833', '6318', '5830']
#
# --------------------
# INFO: Starting new session for Season ID: 10792
# Start writing stage data for stage 24609
# SUCCESS: Wrote data for stage 24609 to bronze\stage_data\league=france-ligue-1\season=2025-2026\stage_id=24609\stage_info.json
# Start getting match_configs for stage 24609
# Found 27 matches for month 202508
# Found 54 matches for month 202509
# Found 90 matches for month 202510
# Found 126 matches for month 202511
# Found 144 matches for month 202512
# Found 171 matches for month 202601
# Found 207 matches for month 202602
# Found 243 matches for month 202603
# Found 279 matches for month 202604
# Found 306 matches for month 202605
# Found 306 matches for stage 24609
# INFO: Data for match 1911273 already exists. Skipping.
# INFO: Data for match 1911284 already exists. Skipping.
# INFO: Data for match 1911290 already exists. Skipping.
# INFO: Data for match 1911296 already exists. Skipping.
# INFO: Data for match 1911281 already exists. Skipping.
# INFO: Data for match 1911287 already exists. Skipping.
# INFO: Data for match 1911275 already exists. Skipping.
# INFO: Data for match 1911278 already exists. Skipping.
# INFO: Data for match 1911293 already exists. Skipping.
# INFO: Data for match 1911280 already exists. Skipping.
# INFO: Data for match 1911274 already exists. Skipping.
# INFO: Data for match 1911277 already exists. Skipping.
# INFO: Data for match 1911285 already exists. Skipping.
# INFO: Data for match 1911282 already exists. Skipping.
# INFO: Data for match 1911283 already exists. Skipping.
# INFO: Data for match 1911286 already exists. Skipping.
# INFO: Data for match 1911276 already exists. Skipping.
# INFO: Data for match 1911279 already exists. Skipping.
# INFO: Data for match 1911295 already exists. Skipping.
# INFO: Data for match 1911310 already exists. Skipping.
# INFO: Data for match 1911321 already exists. Skipping.
#
# --------------------
# INFO: Starting new session for Season ID: 10329
# Start writing stage data for stage 23414
# SUCCESS: Wrote data for stage 23414 to bronze\stage_data\league=france-ligue-1\season=2024-2025\stage_id=23414\stage_info.json
# Start getting match_configs for stage 23414
# Found 22 matches for month 202408
# Found 54 matches for month 202409
# Found 81 matches for month 202410
# Found 112 matches for month 202411
# Found 136 matches for month 202412
# Found 172 matches for month 202501
# Found 208 matches for month 202502
# Found 243 matches for month 202503
# Found 279 matches for month 202504
# Found 306 matches for month 202505
# Found 306 matches for stage 23414
# SUCCESS: Wrote data for match 960901
# SUCCESS: Wrote data for match 960905
# SUCCESS: Wrote data for match 960908
# SUCCESS: Wrote data for match 960910
# SUCCESS: Wrote data for match 960913
# SUCCESS: Wrote data for match 960914
# SUCCESS: Wrote data for match 960915
# SUCCESS: Wrote data for match 960916
# SUCCESS: Wrote data for match 960917
# SUCCESS: Wrote data for match 960897
# INFO: Closing final browser session.

# %%
league_mapping = {
    (81, 3, 2015): "germany-bundesliga",
    (252, 2, 2015): "england-premier-league",
    (247, 36, 2014): "international-fifa-world-cup",
    (250, 12, 2015): "europe-champions-league",
    (108, 5, 2015): "italy-serie-a",
    (74, 22, 2015): "france-ligue-1"
}

import time
import random

driver = None

initial_failures = []

try: 
    for (region_id, tournament_id, start_year_after), league_name in league_mapping.items():
        print("="*50)
        print(f"STARTING LEAGUE: {league_name}")

        if driver:
            driver.quit()
        
        print("INFO: Starting a new browser session...")
        driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

        season_ids, driver = get_season_ids(region_id, tournament_id, start_year_after, driver)
        print(f"Season_ids of {league_name}:", season_ids)

        for season_id in season_ids:
            if driver:
                driver.quit()

            print("\n" + "-"*20)
            print(f"INFO: Starting new session for Season ID: {season_id}")
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

            stage_ids = get_stage_ids(region_id, tournament_id, season_id, driver)
            if not stage_ids:
                print(f"WARNING: No stages found for season {season_id}. Skipping.")
                continue

            for stage_id in stage_ids:
                stage_config = process_season_stages(region_id, tournament_id, season_id, stage_id, league_name, driver)
                if not stage_config:
                    print(f"WARNING: Failed to process metadata for stage {stage_id}. Skipping to next stage.")
                    continue

                stage_path = stage_config["stage_path"]

                match_configs, driver = get_match_configs(stage_config, driver)

                for match_id, start_time_string in match_configs:
                    result = get_match_data(match_id, start_time_string, stage_path, driver)
                    if not result:
                        initial_failures.append([match_id, start_time_string, stage_path])

            time.sleep(random.uniform(10, 20))

    # --- PASS 2: Retry Loop for Failures ---
    final_failures = []
    if initial_failures:
        print("\n" + "="*50)
        print(f"RETRYING {len(initial_failures)} FAILED MATCHES...")
        print("="*50)
        
        for match_id, start_time_string, stage_path in initial_failures:
            print(f"- Retrying match {match_id}...")
            
            result = get_match_data(match_id, start_time_string, stage_path, driver)
            
            if not result:
                print(f"  -> RETRY FAILED: Match {match_id} still failing.")
                final_failures.append((match_id, start_time_string, stage_path))
            else:
                print(f"  -> RETRY SUCCESS: Match {match_id} scraped successfully.")

    # --- Final Report ---
    print("\n" + "="*50)
    print("CRAWL COMPLETE.")
    if final_failures:
        print(f"The following {len(final_failures)} matches could not be scraped after all retries:")
        for match_info in final_failures:
            print(f"  - Match ID: {match_info[0]}")
    else:
        print("All matches were scraped successfully (or were already present).")
    print("="*50)


finally:
    # Make sure the final driver is always closed, even if there's an error
    if driver:
        print("INFO: Closing final browser session.")
        driver.quit()
# Out:
# ==================================================
# STARTING LEAGUE: germany-bundesliga
# INFO: Starting a new browser session...
# Season_ids of germany-bundesliga: ['10720', '10365', '9649', '9120', '8667', '8279', '7872', '7405', '6902', '6392', '5870']
#
# --------------------
# INFO: Data for match 960895 already exists. Skipping.
# INFO: Data for match 960899 already exists. Skipping.
# INFO: Data for match 960878 already exists. Skipping.
# INFO: Data for match 960881 already exists. Skipping.
# INFO: Data for match 960884 already exists. Skipping.
# INFO: Data for match 960866 already exists. Skipping.
# INFO: Data for match 960869 already exists. Skipping.
# INFO: Data for match 960875 already exists. Skipping.
# INFO: Data for match 960912 already exists. Skipping.
# INFO: Data for match 960872 already exists. Skipping.
# INFO: Data for match 960887 already exists. Skipping.
# INFO: Data for match 960911 already exists. Skipping.
# INFO: Data for match 960867 already exists. Skipping.
# INFO: Data for match 960876 already exists. Skipping.
# INFO: Data for match 960870 already exists. Skipping.
# INFO: Data for match 960864 already exists. Skipping.
# INFO: Data for match 960890 already exists. Skipping.
# INFO: Data for match 960894 already exists. Skipping.
# INFO: Data for match 960902 already exists. Skipping.
# INFO: Data for match 960873 already exists. Skipping.
# INFO: Data for match 960862 already exists. Skipping.
# INFO: Data for match 960904 already exists. Skipping.
# INFO: Data for match 960896 already exists. Skipping.
# INFO: Data for match 960885 already exists. Skipping.
# INFO: Data for match 960882 already exists. Skipping.
# INFO: Data for match 960888 already exists. Skipping.
# INFO: Data for match 960863 already exists. Skipping.
# INFO: Data for match 960892 already exists. Skipping.
# INFO: Data for match 960907 already exists. Skipping.
# INFO: Data for match 960900 already exists. Skipping.
# INFO: Data for match 960879 already exists. Skipping.
# INFO: Data for match 960880 already exists. Skipping.
# INFO: Data for match 960883 already exists. Skipping.
# INFO: Data for match 960865 already exists. Skipping.
# INFO: Data for match 960868 already exists. Skipping.
# INFO: Data for match 960871 already exists. Skipping.
# INFO: Data for match 960874 already exists. Skipping.
# INFO: Data for match 960877 already exists. Skipping.
# INFO: Data for match 960893 already exists. Skipping.
# INFO: Data for match 960889 already exists. Skipping.
# INFO: Data for match 960886 already exists. Skipping.
# INFO: Data for match 960898 already exists. Skipping.
# INFO: Data for match 960901 already exists. Skipping.
# INFO: Data for match 960905 already exists. Skipping.
# INFO: Data for match 960908 already exists. Skipping.
# INFO: Data for match 960910 already exists. Skipping.
# INFO: Data for match 960913 already exists. Skipping.
# INFO: Data for match 960914 already exists. Skipping.
# INFO: Data for match 960915 already exists. Skipping.
# INFO: Data for match 960916 already exists. Skipping.
# INFO: Data for match 960917 already exists. Skipping.
# INFO: Data for match 960897 already exists. Skipping.
#
# ==================================================
# RETRYING 1 FAILED MATCHES...
# ==================================================
# - Retrying match 1076372...
# WARNING: Could not find a script containing all required data for match 1076372 on page https://www.whoscored.com/matches/1076372/live
#   -> RETRY FAILED: Match 1076372 still failing.
#
# ==================================================
# CRAWL COMPLETE.
# The following 1 matches could not be scraped after all retries:
#   - Match ID: 1076372
# ==================================================
# INFO: Closing final browser session.

# %%
league_mapping = {
    (250, 30, 2015): "europe-europa-league",
}

import time
import random

driver = None

try: 
    for (region_id, tournament_id, start_year_after), league_name in league_mapping.items():
        print("="*50)
        print(f"STARTING LEAGUE: {league_name}")

        if driver:
            driver.quit()
        
        print("INFO: Starting a new browser session...")
        driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

        season_ids, driver = get_season_ids(region_id, tournament_id, start_year_after, driver)
        print(f"Season_ids of {league_name}:", season_ids)

        for season_id in season_ids:
            if driver:
                driver.quit()

            print("\n" + "-"*20)
            print(f"INFO: Starting new session for Season ID: {season_id}")
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

            stage_ids = get_stage_ids(region_id, tournament_id, season_id, driver)
            if not stage_ids:
                print(f"WARNING: No stages found for season {season_id}. Skipping.")
                continue

            for stage_id in stage_ids:
                stage_config = process_season_stages(region_id, tournament_id, season_id, stage_id, league_name, driver)
                if not stage_config:
                    print(f"WARNING: Failed to process metadata for stage {stage_id}. Skipping to next stage.")
                    continue

                stage_path = stage_config["stage_path"]

                match_configs, driver = get_match_configs(stage_config, driver)

                for match_id, start_time_string in match_configs:
                    result = get_match_data(match_id, start_time_string, stage_path, driver)
                    if not result:
                        initial_failures.append([match_id, start_time_string, stage_path])

            time.sleep(random.uniform(10, 20))

    # --- PASS 2: Retry Loop for Failures ---
    final_failures = []
    if initial_failures:
        print("\n" + "="*50)
        print(f"RETRYING {len(initial_failures)} FAILED MATCHES...")
        print("="*50)
        
        for match_id, start_time_string, stage_path in initial_failures:
            print(f"- Retrying match {match_id}...")
            
            result = get_match_data(match_id, start_time_string, stage_path, driver)
            
            if not result:
                print(f"  -> RETRY FAILED: Match {match_id} still failing.")
                final_failures.append((match_id, start_time_string, stage_path))
            else:
                print(f"  -> RETRY SUCCESS: Match {match_id} scraped successfully.")

    # --- Final Report ---
    print("\n" + "="*50)
    print("CRAWL COMPLETE.")
    if final_failures:
        print(f"The following {len(final_failures)} matches could not be scraped after all retries:")
        for match_info in final_failures:
            print(f"  - Match ID: {match_info[0]}")
    else:
        print("All matches were scraped successfully (or were already present).")
    print("="*50)


finally:
    # Make sure the final driver is always closed, even if there's an error
    if driver:
        print("INFO: Closing final browser session.")
        driver.quit()
# Out:
# ==================================================
# STARTING LEAGUE: europe-europa-league
# INFO: Starting a new browser session...
# Season_ids of europe-europa-league: ['10904', '10458', '9778', '9087', '8741', '8178', '7805', '7353', '6843', '6275', '5849']
#
# --------------------
# INFO: Starting new session for Season ID: 10904
# Start writing stage data for stage 24798
# SUCCESS: Wrote data for stage 24798 to bronze\stage_data\league=europe-europa-league\season=2025-2026\stage_id=24798\stage_info.json
# Start getting match_configs for stage 24798
# Found 144 matches for month 202509
# Found 144 matches for stage 24798
# Start writing stage data for stage 24799
# ERROR: Failed to parse or access key data for stage 24799. Details: list index out of range
# WARNING: Failed to process metadata for stage 24799. Skipping to next stage.
#
# --------------------
# INFO: Starting new session for Season ID: 10458
# Start writing stage data for stage 24084
# SUCCESS: Wrote data for stage 24084 to bronze\stage_data\league=europe-europa-league\season=2024-2025\stage_id=24084\stage_info.json
# Start getting match_configs for stage 24084
# Found 16 matches for month 202502
# Found 32 matches for month 202503
# Found 40 matches for month 202504
# Found 45 matches for month 202505
# Found 45 matches for stage 24084
# SUCCESS: Wrote data for match 1888129
# SUCCESS: Wrote data for match 1888130
# SUCCESS: Wrote data for match 1888133
#   - Match ID: 1057968
#   - Match ID: 1057969
#   - Match ID: 1057970
#   - Match ID: 1057971
#   - Match ID: 1057973
#   - Match ID: 1057972
#   - Match ID: 1057975
#   - Match ID: 1057974
#   - Match ID: 1057977
#   - Match ID: 1057976
#   - Match ID: 1057978
#   - Match ID: 1057979
#   - Match ID: 1057981
#   - Match ID: 1057980
#   - Match ID: 1057982
#   - Match ID: 1057983
#   - Match ID: 1057984
#   - Match ID: 1057985
#   - Match ID: 1057988
#   - Match ID: 1057986
#   - Match ID: 1057987
#   - Match ID: 1057989
#   - Match ID: 1057991
#   - Match ID: 1057990
#   - Match ID: 1079531
#   - Match ID: 1079532
#   - Match ID: 1080310
#   - Match ID: 1080309
#   - Match ID: 1082835
#   - Match ID: 1082836
#   - Match ID: 1087002
#   - Match ID: 1087001
# ==================================================
# INFO: Closing final browser session.

# %%
# player_ids = set()

# for season_id, match in matches.items():
#     for match_id, start_time_string in match:
#         path = f"/data/season/{season_id}/match/{match_id}/match_data.json"
#         match_data_exists = os.path.exists(path)

#         if not match_data_exists:
#             continue

#         with open("path", "r") as f:
#             match_data = json.load(f)
        
#         print(match_data["matchId"])

# %%
# Probably should be in the next layer

# def get_player_data_from_match(season_id, match_id):
#     player_team_dictionary = {}
#     path = f"data/season/{season_id}/matches/{match_id}/match_data.json"
#     print(path)
#     match_data_exists = os.path.exists(path)

#     if not match_data_exists:
#         return False

#     with open(path, "r", encoding="utf-8") as f:
#         match_data = json.load(f)
    
#     match_centre_data = match_data["matchCentreData"]
#     home = match_centre_data["home"]
#     home_team_id = home["teamId"]
#     home_players = home["players"]

#     for home_player in home_players:
#         home_player_id = home_player["playerId"]
        
#         if (home_player_id, home_team_id) in player_team_dictionary.items():
#             continue

#         home_player_name = home_player["name"]

# %%
# get_player_data_from_match(10365, 1834247)
# Out:
# data/season/10365/matches/1834247/match_data.json
# 1834247

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# %%
import os
import json

root_dir = "bronze/match_data"

failed_count = 0
failed_matches = []
fixed_count = 0
fixed_matches = []

for dirpath, dirnames, filenames in os.walk(root_dir):
    # It should always be
    if "match_preview.json" in filenames:
        preview_file = os.path.join(dirpath, "match_preview.json")
        try:
            with open(preview_file, "r", encoding="utf-8") as f:
                data = json.load(f)
            start_time_utc = data.get("data", {}).get("startTimeUtc")
            match_id = data.get("metadata", {}).get("match_id")
            if not start_time_utc:
                print(f"{dirpath}: match_preview.json exists but startTimeUtc not found")

            if "match_data.json" not in filenames:
                # bronze/match_data/league=international-fifa-world-cup/season=2018/stage_id=12757/match_id=1249924
                segments = dirpath.split(os.sep)
                stage_path = "/".join(segments[2:5])

                status = get_match_data(
                    match_id=match_id,
                    start_time_string=start_time_utc,
                    stage_path=stage_path,
                    driver=driver,
                    is_hdfs=False
                )

                if status == MatchStatus.FAILED:
                    failed_count += 1
                    failed_matches.append(f"{match_id} ({stage_path})")
                elif status == MatchStatus.FETCHED:
                    fixed_count += 1
                    fixed_matches.append(f"{match_id} ({stage_path})")

        except Exception as e:
            failed_count += 1
            failed_matches.append(f"{dirpath} (Exception)")
            print(f"[ERROR] Failed to read {preview_file}: {e}")

print("\n=== Summary ===")
print(f"Successfully fixed: {fixed_count}")
print("Fixed matches:", fixed_matches)
print(f"Failed: {failed_count}")
print("Failed matches:", failed_matches)
# Out:
# WARNING: Could not find a script containing all required data for match 1076372 on page https://www.whoscored.com/matches/1076372/live
#
# === Summary ===
# Successfully fixed: 2
# Fixed matches: ['1874049 (league=international-world-cup-qualification-uefa/season=2025-2026/stage_id=23972)', '1873998 (league=international-world-cup-qualification-uefa/season=2025-2026/stage_id=23974)']
# Failed: 1
# Failed matches: ['1076372 (league=france-ligue-1/season=2016-2017/stage_id=13768)']

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# %%
path = "this/is/a/path"
segments = path.split(os.sep)
result = "/".join(segments[2:5])  # ["is", "a"]
print(result)  # Output: "is/a"
# Out:
# a/path

# %%
league_mapping = {
    (81, 3, 2015): "germany-bundesliga",
    (252, 2, 2015): "england-premier-league",
    (108, 5, 2015): "italy-serie-a",
    (74, 22, 2015): "france-ligue-1",
    (206, 4, 2015): "spain-laliga",

    (250, 12, 2015): "europe-champions-league",
    (250, 30, 2015): "europe-europa-league",

    (247, 36, 2014): "international-fifa-world-cup",
    (247, 67, 2025): "international-fifa-club-world-cup",
    (247, 124, 2012): "international-european-championship"
}

IS_HDFS = False
if driver:
    driver.quit()
    driver = None

try: 
    for (region_id, tournament_id, start_year_after), league_name in league_mapping.items():
        print("="*50)
        print(f"STARTING LEAGUE: {league_name}")
        
        print("INFO: Starting a new browser session...")
        if not driver:
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

        season_ids, driver = get_season_ids(region_id, tournament_id, start_year_after, driver)
        print(f"Season_ids of {league_name}:", season_ids)

        for season_id in season_ids:
            print("\n" + "-"*20)
            print(f"INFO: Starting new session for Season ID: {season_id}")

            stage_ids, driver = get_stage_ids(region_id, tournament_id, season_id, driver)
            if not stage_ids:
                print(f"WARNING: No stages found for season {season_id}. Skipping.")
                continue

            for stage_id in stage_ids:
                stage_config = process_season_stages(region_id, tournament_id, season_id, stage_id, league_name, driver, is_hdfs=IS_HDFS)
                if not stage_config:
                    print(f"WARNING: Failed to process metadata for stage {stage_id}. Skipping to next stage.")
                    continue

                stage_path = stage_config["stage_path"]
                stage_name = stage_config["stage_name"]

                match_configs, driver = get_match_configs(stage_config, driver, is_hdfs=IS_HDFS)
                
                matches_count = len(match_configs)
                fetched_count = 0 # Successfully fetched matches

                for match_id, start_time_string in match_configs:
                    status = get_match_data(match_id, start_time_string, stage_path, driver, is_hdfs=IS_HDFS)
                    if status == MatchStatus.FETCHED or status == MatchStatus.ALREADY_EXISTS:
                        fetched_count += 1
                    elif status == MatchStatus.FUTURE_MATCH:
                        matches_count -= 1
                
                print(f"Successfully fetched {fetched_count} out of {matches_count} matches for stage {stage_name} with id {stage_id}")

            # Reset driver after every season
            driver = reset_driver(driver)

finally:
    # Make sure the final driver is always closed, even if there's an error
    if driver:
        print("INFO: Closing final browser session.")
        driver.quit()
# Out:
# ==================================================
# STARTING LEAGUE: germany-bundesliga
# INFO: Starting a new browser session...
# Season_ids of germany-bundesliga: ['10720', '10365', '9649', '9120', '8667', '8279', '7872', '7405', '6902', '6392', '5870']
#
# --------------------
# INFO: Starting new session for Season ID: 10720
# Start writing stage data for stage 24478
# SUCCESS: Wrote data for stage 24478 to local bronze/stage_data/league=germany-bundesliga/season=2025-2026/stage_id=24478/stage_info.json
# Start getting match_configs for stage 24478
# INFO: Closing final browser session.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[98], line 51
#      48 stage_path = stage_config["stage_path"]
#      49 stage_name = stage_config["stage_name"]
# ---> 51 match_configs, driver = get_match_configs(stage_config, driver, is_hdfs=IS_HDFS)
#      53 matches_count = len(match_configs)
#      54 fetched_count = 0 # Successfully fetched matches
#
# Cell In[90], line 22, in get_match_configs(stage_config, driver, is_hdfs)
#      19 monthly_data_url = f"https://www.whoscored.com/tournaments/{stage_id}/data/?d={month_key}&isAggregate=false"
#      21 try:
# ---> 22     driver.get(monthly_data_url)
#      23     # Using execute_script is clever, but let's make it robust
#      24     json_text = driver.execute_script("return document.body.innerText || null;")
#
# File ~/big_data/venv/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:479, in WebDriver.get(self, url)
#     461 def get(self, url: str) -> None:
#     462     """Navigate the browser to the specified URL in the current window or
#     463     tab.
#     464
#    (...)    477     >>> driver.get("https://example.com")
#     478     """
# --> 479     self.execute(Command.GET, {"url": url})
#
# File ~/big_data/venv/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:451, in WebDriver.execute(self, driver_command, params)
#     448     elif "sessionId" not in params:
#     449         params["sessionId"] = self.session_id
# --> 451 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     453 if response:
#     454     self.error_handler.check_response(response)
#
# File ~/big_data/venv/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:404, in RemoteConnection.execute(self, command, params)
#     402 trimmed = self._trim_large_entries(params)
#     403 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 404 return self._request(command_info[0], url, body=data)
#
# File ~/big_data/venv/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:428, in RemoteConnection._request(self, method, url, body)
#     425     body = None
#     427 if self._client_config.keep_alive:
# --> 428     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     429     statuscode = response.status
#     430 else:
#
# File ~/big_data/venv/lib/python3.11/site-packages/urllib3/_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)    140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~/big_data/venv/lib/python3.11/site-packages/urllib3/_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File ~/big_data/venv/lib/python3.11/site-packages/urllib3/poolmanager.py:459, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     457     response = conn.urlopen(method, url, **kw)
#     458 else:
# --> 459     response = conn.urlopen(method, u.request_uri, **kw)
#     461 redirect_location = redirect and response.get_redirect_location()
#     462 if not redirect_location:
#
# File ~/big_data/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/big_data/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/big_data/venv/lib/python3.11/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File /usr/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /usr/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /usr/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
from datetime import datetime, timezone

def write_crawl_time(is_hdfs: bool):
    crawl_time = datetime.now(timezone.utc) - timedelta(days=20)
    crawl_time_str = datetime.strftime(crawl_time, "%Y-%m-%dT%H:%M:%SZ")

    file_path = "bronze/last_crawl_timestamp.txt"
    if is_hdfs:
        hdfs_path = os.path.join(HDFS_PATH, file_path)
        with client.write(hdfs_path, encoding="utf-8") as f:
            f.write(crawl_time_str)
        print(f"Wrote to HDFS: {hdfs_path}")

    else:
        os.makedirs(os.path.dirname(file_path), exist_ok=True)
        with open(file_path, "w", encoding="utf-8") as f:
            f.write(crawl_time_str)
        print(f"Wrote to local FS: {file_path}")

# %%
write_crawl_time(is_hdfs=IS_HDFS)
# Out:
# Wrote to local FS: bronze/last_crawl_timestamp.txt

# %%
league_mapping = {
    (206, 4, 2015): "spain-laliga",
    (250, 30, 2015): "europe-europa-league",

    (250, 751, 2022): "europe-european-championship-qualification",
    (247, 721, 2021): "international-world-cup-qualification-uefa",
    (247, 683, 2018): "international-uefa-nations-league-a",
    (247, 684, 2018): "international-uefa-nations-league-b",
    (247, 685, 2018): "international-uefa-nations-league-c",
    (247, 686, 2018): "international-uefa-nations-league-d"
}

IS_HDFS = False
if driver:
    driver.quit()
    driver = None

# Storing failed matches to try 1 more time
initial_failures = []

try: 
    for (region_id, tournament_id, start_year_after), league_name in league_mapping.items():
        print("="*50)
        print(f"STARTING LEAGUE: {league_name}")
        
        print("INFO: Starting a new browser session...")
        if not driver:
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

        season_ids, driver = get_season_ids(region_id, tournament_id, start_year_after, driver)
        print(f"Season_ids of {league_name}:", season_ids)

        for season_id in season_ids:
            print("\n" + "-"*20)
            print(f"INFO: Starting new session for Season ID: {season_id}")

            stage_ids, driver = get_stage_ids(region_id, tournament_id, season_id, driver)
            if not stage_ids:
                print(f"WARNING: No stages found for season {season_id}. Skipping.")
                continue

            for stage_id in stage_ids:
                stage_config = process_season_stages(region_id, tournament_id, season_id, stage_id, league_name, driver, is_hdfs=IS_HDFS)
                if not stage_config:
                    print(f"WARNING: Failed to process metadata for stage {stage_id}. Skipping to next stage.")
                    continue

                stage_path = stage_config["stage_path"]
                stage_name = stage_config["stage_name"]

                match_configs, driver = get_match_configs(stage_config, driver, is_hdfs=IS_HDFS)
                
                matches_count = len(match_configs)
                fetched_count = 0 # Successfully fetched matches

                for match_id, start_time_string in match_configs:
                    status = get_match_data(match_id, start_time_string, stage_path, driver, is_hdfs=IS_HDFS)
                    if status == MatchStatus.FETCHED or status == MatchStatus.ALREADY_EXISTS:
                        fetched_count += 1
                    elif status == MatchStatus.FUTURE_MATCH:
                        matches_count -= 1
                    elif status == MatchStatus.FAILED:
                        initial_failures.append([match_id, start_time_string, stage_path])
                
                print(f"Successfully fetched {fetched_count} out of {matches_count} matches for stage {stage_name} with id {stage_id}")

            # Reset driver after every season
            driver = reset_driver(driver)

    # Retry loop for failed matches
    final_failures = []
    if initial_failures:
        print("\n" + "="*50)
        print(f"RETRYING {len(initial_failures)} FAILED MATCHES...")
        print("="*50)
        
        for match_id, start_time_string, stage_path in initial_failures:
            status = get_match_data(match_id, start_time_string, stage_path, driver)
            
            if status == MatchStatus.FAILED:
                print(f"  -> RETRY FAILED: Match {match_id} still failing.")
                final_failures.append((match_id, start_time_string, stage_path))
            else:
                print(f"  -> RETRY SUCCESS: Match {match_id} scraped successfully.")

    # Report
    print("\n" + "="*50)
    print("CRAWL COMPLETE.")
    if final_failures:
        print(f"The following {len(final_failures)} matches could not be scraped after all retries:")
        for match_info in final_failures:
            print(f"  - Match ID: {match_info[0]}")
    else:
        print("All matches were scraped successfully (or were already present).")
    print("="*50)

finally:
    # Make sure the final driver is always closed, even if there's an error
    if driver:
        print("INFO: Closing final browser session.")
        driver.quit()
# Out:
# ==================================================
# STARTING LEAGUE: spain-laliga
# INFO: Starting a new browser session...
# Season_ids of spain-laliga: ['10803', '10317', '9682', '9149', '8681', '8321', '7889', '7466', '6960', '6436', '5933']
#
# --------------------
# INFO: Starting new session for Season ID: 10803
# Start writing stage data for stage 24622
# SUCCESS: Wrote data for stage 24622 to local bronze/stage_data/league=spain-laliga/season=2025-2026/stage_id=24622/stage_info.json
# Start getting match_configs for stage 24622
# Found 380 matches for stage 24622
# Successfully fetched 31 out of 31 matches for stage LaLiga with id 24622
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 10317
# WARNING: No stages found, retrying... (attempt 1)
# INFO: Starting a new browser session...
# Start writing stage data for stage 23401
# SUCCESS: Wrote data for stage 23401 to local bronze/stage_data/league=spain-laliga/season=2024-2025/stage_id=23401/stage_info.json
# Start getting match_configs for stage 23401
# Found 380 matches for stage 23401
# Successfully fetched 380 out of 380 matches for stage LaLiga with id 23401
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 9682
# Start writing stage data for stage 22176
# SUCCESS: Wrote data for stage 22176 to local bronze/stage_data/league=spain-laliga/season=2023-2024/stage_id=22176/stage_info.json
# Start getting match_configs for stage 22176
# Found 380 matches for stage 22176
# Successfully fetched 380 out of 380 matches for stage LaLiga with id 22176
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 9149
# Start writing stage data for stage 21073
# SUCCESS: Wrote data for stage 21073 to local bronze/stage_data/league=spain-laliga/season=2022-2023/stage_id=21073/stage_info.json
# Start getting match_configs for stage 21073
# Found 380 matches for stage 21073
# Successfully fetched 380 out of 380 matches for stage LaLiga with id 21073
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8681
# Start writing stage data for stage 19895
# SUCCESS: Wrote data for stage 19895 to local bronze/stage_data/league=spain-laliga/season=2021-2022/stage_id=19895/stage_info.json
# Start getting match_configs for stage 19895
# Found 380 matches for stage 19895
# Successfully fetched 380 out of 380 matches for stage LaLiga with id 19895
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8321
# Start writing stage data for stage 18851
# SUCCESS: Wrote data for stage 18851 to local bronze/stage_data/league=spain-laliga/season=2020-2021/stage_id=18851/stage_info.json
# Start getting match_configs for stage 18851
# Found 380 matches for stage 18851
# Successfully fetched 380 out of 380 matches for stage LaLiga with id 18851
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7889
# Start writing stage data for stage 17702
# SUCCESS: Wrote data for stage 17702 to local bronze/stage_data/league=spain-laliga/season=2019-2020/stage_id=17702/stage_info.json
# Start getting match_configs for stage 17702
# Found 380 matches for stage 17702
# Successfully fetched 380 out of 380 matches for stage LaLiga with id 17702
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7466
# Start writing stage data for stage 16546
# SUCCESS: Wrote data for stage 16546 to local bronze/stage_data/league=spain-laliga/season=2018-2019/stage_id=16546/stage_info.json
# Start getting match_configs for stage 16546
# Found 380 matches for stage 16546
# Successfully fetched 380 out of 380 matches for stage LaLiga with id 16546
# INFO: Starting a new browser session...
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. A with id 22510
# Start writing stage data for stage 22512
# SUCCESS: Wrote data for stage 22512 to local bronze/stage_data/league=europe-europa-league/season=2023-2024/stage_id=22512/stage_info.json
# Start getting match_configs for stage 22512
# Found 12 matches for stage 22512
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. B with id 22512
# Start writing stage data for stage 22511
# SUCCESS: Wrote data for stage 22511 to local bronze/stage_data/league=europe-europa-league/season=2023-2024/stage_id=22511/stage_info.json
# Start getting match_configs for stage 22511
# Found 12 matches for stage 22511
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. C with id 22511
# Start writing stage data for stage 22513
# SUCCESS: Wrote data for stage 22513 to local bronze/stage_data/league=europe-europa-league/season=2023-2024/stage_id=22513/stage_info.json
# Start getting match_configs for stage 22513
# Found 12 matches for stage 22513
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. D with id 22513
# Start writing stage data for stage 22514
# SUCCESS: Wrote data for stage 22514 to local bronze/stage_data/league=europe-europa-league/season=2023-2024/stage_id=22514/stage_info.json
# Start getting match_configs for stage 22514
# Found 12 matches for stage 22514
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. E with id 22514
# Start writing stage data for stage 22517
# SUCCESS: Wrote data for stage 22517 to local bronze/stage_data/league=europe-europa-league/season=2023-2024/stage_id=22517/stage_info.json
# Start getting match_configs for stage 22517
# Found 12 matches for stage 22517
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. F with id 22517
# Start writing stage data for stage 22515
# SUCCESS: Wrote data for stage 22515 to local bronze/stage_data/league=europe-europa-league/season=2023-2024/stage_id=22515/stage_info.json
# Start getting match_configs for stage 22515
# Found 12 matches for stage 22515
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. G with id 22515
# Start writing stage data for stage 22516
# SUCCESS: Wrote data for stage 22516 to local bronze/stage_data/league=europe-europa-league/season=2023-2024/stage_id=22516/stage_info.json
# Start getting match_configs for stage 22516
# Found 12 matches for stage 22516
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. H with id 22516
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 9087
# Start writing stage data for stage 20979
# SUCCESS: Wrote data for stage 20979 to local bronze/stage_data/league=europe-europa-league/season=2022-2023/stage_id=20979/stage_info.json
# Start getting match_configs for stage 20979
# Found 45 matches for stage 20979
# Successfully fetched 45 out of 45 matches for stage Europa League Final Stage with id 20979
# Start writing stage data for stage 20971
# SUCCESS: Wrote data for stage 20971 to local bronze/stage_data/league=europe-europa-league/season=2022-2023/stage_id=20971/stage_info.json
# Start getting match_configs for stage 20971
# Found 12 matches for stage 20971
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. A with id 20971
# Start writing stage data for stage 20972
# SUCCESS: Wrote data for stage 20972 to local bronze/stage_data/league=europe-europa-league/season=2022-2023/stage_id=20972/stage_info.json
# Start getting match_configs for stage 20972
# Found 12 matches for stage 20972
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. B with id 20972
# Found 12 matches for stage 15496
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. H with id 15496
# Start writing stage data for stage 15497
# SUCCESS: Wrote data for stage 15497 to local bronze/stage_data/league=europe-europa-league/season=2017-2018/stage_id=15497/stage_info.json
# Start getting match_configs for stage 15497
# Found 12 matches for stage 15497
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. I with id 15497
# Start writing stage data for stage 15501
# SUCCESS: Wrote data for stage 15501 to local bronze/stage_data/league=europe-europa-league/season=2017-2018/stage_id=15501/stage_info.json
# Start getting match_configs for stage 15501
# Found 12 matches for stage 15501
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. J with id 15501
# Start writing stage data for stage 15500
# SUCCESS: Wrote data for stage 15500 to local bronze/stage_data/league=europe-europa-league/season=2017-2018/stage_id=15500/stage_info.json
# Start getting match_configs for stage 15500
# Found 12 matches for stage 15500
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. K with id 15500
# Start writing stage data for stage 15499
# SUCCESS: Wrote data for stage 15499 to local bronze/stage_data/league=europe-europa-league/season=2017-2018/stage_id=15499/stage_info.json
# Start getting match_configs for stage 15499
# Found 12 matches for stage 15499
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. L with id 15499
# Start writing stage data for stage 15617
# SUCCESS: Wrote data for stage 15617 to local bronze/stage_data/league=europe-europa-league/season=2017-2018/stage_id=15617/stage_info.json
# Start getting match_configs for stage 15617
# Found 61 matches for stage 15617
# Successfully fetched 61 out of 61 matches for stage Europa League Final Stage with id 15617
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 6275
# Start writing stage data for stage 14186
# SUCCESS: Wrote data for stage 14186 to local bronze/stage_data/league=europe-europa-league/season=2016-2017/stage_id=14186/stage_info.json
# Start getting match_configs for stage 14186
# Found 12 matches for stage 14186
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. A with id 14186
# Start writing stage data for stage 14187
# SUCCESS: Wrote data for stage 14187 to local bronze/stage_data/league=europe-europa-league/season=2016-2017/stage_id=14187/stage_info.json
# Start getting match_configs for stage 14187
# Found 12 matches for stage 14187
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. B with id 14187
# Start writing stage data for stage 14184
# SUCCESS: Wrote data for stage 14184 to local bronze/stage_data/league=europe-europa-league/season=2016-2017/stage_id=14184/stage_info.json
# Start getting match_configs for stage 14184
# Found 12 matches for stage 14184
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. C with id 14184
# Start writing stage data for stage 14188
# SUCCESS: Wrote data for stage 14188 to local bronze/stage_data/league=europe-europa-league/season=2016-2017/stage_id=14188/stage_info.json
# Start getting match_configs for stage 14188
# Found 12 matches for stage 14188
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. D with id 14188
# Start writing stage data for stage 14183
# SUCCESS: Wrote data for stage 14183 to local bronze/stage_data/league=europe-europa-league/season=2016-2017/stage_id=14183/stage_info.json
# Start getting match_configs for stage 14183
# Found 12 matches for stage 14183
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. E with id 14183
# Start writing stage data for stage 14182
# SUCCESS: Wrote data for stage 14182 to local bronze/stage_data/league=europe-europa-league/season=2016-2017/stage_id=14182/stage_info.json
# Start getting match_configs for stage 14182
# Found 12 matches for stage 14182
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. F with id 14182
# Start writing stage data for stage 14185
# SUCCESS: Wrote data for stage 14185 to local bronze/stage_data/league=europe-europa-league/season=2016-2017/stage_id=14185/stage_info.json
# Start getting match_configs for stage 14185
# Found 12 matches for stage 14185
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. G with id 14185
# Start writing stage data for stage 14181
# SUCCESS: Wrote data for stage 14181 to local bronze/stage_data/league=europe-europa-league/season=2016-2017/stage_id=14181/stage_info.json
# Start getting match_configs for stage 14181
# Found 12 matches for stage 14181
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. H with id 14181
# Start writing stage data for stage 14180
# SUCCESS: Wrote data for stage 14180 to local bronze/stage_data/league=europe-europa-league/season=2016-2017/stage_id=14180/stage_info.json
# Start getting match_configs for stage 14180
# Found 12 matches for stage 14180
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. I with id 14180
# Start writing stage data for stage 14179
# SUCCESS: Wrote data for stage 14179 to local bronze/stage_data/league=europe-europa-league/season=2016-2017/stage_id=14179/stage_info.json
# Start getting match_configs for stage 14179
# Found 12 matches for stage 14179
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. J with id 14179
# Start writing stage data for stage 14178
# SUCCESS: Wrote data for stage 14178 to local bronze/stage_data/league=europe-europa-league/season=2016-2017/stage_id=14178/stage_info.json
# Start getting match_configs for stage 14178
# Found 12 matches for stage 14178
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. K with id 14178
# Start writing stage data for stage 14177
# SUCCESS: Wrote data for stage 14177 to local bronze/stage_data/league=europe-europa-league/season=2016-2017/stage_id=14177/stage_info.json
# Start getting match_configs for stage 14177
# Found 12 matches for stage 14177
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. L with id 14177
# Start writing stage data for stage 14368
# SUCCESS: Wrote data for stage 14368 to local bronze/stage_data/league=europe-europa-league/season=2016-2017/stage_id=14368/stage_info.json
# Start getting match_configs for stage 14368
# Found 61 matches for stage 14368
# Successfully fetched 61 out of 61 matches for stage Europa League Final Stage with id 14368
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 5849
# Start writing stage data for stage 12869
# SUCCESS: Wrote data for stage 12869 to local bronze/stage_data/league=europe-europa-league/season=2015-2016/stage_id=12869/stage_info.json
# Start getting match_configs for stage 12869
# Found 12 matches for stage 12869
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. A with id 12869
# Start writing stage data for stage 12870
# SUCCESS: Wrote data for stage 12870 to local bronze/stage_data/league=europe-europa-league/season=2015-2016/stage_id=12870/stage_info.json
# Start getting match_configs for stage 12870
# Found 12 matches for stage 12870
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. B with id 12870
# Start writing stage data for stage 12876
# SUCCESS: Wrote data for stage 12876 to local bronze/stage_data/league=europe-europa-league/season=2015-2016/stage_id=12876/stage_info.json
# Start getting match_configs for stage 12876
# Found 12 matches for stage 12876
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. C with id 12876
# Start writing stage data for stage 12871
# SUCCESS: Wrote data for stage 12871 to local bronze/stage_data/league=europe-europa-league/season=2015-2016/stage_id=12871/stage_info.json
# Start getting match_configs for stage 12871
# Found 12 matches for stage 12871
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. D with id 12871
# Start writing stage data for stage 12872
# SUCCESS: Wrote data for stage 12872 to local bronze/stage_data/league=europe-europa-league/season=2015-2016/stage_id=12872/stage_info.json
# Start getting match_configs for stage 12872
# Found 12 matches for stage 12872
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. E with id 12872
# Start writing stage data for stage 12873
# SUCCESS: Wrote data for stage 12873 to local bronze/stage_data/league=europe-europa-league/season=2015-2016/stage_id=12873/stage_info.json
# Start getting match_configs for stage 12873
# Found 12 matches for stage 12873
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. F with id 12873
# Start writing stage data for stage 12875
# SUCCESS: Wrote data for stage 12875 to local bronze/stage_data/league=europe-europa-league/season=2015-2016/stage_id=12875/stage_info.json
# Start getting match_configs for stage 12875
# Found 12 matches for stage 12875
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. G with id 12875
# Start writing stage data for stage 12874
# SUCCESS: Wrote data for stage 12874 to local bronze/stage_data/league=europe-europa-league/season=2015-2016/stage_id=12874/stage_info.json
# Start getting match_configs for stage 12874
# Found 12 matches for stage 12874
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. H with id 12874
# Start writing stage data for stage 12879
# SUCCESS: Wrote data for stage 12879 to local bronze/stage_data/league=europe-europa-league/season=2015-2016/stage_id=12879/stage_info.json
# Start getting match_configs for stage 12879
# Found 12 matches for stage 12879
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. I with id 12879
# Start writing stage data for stage 12877
# SUCCESS: Wrote data for stage 12877 to local bronze/stage_data/league=europe-europa-league/season=2015-2016/stage_id=12877/stage_info.json
# Start getting match_configs for stage 12877
# Found 12 matches for stage 12877
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. J with id 12877
# Start writing stage data for stage 12880
# SUCCESS: Wrote data for stage 12880 to local bronze/stage_data/league=europe-europa-league/season=2015-2016/stage_id=12880/stage_info.json
# Start getting match_configs for stage 12880
# Found 12 matches for stage 12880
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. K with id 12880
# Start writing stage data for stage 12878
# SUCCESS: Wrote data for stage 12878 to local bronze/stage_data/league=europe-europa-league/season=2015-2016/stage_id=12878/stage_info.json
# Start getting match_configs for stage 12878
# Found 12 matches for stage 12878
# Successfully fetched 12 out of 12 matches for stage Europa League Grp. L with id 12878
# Start writing stage data for stage 13186
# SUCCESS: Wrote data for stage 13186 to local bronze/stage_data/league=europe-europa-league/season=2015-2016/stage_id=13186/stage_info.json
# Start getting match_configs for stage 13186
# Found 61 matches for stage 13186
# Successfully fetched 61 out of 61 matches for stage Europa League Final Stages with id 13186
# INFO: Starting a new browser session...
# ==================================================
# STARTING LEAGUE: europe-european-championship-qualification
# INFO: Starting a new browser session...
# Season_ids of europe-european-championship-qualification: ['10118', '10295']
#
# --------------------
# INFO: Starting new session for Season ID: 10118
# Start writing stage data for stage 21405
# SUCCESS: Wrote data for stage 21405 to local bronze/stage_data/league=europe-european-championship-qualification/season=2023/stage_id=21405/stage_info.json
# Start getting match_configs for stage 21405
# Found 20 matches for stage 21405
# Successfully fetched 20 out of 20 matches for stage EURO Qualification Grp. A with id 21405
# Start writing stage data for stage 21406
# SUCCESS: Wrote data for stage 21406 to local bronze/stage_data/league=europe-european-championship-qualification/season=2023/stage_id=21406/stage_info.json
# Start getting match_configs for stage 21406
# Found 20 matches for stage 21406
# Successfully fetched 20 out of 20 matches for stage EURO Qualification Grp. B with id 21406
# Start writing stage data for stage 21407
# SUCCESS: Wrote data for stage 21407 to local bronze/stage_data/league=europe-european-championship-qualification/season=2023/stage_id=21407/stage_info.json
# Start getting match_configs for stage 21407
# Found 20 matches for stage 21407
# Successfully fetched 20 out of 20 matches for stage EURO Qualification Grp. C with id 21407
# Start writing stage data for stage 21408
# SUCCESS: Wrote data for stage 21408 to local bronze/stage_data/league=europe-european-championship-qualification/season=2023/stage_id=21408/stage_info.json
# Start getting match_configs for stage 21408
# Found 20 matches for stage 21408
# Successfully fetched 20 out of 20 matches for stage EURO Qualification Grp. D with id 21408
# Start writing stage data for stage 21409
# SUCCESS: Wrote data for stage 21409 to local bronze/stage_data/league=europe-european-championship-qualification/season=2023/stage_id=21409/stage_info.json
# Start getting match_configs for stage 21409
# Found 20 matches for stage 21409
# Successfully fetched 20 out of 20 matches for stage EURO Qualification Grp. E with id 21409
# Start writing stage data for stage 21410
# SUCCESS: Wrote data for stage 21410 to local bronze/stage_data/league=europe-european-championship-qualification/season=2023/stage_id=21410/stage_info.json
# Start getting match_configs for stage 21410
# Found 20 matches for stage 21410
# Successfully fetched 20 out of 20 matches for stage EURO Qualification Grp. F with id 21410
# Start writing stage data for stage 21411
# SUCCESS: Wrote data for stage 21411 to local bronze/stage_data/league=europe-european-championship-qualification/season=2023/stage_id=21411/stage_info.json
# Start getting match_configs for stage 21411
# Found 20 matches for stage 21411
# Successfully fetched 20 out of 20 matches for stage EURO Qualification Grp. G with id 21411
# Start writing stage data for stage 21412
# SUCCESS: Wrote data for stage 21412 to local bronze/stage_data/league=europe-european-championship-qualification/season=2023/stage_id=21412/stage_info.json
# Start getting match_configs for stage 21412
# Found 30 matches for stage 21412
# Successfully fetched 30 out of 30 matches for stage EURO Qualification Grp. H with id 21412
# Start writing stage data for stage 21413
# SUCCESS: Wrote data for stage 21413 to local bronze/stage_data/league=europe-european-championship-qualification/season=2023/stage_id=21413/stage_info.json
# Start getting match_configs for stage 21413
# Found 30 matches for stage 21413
# Successfully fetched 30 out of 30 matches for stage EURO Qualification Grp. I with id 21413
# Start writing stage data for stage 21414
# Successfully fetched 6 out of 6 matches for stage UEFA Nations League B Grp. 2 with id 15944
# Start writing stage data for stage 15945
# SUCCESS: Wrote data for stage 15945 to local bronze/stage_data/league=international-uefa-nations-league-b/season=2018-2019/stage_id=15945/stage_info.json
# Start getting match_configs for stage 15945
# Found 6 matches for stage 15945
# Successfully fetched 6 out of 6 matches for stage UEFA Nations League B Grp. 3 with id 15945
# Start writing stage data for stage 15946
# SUCCESS: Wrote data for stage 15946 to local bronze/stage_data/league=international-uefa-nations-league-b/season=2018-2019/stage_id=15946/stage_info.json
# Start getting match_configs for stage 15946
# Found 6 matches for stage 15946
# Successfully fetched 6 out of 6 matches for stage UEFA Nations League B Grp. 4 with id 15946
# INFO: Starting a new browser session...
# ==================================================
# STARTING LEAGUE: international-uefa-nations-league-c
# INFO: Starting a new browser session...
# Season_ids of international-uefa-nations-league-c: ['9982', '8872', '8156', '7215']
#
# --------------------
# INFO: Starting new session for Season ID: 9982
# Start writing stage data for stage 22914
# SUCCESS: Wrote data for stage 22914 to local bronze/stage_data/league=international-uefa-nations-league-c/season=2024-2025/stage_id=22914/stage_info.json
# Start getting match_configs for stage 22914
# Found 12 matches for stage 22914
# Successfully fetched 12 out of 12 matches for stage UEFA Nations League C Grp. 1 with id 22914
# Start writing stage data for stage 22913
# SUCCESS: Wrote data for stage 22913 to local bronze/stage_data/league=international-uefa-nations-league-c/season=2024-2025/stage_id=22913/stage_info.json
# Start getting match_configs for stage 22913
# Found 12 matches for stage 22913
# Successfully fetched 12 out of 12 matches for stage UEFA Nations League C Grp. 2 with id 22913
# Start writing stage data for stage 22915
# SUCCESS: Wrote data for stage 22915 to local bronze/stage_data/league=international-uefa-nations-league-c/season=2024-2025/stage_id=22915/stage_info.json
# Start getting match_configs for stage 22915
# Found 12 matches for stage 22915
# Successfully fetched 12 out of 12 matches for stage UEFA Nations League C Grp. 3 with id 22915
# Start writing stage data for stage 22916
# SUCCESS: Wrote data for stage 22916 to local bronze/stage_data/league=international-uefa-nations-league-c/season=2024-2025/stage_id=22916/stage_info.json
# Start getting match_configs for stage 22916
# Found 12 matches for stage 22916
# Successfully fetched 12 out of 12 matches for stage UEFA Nations League C Grp. 4 with id 22916
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8872
# Start writing stage data for stage 20395
# SUCCESS: Wrote data for stage 20395 to local bronze/stage_data/league=international-uefa-nations-league-c/season=2022-2023/stage_id=20395/stage_info.json
# Start getting match_configs for stage 20395
# Found 12 matches for stage 20395
# Successfully fetched 12 out of 12 matches for stage UEFA Nations League C Grp. 1 with id 20395
# Start writing stage data for stage 20398
# SUCCESS: Wrote data for stage 20398 to local bronze/stage_data/league=international-uefa-nations-league-c/season=2022-2023/stage_id=20398/stage_info.json
# Start getting match_configs for stage 20398
# Found 12 matches for stage 20398
# Successfully fetched 12 out of 12 matches for stage UEFA Nations League C Grp. 2 with id 20398
# Start writing stage data for stage 20397
# SUCCESS: Wrote data for stage 20397 to local bronze/stage_data/league=international-uefa-nations-league-c/season=2022-2023/stage_id=20397/stage_info.json
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7216
# Start writing stage data for stage 15951
# SUCCESS: Wrote data for stage 15951 to local bronze/stage_data/league=international-uefa-nations-league-d/season=2018-2019/stage_id=15951/stage_info.json
# Start getting match_configs for stage 15951
# Found 12 matches for stage 15951
# Successfully fetched 12 out of 12 matches for stage UEFA Nations League D Grp. 1 with id 15951
# Start writing stage data for stage 15953
# SUCCESS: Wrote data for stage 15953 to local bronze/stage_data/league=international-uefa-nations-league-d/season=2018-2019/stage_id=15953/stage_info.json
# Start getting match_configs for stage 15953
# Found 12 matches for stage 15953
# Successfully fetched 12 out of 12 matches for stage UEFA Nations League D Grp. 2 with id 15953
# Start writing stage data for stage 15954
# SUCCESS: Wrote data for stage 15954 to local bronze/stage_data/league=international-uefa-nations-league-d/season=2018-2019/stage_id=15954/stage_info.json
# Start getting match_configs for stage 15954
# Found 12 matches for stage 15954
# Successfully fetched 12 out of 12 matches for stage UEFA Nations League D Grp. 3 with id 15954
# Start writing stage data for stage 15955
# SUCCESS: Wrote data for stage 15955 to local bronze/stage_data/league=international-uefa-nations-league-d/season=2018-2019/stage_id=15955/stage_info.json
# Start getting match_configs for stage 15955
# Found 12 matches for stage 15955
# Successfully fetched 12 out of 12 matches for stage UEFA Nations League D Grp. 4 with id 15955
# INFO: Starting a new browser session...
#
# ==================================================
# CRAWL COMPLETE.
# All matches were scraped successfully (or were already present).
# ==================================================
# INFO: Closing final browser session.

# %%
league_mapping = {

    
    (247, 124, 2012): "international-european-championship"
}

IS_HDFS = False
if driver:
    driver.quit()
    driver = None

# Storing failed matches to try 1 more time
initial_failures = []

try: 
    for (region_id, tournament_id, start_year_after), league_name in league_mapping.items():
        print("="*50)
        print(f"STARTING LEAGUE: {league_name}")
        
        print("INFO: Starting a new browser session...")
        if not driver:
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

        season_ids, driver = get_season_ids(region_id, tournament_id, start_year_after, driver)
        print(f"Season_ids of {league_name}:", season_ids)

        for season_id in season_ids:
            print("\n" + "-"*20)
            print(f"INFO: Starting new session for Season ID: {season_id}")

            stage_ids, driver = get_stage_ids(region_id, tournament_id, season_id, driver)
            if not stage_ids:
                print(f"WARNING: No stages found for season {season_id}. Skipping.")
                continue

            for stage_id in stage_ids:
                stage_config = process_season_stages(region_id, tournament_id, season_id, stage_id, league_name, driver, is_hdfs=IS_HDFS)
                if not stage_config:
                    print(f"WARNING: Failed to process metadata for stage {stage_id}. Skipping to next stage.")
                    continue

                stage_path = stage_config["stage_path"]
                stage_name = stage_config["stage_name"]

                match_configs, driver = get_match_configs(stage_config, driver, is_hdfs=IS_HDFS)
                
                matches_count = len(match_configs)
                fetched_count = 0 # Successfully fetched matches

                for match_id, start_time_string in match_configs:
                    status = get_match_data(match_id, start_time_string, stage_path, driver, is_hdfs=IS_HDFS)
                    if status == MatchStatus.FETCHED or status == MatchStatus.ALREADY_EXISTS:
                        fetched_count += 1
                    elif status == MatchStatus.FUTURE_MATCH:
                        matches_count -= 1
                    elif status == MatchStatus.FAILED:
                        initial_failures.append([match_id, start_time_string, stage_path])
                
                print(f"Successfully fetched {fetched_count} out of {matches_count} matches for stage {stage_name} with id {stage_id}")

            # Reset driver after every season
            driver = reset_driver(driver)

    # Retry loop for failed matches
    final_failures = []
    if initial_failures:
        print("\n" + "="*50)
        print(f"RETRYING {len(initial_failures)} FAILED MATCHES...")
        print("="*50)
        
        for match_id, start_time_string, stage_path in initial_failures:
            status = get_match_data(match_id, start_time_string, stage_path, driver)
            
            if status == MatchStatus.FAILED:
                print(f"  -> RETRY FAILED: Match {match_id} still failing.")
                final_failures.append((match_id, start_time_string, stage_path))
            else:
                print(f"  -> RETRY SUCCESS: Match {match_id} scraped successfully.")

    # Report
    print("\n" + "="*50)
    print("CRAWL COMPLETE.")
    if final_failures:
        print(f"The following {len(final_failures)} matches could not be scraped after all retries:")
        for match_info in final_failures:
            print(f"  - Match ID: {match_info[0]}")
    else:
        print("All matches were scraped successfully (or were already present).")
    print("="*50)

finally:
    # Make sure the final driver is always closed, even if there's an error
    if driver:
        print("INFO: Closing final browser session.")
        driver.quit()
# Out:
# ==================================================
# STARTING LEAGUE: international-european-championship
# INFO: Starting a new browser session...
# Season_ids of international-european-championship: ['9299', '7329', '4246', '3164']
#
# --------------------
# INFO: Starting new session for Season ID: 9299
# Start writing stage data for stage 21415
# SUCCESS: Wrote data for stage 21415 to local bronze/stage_data/league=international-european-championship/season=2024/stage_id=21415/stage_info.json
# Start getting match_configs for stage 21415
# Found 15 matches for stage 21415
# Successfully fetched 15 out of 15 matches for stage EURO Final Stage with id 21415
# Start writing stage data for stage 23157
# SUCCESS: Wrote data for stage 23157 to local bronze/stage_data/league=international-european-championship/season=2024/stage_id=23157/stage_info.json
# Start getting match_configs for stage 23157
# Found 0 matches for stage 23157
# Successfully fetched 0 out of 0 matches for stage EURO Grp. D with id 23157
# Start writing stage data for stage 21399
# SUCCESS: Wrote data for stage 21399 to local bronze/stage_data/league=international-european-championship/season=2024/stage_id=21399/stage_info.json
# Start getting match_configs for stage 21399
# Found 6 matches for stage 21399
# Successfully fetched 6 out of 6 matches for stage EURO Grp. A with id 21399
# Start writing stage data for stage 21400
# SUCCESS: Wrote data for stage 21400 to local bronze/stage_data/league=international-european-championship/season=2024/stage_id=21400/stage_info.json
# Start getting match_configs for stage 21400
# Found 6 matches for stage 21400
# Successfully fetched 6 out of 6 matches for stage EURO Grp. B with id 21400
# Start writing stage data for stage 21403
# SUCCESS: Wrote data for stage 21403 to local bronze/stage_data/league=international-european-championship/season=2024/stage_id=21403/stage_info.json
# Start getting match_configs for stage 21403
# Found 6 matches for stage 21403
# Successfully fetched 6 out of 6 matches for stage EURO Grp. C with id 21403
# Start writing stage data for stage 21401
# SUCCESS: Wrote data for stage 21401 to local bronze/stage_data/league=international-european-championship/season=2024/stage_id=21401/stage_info.json
# Start getting match_configs for stage 21401
# Found 6 matches for stage 21401
# Successfully fetched 6 out of 6 matches for stage EURO Grp. D with id 21401
# Start writing stage data for stage 21402
# Start getting match_configs for stage 8988
# Found 6 matches for stage 8988
# Successfully fetched 6 out of 6 matches for stage EURO Grp. B with id 8988
# Start writing stage data for stage 8989
# SUCCESS: Wrote data for stage 8989 to local bronze/stage_data/league=international-european-championship/season=2016/stage_id=8989/stage_info.json
# Start getting match_configs for stage 8989
# Found 6 matches for stage 8989
# Successfully fetched 6 out of 6 matches for stage EURO Grp. C with id 8989
# Start writing stage data for stage 8990
# SUCCESS: Wrote data for stage 8990 to local bronze/stage_data/league=international-european-championship/season=2016/stage_id=8990/stage_info.json
# Start getting match_configs for stage 8990
# Found 6 matches for stage 8990
# Successfully fetched 6 out of 6 matches for stage EURO Grp. D with id 8990
# Start writing stage data for stage 8991
# SUCCESS: Wrote data for stage 8991 to local bronze/stage_data/league=international-european-championship/season=2016/stage_id=8991/stage_info.json
# Start getting match_configs for stage 8991
# Found 6 matches for stage 8991
# Successfully fetched 6 out of 6 matches for stage EURO Grp. E with id 8991
# Start writing stage data for stage 8992
# SUCCESS: Wrote data for stage 8992 to local bronze/stage_data/league=international-european-championship/season=2016/stage_id=8992/stage_info.json
# Start getting match_configs for stage 8992
# Found 6 matches for stage 8992
# Successfully fetched 6 out of 6 matches for stage EURO Grp. F with id 8992
# Start writing stage data for stage 8994
# SUCCESS: Wrote data for stage 8994 to local bronze/stage_data/league=international-european-championship/season=2016/stage_id=8994/stage_info.json
# Start getting match_configs for stage 8994
# Found 8 matches for stage 8994
# Successfully fetched 8 out of 8 matches for stage EURO 1/8 Finals with id 8994
# Start writing stage data for stage 8993
# SUCCESS: Wrote data for stage 8993 to local bronze/stage_data/league=international-european-championship/season=2016/stage_id=8993/stage_info.json
# Start getting match_configs for stage 8993
# Found 4 matches for stage 8993
# Successfully fetched 4 out of 4 matches for stage EURO Quarter Finals with id 8993
# Start writing stage data for stage 8995
# SUCCESS: Wrote data for stage 8995 to local bronze/stage_data/league=international-european-championship/season=2016/stage_id=8995/stage_info.json
# Start getting match_configs for stage 8995
# Found 2 matches for stage 8995
# Successfully fetched 2 out of 2 matches for stage EURO Semi Finals with id 8995
# Start writing stage data for stage 8996
# SUCCESS: Wrote data for stage 8996 to local bronze/stage_data/league=international-european-championship/season=2016/stage_id=8996/stage_info.json
# Start getting match_configs for stage 8996
# Found 1 matches for stage 8996
# Successfully fetched 1 out of 1 matches for stage EURO Final with id 8996
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 3164
# Start writing stage data for stage 5980
# SUCCESS: Wrote data for stage 5980 to local bronze/stage_data/league=international-european-championship/season=2012/stage_id=5980/stage_info.json
# Start getting match_configs for stage 5980
# Found 6 matches for stage 5980
# Successfully fetched 6 out of 6 matches for stage EURO Grp. A with id 5980
# Start writing stage data for stage 5981
# SUCCESS: Wrote data for stage 5981 to local bronze/stage_data/league=international-european-championship/season=2012/stage_id=5981/stage_info.json
# Start getting match_configs for stage 5981
# Found 6 matches for stage 5981
# Successfully fetched 6 out of 6 matches for stage EURO Grp. B with id 5981
# Start writing stage data for stage 5982
# SUCCESS: Wrote data for stage 5982 to local bronze/stage_data/league=international-european-championship/season=2012/stage_id=5982/stage_info.json
# Start getting match_configs for stage 5982
# Found 6 matches for stage 5982
# Successfully fetched 6 out of 6 matches for stage EURO Grp. C with id 5982
# Start writing stage data for stage 5983
# SUCCESS: Wrote data for stage 5983 to local bronze/stage_data/league=international-european-championship/season=2012/stage_id=5983/stage_info.json
# Start getting match_configs for stage 5983
# Found 6 matches for stage 5983
# Successfully fetched 6 out of 6 matches for stage EURO Grp. D with id 5983
# Start writing stage data for stage 5975
# SUCCESS: Wrote data for stage 5975 to local bronze/stage_data/league=international-european-championship/season=2012/stage_id=5975/stage_info.json
# Start getting match_configs for stage 5975
# Found 4 matches for stage 5975
# Successfully fetched 4 out of 4 matches for stage EURO Quarter finals with id 5975
# Start writing stage data for stage 5976
# SUCCESS: Wrote data for stage 5976 to local bronze/stage_data/league=international-european-championship/season=2012/stage_id=5976/stage_info.json
# Start getting match_configs for stage 5976
# Found 2 matches for stage 5976
# Successfully fetched 2 out of 2 matches for stage EURO Semi finals with id 5976
# Start writing stage data for stage 5978
# SUCCESS: Wrote data for stage 5978 to local bronze/stage_data/league=international-european-championship/season=2012/stage_id=5978/stage_info.json
# Start getting match_configs for stage 5978
# Found 1 matches for stage 5978
# Successfully fetched 1 out of 1 matches for stage EURO Final with id 5978
# INFO: Starting a new browser session...
#
# ==================================================
# CRAWL COMPLETE.
# All matches were scraped successfully (or were already present).
# ==================================================
# INFO: Closing final browser session.

# %%
from datetime import datetime, timezone

def write_crawl_time(is_hdfs: bool):
    crawl_time = datetime.now(timezone.utc) - timedelta(days=20)
    crawl_time_str = datetime.strftime(crawl_time, "%Y-%m-%dT%H:%M:%SZ")

    file_path = "bronze/last_crawl_timestamp.txt"
    
    try:
        if is_hdfs:
            hdfs_path = os.path.join(HDFS_PATH, file_path)
            parent = os.path.dirname(hdfs_path)
            client.makedirs(parent)

            # always overwrite
            with client.write(hdfs_path, encoding="utf-8", overwrite=True) as f:
                f.write(crawl_time_str)

            print(f"SUCCESS: Wrote crawl timestamp to HDFS: {hdfs_path}")

        else:
            os.makedirs(os.path.dirname(file_path), exist_ok=True)

            # always overwrite
            with open(file_path, "w", encoding="utf-8") as f:
                f.write(crawl_time_str)

            print(f"SUCCESS: Wrote crawl timestamp to local FS: {file_path}")

    except Exception as e:
        print(f"FATAL ERROR: Could not write crawl timestamp. Details: {e}")

# %%
IS_HDFS = True
write_crawl_time(is_hdfs=IS_HDFS)
# Out:
# SUCCESS: Wrote crawl timestamp to HDFS: /user/dottier/bronze/last_crawl_timestamp.txt

# %%
league_mapping = {
    (81, 3, 2015): "germany-bundesliga",
    (252, 2, 2015): "england-premier-league",
    (108, 5, 2015): "italy-serie-a",
    (74, 22, 2015): "france-ligue-1",
    (206, 4, 2015): "spain-laliga",

    (250, 12, 2015): "europe-champions-league",
    (250, 30, 2015): "europe-europa-league",

    (247, 36, 2014): "international-fifa-world-cup",
    (247, 67, 2025): "international-fifa-club-world-cup",
    (247, 124, 2012): "international-european-championship",
    
    (250, 751, 2022): "europe-european-championship-qualification",
    (247, 721, 2021): "international-world-cup-qualification-uefa",
    (247, 683, 2018): "international-uefa-nations-league-a",
    (247, 684, 2018): "international-uefa-nations-league-b",
    (247, 685, 2018): "international-uefa-nations-league-c",
    (247, 686, 2018): "international-uefa-nations-league-d"
}

if driver:
    driver.quit()
    driver = None

# Storing failed matches to try 1 more time
initial_failures = []

try: 
    for (region_id, tournament_id, start_year_after), league_name in league_mapping.items():
        print("="*50)
        print(f"STARTING LEAGUE: {league_name}")
        
        print("INFO: Starting a new browser session...")
        if not driver:
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

        season_ids, driver = get_season_ids(region_id, tournament_id, start_year_after, driver)
        print(f"Season_ids of {league_name}:", season_ids)

        for season_id in season_ids:
            print("\n" + "-"*20)
            print(f"INFO: Starting new session for Season ID: {season_id}")

            stage_ids, driver = get_stage_ids(region_id, tournament_id, season_id, driver)
            if not stage_ids:
                print(f"WARNING: No stages found for season {season_id}. Skipping.")
                continue

            for stage_id in stage_ids:
                stage_config = process_season_stages(region_id, tournament_id, season_id, stage_id, league_name, driver, is_hdfs=IS_HDFS)
                if not stage_config:
                    print(f"WARNING: Failed to process metadata for stage {stage_id}. Skipping to next stage.")
                    continue

                stage_path = stage_config["stage_path"]
                stage_name = stage_config["stage_name"]

                match_configs, driver = get_match_configs(stage_config, driver, is_hdfs=IS_HDFS)
                
                matches_count = len(match_configs)
                fetched_count = 0 # Successfully fetched matches
                already_exists_count = 0
                future_count = 0
                failed_count = 0

                for match_id, start_time_string in match_configs:
                    status = get_match_data(match_id, start_time_string, stage_path, driver, is_hdfs=IS_HDFS)
                    if status == MatchStatus.FETCHED:
                        fetched_count += 1
                    elif status == MatchStatus.ALREADY_EXISTS:
                        already_exists_count += 1
                    elif status == MatchStatus.FUTURE_MATCH:
                        future_count += 1
                    elif status == MatchStatus.FAILED:
                        failed_count += 1
                        initial_failures.append([match_id, start_time_string, stage_path])
                
                print(f"""
                Stage '{stage_name}' (ID: {stage_id}) summary:
                Total matches considered : {matches_count}
                Successfully fetched      : {fetched_count}
                Already existed           : {already_exists_count}
                Scheduled for future      : {future_count}
                Failed to fetch           : {failed_count}
                """)

            # Reset driver after every season
            driver = reset_driver(driver)

    # Retry loop for failed matches
    final_failures = []
    if initial_failures:
        print("\n" + "="*50)
        print(f"RETRYING {len(initial_failures)} FAILED MATCHES...")
        print("="*50)
        
        for match_id, start_time_string, stage_path in initial_failures:
            status = get_match_data(match_id, start_time_string, stage_path, driver)
            
            if status == MatchStatus.FAILED:
                print(f"  -> RETRY FAILED: Match {match_id} still failing.")
                final_failures.append((match_id, start_time_string, stage_path))
            else:
                print(f"  -> RETRY SUCCESS: Match {match_id} scraped successfully.")

    # Report
    print("\n" + "="*50)
    print("CRAWL COMPLETE.")
    if final_failures:
        print(f"The following {len(final_failures)} matches could not be scraped after all retries:")
        for match_info in final_failures:
            print(f"  - Match ID: {match_info[0]}")
    else:
        print("All matches were scraped successfully (or were already present).")
    print("="*50)

finally:
    # Make sure the final driver is always closed, even if there's an error
    if driver:
        print("INFO: Closing final browser session.")
        driver.quit()
# Out:
# ==================================================
# STARTING LEAGUE: germany-bundesliga
# INFO: Starting a new browser session...
# WARNING: Could not find season dropdown for tournament 3. Retrying
# INFO: Starting a new browser session...
# Season_ids of germany-bundesliga: ['10720', '10365', '9649', '9120', '8667', '8279', '7872', '7405', '6902', '6392', '5870']
#
# --------------------
# INFO: Starting new session for Season ID: 10720
# Start writing stage data for stage 24478
# SUCCESS: Wrote data for stage 24478 to HDFS bronze/stage_data/league=germany-bundesliga/season=2025-2026/stage_id=24478/stage_info.json
# Start getting match_configs for stage 24478
# Found 306 matches for stage 24478
#
#                 Stage 'Bundesliga' (ID: 24478) summary:
#                 Total matches considered : 306
#                 Successfully fetched      : 0
#                 Already existed           : 18
#                 Scheduled for future      : 288
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 10365
# Start writing stage data for stage 23471
# SUCCESS: Wrote data for stage 23471 to HDFS bronze/stage_data/league=germany-bundesliga/season=2024-2025/stage_id=23471/stage_info.json
# Start getting match_configs for stage 23471
# Found 306 matches for stage 23471
#
#                 Stage 'Bundesliga' (ID: 23471) summary:
#                 Total matches considered : 306
#                 Successfully fetched      : 0
#                 Already existed           : 306
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 9649
# Start writing stage data for stage 22128
# SUCCESS: Wrote data for stage 22128 to HDFS bronze/stage_data/league=germany-bundesliga/season=2023-2024/stage_id=22128/stage_info.json
# Start getting match_configs for stage 22128
# Found 306 matches for stage 22128
#
#                 Stage 'Bundesliga' (ID: 22128) summary:
#                 Total matches considered : 306
#                 Successfully fetched      : 0
#                 Already existed           : 306
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 9120
# Start writing stage data for stage 21026
# SUCCESS: Wrote data for stage 21026 to HDFS bronze/stage_data/league=germany-bundesliga/season=2022-2023/stage_id=21026/stage_info.json
# Start getting match_configs for stage 21026
# Found 306 matches for stage 21026
#
#                 Stage 'Bundesliga' (ID: 21026) summary:
#                 Total matches considered : 306
#                 Successfully fetched      : 0
#                 Already existed           : 306
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8667
# Start writing stage data for stage 19862
# SUCCESS: Wrote data for stage 19862 to HDFS bronze/stage_data/league=germany-bundesliga/season=2021-2022/stage_id=19862/stage_info.json
# Start getting match_configs for stage 19862
# Found 306 matches for stage 19862
#
#                 Stage '1. Bundesliga' (ID: 19862) summary:
#                 Total matches considered : 306
#                 Successfully fetched      : 0
#                 Already existed           : 306
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8279
# Start writing stage data for stage 18762
# SUCCESS: Wrote data for stage 18762 to HDFS bronze/stage_data/league=germany-bundesliga/season=2020-2021/stage_id=18762/stage_info.json
# Start getting match_configs for stage 18762
# Found 306 matches for stage 18762
#
#                 Stage '1. Bundesliga' (ID: 18762) summary:
#                 Total matches considered : 306
#                 Successfully fetched      : 0
#                 Already existed           : 306
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7872
# Start writing stage data for stage 17682
# SUCCESS: Wrote data for stage 17682 to HDFS bronze/stage_data/league=germany-bundesliga/season=2019-2020/stage_id=17682/stage_info.json
# Start getting match_configs for stage 17682
# Found 306 matches for stage 17682
#
#                 Stage '1. Bundesliga' (ID: 17682) summary:
#                 Total matches considered : 306
#                 Successfully fetched      : 0
#                 Already existed           : 306
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7405
# Start writing stage data for stage 16427
# SUCCESS: Wrote data for stage 16427 to HDFS bronze/stage_data/league=germany-bundesliga/season=2018-2019/stage_id=16427/stage_info.json
# Start getting match_configs for stage 16427
# Found 306 matches for stage 16427
#
#                 Stage '1. Bundesliga' (ID: 16427) summary:
#                 Total matches considered : 306
#                 Successfully fetched      : 0
#                 Already existed           : 306
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 6902
# Start writing stage data for stage 15243
# SUCCESS: Wrote data for stage 15243 to HDFS bronze/stage_data/league=germany-bundesliga/season=2017-2018/stage_id=15243/stage_info.json
# Start getting match_configs for stage 15243
# Found 306 matches for stage 15243
#
#                 Stage '1. Bundesliga' (ID: 15243) summary:
#                 Total matches considered : 306
#                 Successfully fetched      : 0
#                 Already existed           : 306
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 6392
# Start writing stage data for stage 13872
# SUCCESS: Wrote data for stage 13872 to HDFS bronze/stage_data/league=germany-bundesliga/season=2016-2017/stage_id=13872/stage_info.json
# Start getting match_configs for stage 13872
# Found 306 matches for stage 13872
#
#                 Stage '1. Bundesliga' (ID: 13872) summary:
#                 Total matches considered : 306
#                 Successfully fetched      : 0
#                 Already existed           : 306
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 5870
# Start writing stage data for stage 12559
# SUCCESS: Wrote data for stage 12559 to HDFS bronze/stage_data/league=germany-bundesliga/season=2015-2016/stage_id=12559/stage_info.json
# Start getting match_configs for stage 12559
# Found 306 matches for stage 12559
#
#                 Stage '1. Bundesliga' (ID: 12559) summary:
#                 Total matches considered : 306
#                 Successfully fetched      : 0
#                 Already existed           : 306
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
# ==================================================
# STARTING LEAGUE: england-premier-league
# INFO: Starting a new browser session...
# Season_ids of england-premier-league: ['10743', '10316', '9618', '9075', '8618', '8228', '7811', '7361', '6829', '6335', '5826']
#
# --------------------
# INFO: Starting new session for Season ID: 10743
# Start writing stage data for stage 24533
# SUCCESS: Wrote data for stage 24533 to HDFS bronze/stage_data/league=england-premier-league/season=2025-2026/stage_id=24533/stage_info.json
# Start getting match_configs for stage 24533
# Found 380 matches for stage 24533
# SUCCESS: Wrote data for match 1903138
# SUCCESS: Wrote data for match 1903139
# SUCCESS: Wrote data for match 1903145
# SUCCESS: Wrote data for match 1903137
#
#                 Stage 'Premier League' (ID: 24533) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 4
#                 Already existed           : 26
#                 Scheduled for future      : 350
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 10316
# Start writing stage data for stage 23400
# SUCCESS: Wrote data for stage 23400 to HDFS bronze/stage_data/league=england-premier-league/season=2024-2025/stage_id=23400/stage_info.json
# Start getting match_configs for stage 23400
# Found 380 matches for stage 23400
#
#                 Stage 'Premier League' (ID: 23400) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 9618
# Start writing stage data for stage 22076
# SUCCESS: Wrote data for stage 22076 to HDFS bronze/stage_data/league=england-premier-league/season=2023-2024/stage_id=22076/stage_info.json
# Start getting match_configs for stage 22076
# Found 380 matches for stage 22076
#
#                 Stage 'Premier League' (ID: 22076) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 9075
# Start writing stage data for stage 20934
# SUCCESS: Wrote data for stage 20934 to HDFS bronze/stage_data/league=england-premier-league/season=2022-2023/stage_id=20934/stage_info.json
# Start getting match_configs for stage 20934
# Found 380 matches for stage 20934
#
#                 Stage 'Premier League' (ID: 20934) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8618
# Start writing stage data for stage 19793
# SUCCESS: Wrote data for stage 19793 to HDFS bronze/stage_data/league=england-premier-league/season=2021-2022/stage_id=19793/stage_info.json
# Start getting match_configs for stage 19793
# Found 380 matches for stage 19793
#
#                 Stage 'Premier League' (ID: 19793) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8228
# Start writing stage data for stage 18685
# SUCCESS: Wrote data for stage 18685 to HDFS bronze/stage_data/league=england-premier-league/season=2020-2021/stage_id=18685/stage_info.json
# Start getting match_configs for stage 18685
# Found 380 matches for stage 18685
#
#                 Stage 'Premier League' (ID: 18685) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7811
# Start writing stage data for stage 17590
# SUCCESS: Wrote data for stage 17590 to HDFS bronze/stage_data/league=england-premier-league/season=2019-2020/stage_id=17590/stage_info.json
# Start getting match_configs for stage 17590
# Found 380 matches for stage 17590
#
#                 Stage 'Premier League' (ID: 17590) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7361
# Start writing stage data for stage 16368
# SUCCESS: Wrote data for stage 16368 to HDFS bronze/stage_data/league=england-premier-league/season=2018-2019/stage_id=16368/stage_info.json
# Start getting match_configs for stage 16368
# Found 380 matches for stage 16368
#
#                 Stage 'Premier League' (ID: 16368) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 6829
# Start writing stage data for stage 15151
# SUCCESS: Wrote data for stage 15151 to HDFS bronze/stage_data/league=england-premier-league/season=2017-2018/stage_id=15151/stage_info.json
# Start getting match_configs for stage 15151
# Found 380 matches for stage 15151
#
#                 Stage 'Premier League' (ID: 15151) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 6335
# Start writing stage data for stage 13796
# SUCCESS: Wrote data for stage 13796 to HDFS bronze/stage_data/league=england-premier-league/season=2016-2017/stage_id=13796/stage_info.json
# Start getting match_configs for stage 13796
# Found 380 matches for stage 13796
#
#                 Stage 'Premier League' (ID: 13796) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 5826
# Start writing stage data for stage 12496
# SUCCESS: Wrote data for stage 12496 to HDFS bronze/stage_data/league=england-premier-league/season=2015-2016/stage_id=12496/stage_info.json
# Start getting match_configs for stage 12496
# Found 380 matches for stage 12496
#
#                 Stage 'Premier League' (ID: 12496) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
# ==================================================
# STARTING LEAGUE: italy-serie-a
# INFO: Starting a new browser session...
# Season_ids of italy-serie-a: ['10732', '10375', '9659', '9159', '8735', '8330', '7928', '7468', '6974', '6461', '5970']
#
# --------------------
# INFO: Starting new session for Season ID: 10732
# Start writing stage data for stage 24500
# SUCCESS: Wrote data for stage 24500 to HDFS bronze/stage_data/league=italy-serie-a/season=2025-2026/stage_id=24500/stage_info.json
# Start getting match_configs for stage 24500
# Found 380 matches for stage 24500
# SUCCESS: Wrote data for match 1901073
# SUCCESS: Wrote data for match 1901080
# SUCCESS: Wrote data for match 1901074
# SUCCESS: Wrote data for match 1901075
#
#                 Stage 'Serie A' (ID: 24500) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 4
#                 Already existed           : 16
#                 Scheduled for future      : 360
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 10375
# Start writing stage data for stage 23490
# SUCCESS: Wrote data for stage 23490 to HDFS bronze/stage_data/league=italy-serie-a/season=2024-2025/stage_id=23490/stage_info.json
# Start getting match_configs for stage 23490
# Found 380 matches for stage 23490
#
#                 Stage 'Serie A' (ID: 23490) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 9659
# Start writing stage data for stage 22143
# SUCCESS: Wrote data for stage 22143 to HDFS bronze/stage_data/league=italy-serie-a/season=2023-2024/stage_id=22143/stage_info.json
# Start getting match_configs for stage 22143
# Found 380 matches for stage 22143
#
#                 Stage 'Serie A' (ID: 22143) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 9159
# Start writing stage data for stage 21087
# SUCCESS: Wrote data for stage 21087 to HDFS bronze/stage_data/league=italy-serie-a/season=2022-2023/stage_id=21087/stage_info.json
# Start getting match_configs for stage 21087
# Found 380 matches for stage 21087
#
#                 Stage 'Serie A' (ID: 21087) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 22100
# SUCCESS: Wrote data for stage 22100 to HDFS bronze/stage_data/league=italy-serie-a/season=2022-2023/stage_id=22100/stage_info.json
# Start getting match_configs for stage 22100
# Found 1 matches for stage 22100
#
#                 Stage 'Serie A Relegation Playoff' (ID: 22100) summary:
#                 Total matches considered : 1
#                 Successfully fetched      : 0
#                 Already existed           : 1
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8735
# Start writing stage data for stage 19982
# SUCCESS: Wrote data for stage 19982 to HDFS bronze/stage_data/league=italy-serie-a/season=2021-2022/stage_id=19982/stage_info.json
# Start getting match_configs for stage 19982
# Found 380 matches for stage 19982
#
#                 Stage 'Serie A' (ID: 19982) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8330
# Start writing stage data for stage 18873
# SUCCESS: Wrote data for stage 18873 to HDFS bronze/stage_data/league=italy-serie-a/season=2020-2021/stage_id=18873/stage_info.json
# Start getting match_configs for stage 18873
# Found 380 matches for stage 18873
#
#                 Stage 'Serie A' (ID: 18873) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7928
# Start writing stage data for stage 17835
# SUCCESS: Wrote data for stage 17835 to HDFS bronze/stage_data/league=italy-serie-a/season=2019-2020/stage_id=17835/stage_info.json
# Start getting match_configs for stage 17835
# Found 380 matches for stage 17835
#
#                 Stage 'Serie A' (ID: 17835) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7468
# Start writing stage data for stage 16548
# SUCCESS: Wrote data for stage 16548 to HDFS bronze/stage_data/league=italy-serie-a/season=2018-2019/stage_id=16548/stage_info.json
# Start getting match_configs for stage 16548
# Found 380 matches for stage 16548
#
#                 Stage 'Serie A' (ID: 16548) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 6974
# Start writing stage data for stage 15404
# SUCCESS: Wrote data for stage 15404 to HDFS bronze/stage_data/league=italy-serie-a/season=2017-2018/stage_id=15404/stage_info.json
# Start getting match_configs for stage 15404
# Found 380 matches for stage 15404
#
#                 Stage 'Serie A' (ID: 15404) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 6461
# Start writing stage data for stage 14014
# SUCCESS: Wrote data for stage 14014 to HDFS bronze/stage_data/league=italy-serie-a/season=2016-2017/stage_id=14014/stage_info.json
# Start getting match_configs for stage 14014
# Found 380 matches for stage 14014
#
#                 Stage 'Serie A' (ID: 14014) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 5970
# Start writing stage data for stage 12770
# SUCCESS: Wrote data for stage 12770 to HDFS bronze/stage_data/league=italy-serie-a/season=2015-2016/stage_id=12770/stage_info.json
# Start getting match_configs for stage 12770
# Found 380 matches for stage 12770
#
#                 Stage 'Serie A' (ID: 12770) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
# ==================================================
# STARTING LEAGUE: france-ligue-1
# INFO: Starting a new browser session...
# Season_ids of france-ligue-1: ['10792', '10329', '9635', '9129', '8671', '8185', '7814', '7344', '6833', '6318', '5830']
#
# --------------------
# INFO: Starting new session for Season ID: 10792
# Start writing stage data for stage 24609
# SUCCESS: Wrote data for stage 24609 to HDFS bronze/stage_data/league=france-ligue-1/season=2025-2026/stage_id=24609/stage_info.json
# Start getting match_configs for stage 24609
# Found 306 matches for stage 24609
# SUCCESS: Wrote data for match 1911289
# SUCCESS: Wrote data for match 1911292
# SUCCESS: Wrote data for match 1911318
# SUCCESS: Wrote data for match 1911324
# SUCCESS: Wrote data for match 1911315
#
#                 Stage 'Ligue 1' (ID: 24609) summary:
#                 Total matches considered : 306
#                 Successfully fetched      : 5
#                 Already existed           : 22
#                 Scheduled for future      : 279
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 10329
# Start writing stage data for stage 23414
# SUCCESS: Wrote data for stage 23414 to HDFS bronze/stage_data/league=france-ligue-1/season=2024-2025/stage_id=23414/stage_info.json
# Start getting match_configs for stage 23414
# Found 306 matches for stage 23414
#
#                 Stage 'Ligue 1' (ID: 23414) summary:
#                 Total matches considered : 306
#                 Successfully fetched      : 0
#                 Already existed           : 306
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 9635
# Start writing stage data for stage 22105
# SUCCESS: Wrote data for stage 22105 to HDFS bronze/stage_data/league=france-ligue-1/season=2023-2024/stage_id=22105/stage_info.json
# Start getting match_configs for stage 22105
# Found 306 matches for stage 22105
#
#                 Stage 'Ligue 1' (ID: 22105) summary:
#                 Total matches considered : 306
#                 Successfully fetched      : 0
#                 Already existed           : 306
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 9129
# Start writing stage data for stage 21037
# SUCCESS: Wrote data for stage 21037 to HDFS bronze/stage_data/league=france-ligue-1/season=2022-2023/stage_id=21037/stage_info.json
# Start getting match_configs for stage 21037
# Found 380 matches for stage 21037
#
#                 Stage 'Ligue 1' (ID: 21037) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8671
# Start writing stage data for stage 19866
# SUCCESS: Wrote data for stage 19866 to HDFS bronze/stage_data/league=france-ligue-1/season=2021-2022/stage_id=19866/stage_info.json
# Start getting match_configs for stage 19866
# Found 380 matches for stage 19866
#
#                 Stage 'Ligue 1' (ID: 19866) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8185
# Start writing stage data for stage 18594
# SUCCESS: Wrote data for stage 18594 to HDFS bronze/stage_data/league=france-ligue-1/season=2020-2021/stage_id=18594/stage_info.json
# Start getting match_configs for stage 18594
# Found 380 matches for stage 18594
#
#                 Stage 'Ligue 1' (ID: 18594) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7814
# Start writing stage data for stage 17593
# SUCCESS: Wrote data for stage 17593 to HDFS bronze/stage_data/league=france-ligue-1/season=2019-2020/stage_id=17593/stage_info.json
# Start getting match_configs for stage 17593
# Found 380 matches for stage 17593
#
#                 Stage 'Ligue 1' (ID: 17593) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7344
# Start writing stage data for stage 16348
# SUCCESS: Wrote data for stage 16348 to HDFS bronze/stage_data/league=france-ligue-1/season=2018-2019/stage_id=16348/stage_info.json
# Start getting match_configs for stage 16348
# Found 380 matches for stage 16348
#
#                 Stage 'Ligue 1' (ID: 16348) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 6833
# Start writing stage data for stage 15155
# SUCCESS: Wrote data for stage 15155 to HDFS bronze/stage_data/league=france-ligue-1/season=2017-2018/stage_id=15155/stage_info.json
# Start getting match_configs for stage 15155
# Found 380 matches for stage 15155
#
#                 Stage 'Ligue 1' (ID: 15155) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 6318
# WARNING: No stages found, retrying... (attempt 1)
# INFO: Starting a new browser session...
# Start writing stage data for stage 13768
# SUCCESS: Wrote data for stage 13768 to HDFS bronze/stage_data/league=france-ligue-1/season=2016-2017/stage_id=13768/stage_info.json
# Start getting match_configs for stage 13768
# Found 381 matches for stage 13768
# WARNING: Could not find a script containing all required data for match 1076372 on page https://www.whoscored.com/matches/1076372/live
#
#                 Stage 'Ligue 1' (ID: 13768) summary:
#                 Total matches considered : 381
#                 Successfully fetched      : 0
#                 Already existed           : 380
#                 Scheduled for future      : 0
#                 Failed to fetch           : 1
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 5830
# Start writing stage data for stage 12501
# SUCCESS: Wrote data for stage 12501 to HDFS bronze/stage_data/league=france-ligue-1/season=2015-2016/stage_id=12501/stage_info.json
# Start getting match_configs for stage 12501
# Found 381 matches for stage 12501
#
#                 Stage 'Ligue 1' (ID: 12501) summary:
#                 Total matches considered : 381
#                 Successfully fetched      : 0
#                 Already existed           : 381
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
# ==================================================
# STARTING LEAGUE: spain-laliga
# INFO: Starting a new browser session...
# Season_ids of spain-laliga: ['10803', '10317', '9682', '9149', '8681', '8321', '7889', '7466', '6960', '6436', '5933']
#
# --------------------
# INFO: Starting new session for Season ID: 10803
# Start writing stage data for stage 24622
# SUCCESS: Wrote data for stage 24622 to HDFS bronze/stage_data/league=spain-laliga/season=2025-2026/stage_id=24622/stage_info.json
# Start getting match_configs for stage 24622
# Found 380 matches for stage 24622
# SUCCESS: Wrote data for match 1913884
# SUCCESS: Wrote data for match 1913899
# SUCCESS: Wrote data for match 1913896
# SUCCESS: Wrote data for match 1913920
# SUCCESS: Wrote data for match 1913887
# SUCCESS: Wrote data for match 1913902
# SUCCESS: Wrote data for match 1913893
# SUCCESS: Wrote data for match 1913904
#
#                 Stage 'LaLiga' (ID: 24622) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 8
#                 Already existed           : 23
#                 Scheduled for future      : 349
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 10317
# Start writing stage data for stage 23401
# SUCCESS: Wrote data for stage 23401 to HDFS bronze/stage_data/league=spain-laliga/season=2024-2025/stage_id=23401/stage_info.json
# Start getting match_configs for stage 23401
# Found 380 matches for stage 23401
# SUCCESS: Wrote data for match 1821735
#
#                 Stage 'LaLiga' (ID: 23401) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 1
#                 Already existed           : 379
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 9682
# Start writing stage data for stage 22176
# SUCCESS: Wrote data for stage 22176 to HDFS bronze/stage_data/league=spain-laliga/season=2023-2024/stage_id=22176/stage_info.json
# Start getting match_configs for stage 22176
# Found 380 matches for stage 22176
# SUCCESS: Wrote data for match 1734738
#
#                 Stage 'LaLiga' (ID: 22176) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 1
#                 Already existed           : 379
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 9149
# Start writing stage data for stage 21073
# SUCCESS: Wrote data for stage 21073 to HDFS bronze/stage_data/league=spain-laliga/season=2022-2023/stage_id=21073/stage_info.json
# Start getting match_configs for stage 21073
# Found 380 matches for stage 21073
# SUCCESS: Wrote data for match 1650856
#
#                 Stage 'LaLiga' (ID: 21073) summary:
#                 Total matches considered : 380
#                 Successfully fetched      : 1
#                 Already existed           : 379
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8681
# Start writing stage data for stage 19895
# SUCCESS: Wrote data for stage 19895 to HDFS bronze/stage_data/league=spain-laliga/season=2021-2022/stage_id=19895/stage_info.json
# Start getting match_configs for stage 19895
# Found 4 matches for stage 19111
# SUCCESS: Wrote data for match 1514114
# SUCCESS: Wrote data for match 1514115
# SUCCESS: Wrote data for match 1514112
# SUCCESS: Wrote data for match 1514113
#
#                 Stage 'UEFA Nations League C Relegation Playoff' (ID: 19111) summary:
#                 Total matches considered : 4
#                 Successfully fetched      : 4
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7215
# Start writing stage data for stage 15947
# SUCCESS: Wrote data for stage 15947 to HDFS bronze/stage_data/league=international-uefa-nations-league-c/season=2018-2019/stage_id=15947/stage_info.json
# Start getting match_configs for stage 15947
# Found 6 matches for stage 15947
# SUCCESS: Wrote data for match 1266301
# SUCCESS: Wrote data for match 1266302
# SUCCESS: Wrote data for match 1266303
# SUCCESS: Wrote data for match 1266304
# SUCCESS: Wrote data for match 1266305
# SUCCESS: Wrote data for match 1266306
#
#                 Stage 'UEFA Nations League C Grp. 1' (ID: 15947) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 6
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 15948
# SUCCESS: Wrote data for stage 15948 to HDFS bronze/stage_data/league=international-uefa-nations-league-c/season=2018-2019/stage_id=15948/stage_info.json
# Start getting match_configs for stage 15948
# Found 12 matches for stage 15948
# SUCCESS: Wrote data for match 1266319
# SUCCESS: Wrote data for match 1266320
# SUCCESS: Wrote data for match 1266321
# SUCCESS: Wrote data for match 1266322
# SUCCESS: Wrote data for match 1266323
# SUCCESS: Wrote data for match 1266324
# SUCCESS: Wrote data for match 1266325
# SUCCESS: Wrote data for match 1266326
# SUCCESS: Wrote data for match 1266327
# SUCCESS: Wrote data for match 1266328
# SUCCESS: Wrote data for match 1266329
# SUCCESS: Wrote data for match 1266330
#
#                 Stage 'UEFA Nations League C Grp. 2' (ID: 15948) summary:
#                 Total matches considered : 12
#                 Successfully fetched      : 12
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 15949
# SUCCESS: Wrote data for stage 15949 to HDFS bronze/stage_data/league=international-uefa-nations-league-c/season=2018-2019/stage_id=15949/stage_info.json
# Start getting match_configs for stage 15949
# Found 12 matches for stage 15949
# SUCCESS: Wrote data for match 1266343
# SUCCESS: Wrote data for match 1266344
# SUCCESS: Wrote data for match 1266345
# SUCCESS: Wrote data for match 1266346
# SUCCESS: Wrote data for match 1266347
# SUCCESS: Wrote data for match 1266348
# SUCCESS: Wrote data for match 1266349
# SUCCESS: Wrote data for match 1266350
# SUCCESS: Wrote data for match 1266351
# SUCCESS: Wrote data for match 1266352
# SUCCESS: Wrote data for match 1266353
# SUCCESS: Wrote data for match 1266354
#
#                 Stage 'UEFA Nations League C Grp. 3' (ID: 15949) summary:
#                 Total matches considered : 12
#                 Successfully fetched      : 12
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 15950
# SUCCESS: Wrote data for stage 15950 to HDFS bronze/stage_data/league=international-uefa-nations-league-c/season=2018-2019/stage_id=15950/stage_info.json
# Start getting match_configs for stage 15950
# Found 12 matches for stage 15950
# SUCCESS: Wrote data for match 1266355
# SUCCESS: Wrote data for match 1266356
# SUCCESS: Wrote data for match 1266357
# SUCCESS: Wrote data for match 1266358
# SUCCESS: Wrote data for match 1266359
# SUCCESS: Wrote data for match 1266360
# SUCCESS: Wrote data for match 1266361
# SUCCESS: Wrote data for match 1266362
# SUCCESS: Wrote data for match 1266363
# SUCCESS: Wrote data for match 1266364
# SUCCESS: Wrote data for match 1266365
# SUCCESS: Wrote data for match 1266366
#
#                 Stage 'UEFA Nations League C Grp. 4' (ID: 15950) summary:
#                 Total matches considered : 12
#                 Successfully fetched      : 12
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
# ==================================================
# STARTING LEAGUE: international-uefa-nations-league-d
# INFO: Starting a new browser session...
# Season_ids of international-uefa-nations-league-d: ['9983', '8871', '8157', '7216']
#
# --------------------
# INFO: Starting new session for Season ID: 9983
# Start writing stage data for stage 22917
# SUCCESS: Wrote data for stage 22917 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2024-2025/stage_id=22917/stage_info.json
# Start getting match_configs for stage 22917
# Found 6 matches for stage 22917
# SUCCESS: Wrote data for match 1803719
# SUCCESS: Wrote data for match 1812414
# SUCCESS: Wrote data for match 1812415
# SUCCESS: Wrote data for match 1812416
# SUCCESS: Wrote data for match 1812417
# SUCCESS: Wrote data for match 1803720
#
#                 Stage 'UEFA Nations League D Grp. 1' (ID: 22917) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 6
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 22918
# SUCCESS: Wrote data for stage 22918 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2024-2025/stage_id=22918/stage_info.json
# Start getting match_configs for stage 22918
# Found 6 matches for stage 22918
# SUCCESS: Wrote data for match 1803751
# SUCCESS: Wrote data for match 1803752
# SUCCESS: Wrote data for match 1803753
# SUCCESS: Wrote data for match 1803754
# SUCCESS: Wrote data for match 1803755
# SUCCESS: Wrote data for match 1803756
#
#                 Stage 'UEFA Nations League D Grp. 2' (ID: 22918) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 6
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8871
# Start writing stage data for stage 20394
# SUCCESS: Wrote data for stage 20394 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2022-2023/stage_id=20394/stage_info.json
# Start getting match_configs for stage 20394
# Found 12 matches for stage 20394
# SUCCESS: Wrote data for match 1605381
# SUCCESS: Wrote data for match 1631903
# SUCCESS: Wrote data for match 1605382
# SUCCESS: Wrote data for match 1631904
# SUCCESS: Wrote data for match 1631905
# SUCCESS: Wrote data for match 1605383
# SUCCESS: Wrote data for match 1631906
# SUCCESS: Wrote data for match 1605384
# SUCCESS: Wrote data for match 1631907
# SUCCESS: Wrote data for match 1605385
# SUCCESS: Wrote data for match 1605386
# SUCCESS: Wrote data for match 1631908
#
#                 Stage 'UEFA Nations League D Grp. 1' (ID: 20394) summary:
#                 Total matches considered : 12
#                 Successfully fetched      : 12
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 20396
# SUCCESS: Wrote data for stage 20396 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2022-2023/stage_id=20396/stage_info.json
# Start getting match_configs for stage 20396
# Found 6 matches for stage 20396
# SUCCESS: Wrote data for match 1631921
# SUCCESS: Wrote data for match 1605399
# SUCCESS: Wrote data for match 1631922
# SUCCESS: Wrote data for match 1605400
# SUCCESS: Wrote data for match 1631923
# SUCCESS: Wrote data for match 1631924
#
#                 Stage 'UEFA Nations League D Grp. 2' (ID: 20396) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 6
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8157
# Start writing stage data for stage 18470
# SUCCESS: Wrote data for stage 18470 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2020-2021/stage_id=18470/stage_info.json
# Start getting match_configs for stage 18470
# Found 12 matches for stage 18470
# SUCCESS: Wrote data for match 1457075
# SUCCESS: Wrote data for match 1457074
# SUCCESS: Wrote data for match 1457076
# SUCCESS: Wrote data for match 1457077
# SUCCESS: Wrote data for match 1457079
# SUCCESS: Wrote data for match 1457078
# SUCCESS: Wrote data for match 1457081
# SUCCESS: Wrote data for match 1457080
# SUCCESS: Wrote data for match 1457082
# SUCCESS: Wrote data for match 1457083
# SUCCESS: Wrote data for match 1457084
# SUCCESS: Wrote data for match 1457085
#
#                 Stage 'UEFA Nations League D Grp. 1' (ID: 18470) summary:
#                 Total matches considered : 12
#                 Successfully fetched      : 12
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 18471
# SUCCESS: Wrote data for stage 18471 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2020-2021/stage_id=18471/stage_info.json
# Start getting match_configs for stage 18471
# Found 6 matches for stage 18471
# SUCCESS: Wrote data for match 1457068
# SUCCESS: Wrote data for match 1457069
# SUCCESS: Wrote data for match 1457070
# SUCCESS: Wrote data for match 1457071
# SUCCESS: Wrote data for match 1457072
# SUCCESS: Wrote data for match 1457073
#
#                 Stage 'UEFA Nations League D Grp. 2' (ID: 18471) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 6
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7216
# Start writing stage data for stage 15951
# SUCCESS: Wrote data for stage 15951 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2018-2019/stage_id=15951/stage_info.json
# Start getting match_configs for stage 15951
# Found 12 matches for stage 15951
# SUCCESS: Wrote data for match 1266331
# SUCCESS: Wrote data for match 1266332
# SUCCESS: Wrote data for match 1266333
# SUCCESS: Wrote data for match 1266334
# SUCCESS: Wrote data for match 1266335
# SUCCESS: Wrote data for match 1266336
# SUCCESS: Wrote data for match 1266337
# SUCCESS: Wrote data for match 1266338
# SUCCESS: Wrote data for match 1266339
# SUCCESS: Wrote data for match 1266340
# SUCCESS: Wrote data for match 1266341
# SUCCESS: Wrote data for match 1266342
#
#                 Stage 'UEFA Nations League D Grp. 1' (ID: 15951) summary:
#                 Total matches considered : 12
#                 Successfully fetched      : 12
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 15953
# SUCCESS: Wrote data for stage 15953 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2018-2019/stage_id=15953/stage_info.json
# Start getting match_configs for stage 15953
# Found 12 matches for stage 15953
# SUCCESS: Wrote data for match 1266367
# SUCCESS: Wrote data for match 1266368
# SUCCESS: Wrote data for match 1266369
# SUCCESS: Wrote data for match 1266370
# SUCCESS: Wrote data for match 1266371
# SUCCESS: Wrote data for match 1266372
# SUCCESS: Wrote data for match 1266373
# SUCCESS: Wrote data for match 1266374
# SUCCESS: Wrote data for match 1266375
# SUCCESS: Wrote data for match 1266376
# SUCCESS: Wrote data for match 1266377
# SUCCESS: Wrote data for match 1266378
#
#                 Stage 'UEFA Nations League D Grp. 2' (ID: 15953) summary:
#                 Total matches considered : 12
#                 Successfully fetched      : 12
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 15954
# SUCCESS: Wrote data for stage 15954 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2018-2019/stage_id=15954/stage_info.json
# Start getting match_configs for stage 15954
# Found 12 matches for stage 15954
# SUCCESS: Wrote data for match 1266379
# SUCCESS: Wrote data for match 1266380
# SUCCESS: Wrote data for match 1266381
# SUCCESS: Wrote data for match 1266382
# SUCCESS: Wrote data for match 1266383
# SUCCESS: Wrote data for match 1266384
# SUCCESS: Wrote data for match 1266385

# %%
league_mapping = {
    (247, 686, 2018): "international-uefa-nations-league-d"
}

IS_HDFS = True
driver = None

# Storing failed matches to try 1 more time
initial_failures = []

try: 
    for (region_id, tournament_id, start_year_after), league_name in league_mapping.items():
        print("="*50)
        print(f"STARTING LEAGUE: {league_name}")
        
        print("INFO: Starting a new browser session...")
        if not driver:
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

        season_ids, driver = get_season_ids(region_id, tournament_id, start_year_after, driver)
        print(f"Season_ids of {league_name}:", season_ids)

        for season_id in season_ids:
            print("\n" + "-"*20)
            print(f"INFO: Starting new session for Season ID: {season_id}")

            stage_ids, driver = get_stage_ids(region_id, tournament_id, season_id, driver)
            if not stage_ids:
                print(f"WARNING: No stages found for season {season_id}. Skipping.")
                continue

            for stage_id in stage_ids:
                stage_config = process_season_stages(region_id, tournament_id, season_id, stage_id, league_name, driver, is_hdfs=IS_HDFS)
                if not stage_config:
                    print(f"WARNING: Failed to process metadata for stage {stage_id}. Skipping to next stage.")
                    continue

                stage_path = stage_config["stage_path"]
                stage_name = stage_config["stage_name"]

                match_configs, driver = get_match_configs(stage_config, driver, is_hdfs=IS_HDFS)
                
                matches_count = len(match_configs)
                fetched_count = 0 # Successfully fetched matches
                already_exists_count = 0
                future_count = 0
                failed_count = 0

                for match_id, start_time_string in match_configs:
                    status = get_match_data(match_id, start_time_string, stage_path, driver, is_hdfs=IS_HDFS)
                    if status == MatchStatus.FETCHED:
                        fetched_count += 1
                    elif status == MatchStatus.ALREADY_EXISTS:
                        already_exists_count += 1
                    elif status == MatchStatus.FUTURE_MATCH:
                        future_count += 1
                    elif status == MatchStatus.FAILED:
                        failed_count += 1
                        initial_failures.append([match_id, start_time_string, stage_path])
                
                print(f"""
                Stage '{stage_name}' (ID: {stage_id}) summary:
                Total matches considered : {matches_count}
                Successfully fetched      : {fetched_count}
                Already existed           : {already_exists_count}
                Scheduled for future      : {future_count}
                Failed to fetch           : {failed_count}
                """)

            # Reset driver after every season
            driver = reset_driver(driver)

    # Retry loop for failed matches
    final_failures = []
    if initial_failures:
        print("\n" + "="*50)
        print(f"RETRYING {len(initial_failures)} FAILED MATCHES...")
        print("="*50)
        
        for match_id, start_time_string, stage_path in initial_failures:
            status = get_match_data(match_id, start_time_string, stage_path, driver)
            
            if status == MatchStatus.FAILED:
                print(f"  -> RETRY FAILED: Match {match_id} still failing.")
                final_failures.append((match_id, start_time_string, stage_path))
            else:
                print(f"  -> RETRY SUCCESS: Match {match_id} scraped successfully.")

    # Report
    print("\n" + "="*50)
    print("CRAWL COMPLETE.")
    if final_failures:
        print(f"The following {len(final_failures)} matches could not be scraped after all retries:")
        for match_info in final_failures:
            print(f"  - Match ID: {match_info[0]}")
    else:
        print("All matches were scraped successfully (or were already present).")
    print("="*50)

finally:
    # Make sure the final driver is always closed, even if there's an error
    if driver:
        print("INFO: Closing final browser session.")
        driver.quit()
# Out:
# ==================================================
# STARTING LEAGUE: international-uefa-nations-league-d
# INFO: Starting a new browser session...
# Season_ids of international-uefa-nations-league-d: ['9983', '8871', '8157', '7216']
#
# --------------------
# INFO: Starting new session for Season ID: 9983
# Start writing stage data for stage 22917
# SUCCESS: Wrote data for stage 22917 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2024-2025/stage_id=22917/stage_info.json
# Start getting match_configs for stage 22917
# Found 6 matches for stage 22917
#
#                 Stage 'UEFA Nations League D Grp. 1' (ID: 22917) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 22918
# SUCCESS: Wrote data for stage 22918 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2024-2025/stage_id=22918/stage_info.json
# Start getting match_configs for stage 22918
# Found 6 matches for stage 22918
#
#                 Stage 'UEFA Nations League D Grp. 2' (ID: 22918) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8871
# Start writing stage data for stage 20394
# SUCCESS: Wrote data for stage 20394 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2022-2023/stage_id=20394/stage_info.json
# Start getting match_configs for stage 20394
# Found 12 matches for stage 20394
#
#                 Stage 'UEFA Nations League D Grp. 1' (ID: 20394) summary:
#                 Total matches considered : 12
#                 Successfully fetched      : 0
#                 Already existed           : 12
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 20396
# SUCCESS: Wrote data for stage 20396 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2022-2023/stage_id=20396/stage_info.json
# Start getting match_configs for stage 20396
# Found 6 matches for stage 20396
#
#                 Stage 'UEFA Nations League D Grp. 2' (ID: 20396) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 8157
# Start writing stage data for stage 18470
# SUCCESS: Wrote data for stage 18470 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2020-2021/stage_id=18470/stage_info.json
# Start getting match_configs for stage 18470
# Found 12 matches for stage 18470
#
#                 Stage 'UEFA Nations League D Grp. 1' (ID: 18470) summary:
#                 Total matches considered : 12
#                 Successfully fetched      : 0
#                 Already existed           : 12
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 18471
# SUCCESS: Wrote data for stage 18471 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2020-2021/stage_id=18471/stage_info.json
# Start getting match_configs for stage 18471
# Found 6 matches for stage 18471
#
#                 Stage 'UEFA Nations League D Grp. 2' (ID: 18471) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7216
# Start writing stage data for stage 15951
# SUCCESS: Wrote data for stage 15951 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2018-2019/stage_id=15951/stage_info.json
# Start getting match_configs for stage 15951
# Found 12 matches for stage 15951
#
#                 Stage 'UEFA Nations League D Grp. 1' (ID: 15951) summary:
#                 Total matches considered : 12
#                 Successfully fetched      : 0
#                 Already existed           : 12
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 15953
# SUCCESS: Wrote data for stage 15953 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2018-2019/stage_id=15953/stage_info.json
# Start getting match_configs for stage 15953
# Found 12 matches for stage 15953
#
#                 Stage 'UEFA Nations League D Grp. 2' (ID: 15953) summary:
#                 Total matches considered : 12
#                 Successfully fetched      : 0
#                 Already existed           : 12
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 15954
# SUCCESS: Wrote data for stage 15954 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2018-2019/stage_id=15954/stage_info.json
# Start getting match_configs for stage 15954
# Found 12 matches for stage 15954
# SUCCESS: Wrote data for match 1266387
# SUCCESS: Wrote data for match 1266388
# SUCCESS: Wrote data for match 1266389
# SUCCESS: Wrote data for match 1266390
#
#                 Stage 'UEFA Nations League D Grp. 3' (ID: 15954) summary:
#                 Total matches considered : 12
#                 Successfully fetched      : 4
#                 Already existed           : 8
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 15955
# SUCCESS: Wrote data for stage 15955 to HDFS bronze/stage_data/league=international-uefa-nations-league-d/season=2018-2019/stage_id=15955/stage_info.json
# Start getting match_configs for stage 15955
# Found 12 matches for stage 15955
# SUCCESS: Wrote data for match 1266391
# SUCCESS: Wrote data for match 1266392
# SUCCESS: Wrote data for match 1266393
# SUCCESS: Wrote data for match 1266394
# SUCCESS: Wrote data for match 1266395
# SUCCESS: Wrote data for match 1266396
# SUCCESS: Wrote data for match 1266397
# SUCCESS: Wrote data for match 1266398
# SUCCESS: Wrote data for match 1266399
# SUCCESS: Wrote data for match 1266400
# SUCCESS: Wrote data for match 1266401
# SUCCESS: Wrote data for match 1266402
#
#                 Stage 'UEFA Nations League D Grp. 4' (ID: 15955) summary:
#                 Total matches considered : 12
#                 Successfully fetched      : 12
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# ==================================================
# CRAWL COMPLETE.
# All matches were scraped successfully (or were already present).
# ==================================================
# INFO: Closing final browser session.

# %%
IS_HDFS = True

# %%
import os
import json
import posixpath

root_dir = "bronze/match_data"

if IS_HDFS:
    root_dir = os.path.join(HDFS_PATH, root_dir)

failed_count = 0
failed_matches = []
fixed_count = 0
fixed_matches = []

driver = None
if not driver:
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

def hdfs_walk(client, root):
    """
    Walk HDFS directory tree like os.walk.
    """
    dirs, files = [], []
    for entry in client.list(root, status=True):
        name, info = entry
        if info['type'] == 'DIRECTORY':
            dirs.append(name)
        else:
            files.append(name)
    yield root, dirs, files
    for d in dirs:
        new_root = posixpath.join(root, d)
        yield from hdfs_walk(client, new_root)


# Decide source
if IS_HDFS:
    client = InsecureClient("http://localhost:9870", user="dottier")
    walker = hdfs_walk(client, root_dir)
else:
    walker = os.walk(root_dir)

for dirpath, dirnames, filenames in walker:
    if "match_preview.json" in filenames:
        # Build preview file path
        if IS_HDFS:
            preview_file = posixpath.join(dirpath, "match_preview.json")
            try:
                with client.read(preview_file, encoding="utf-8") as f:
                    data = json.load(f)
            except Exception as e:
                failed_count += 1
                failed_matches.append(f"{dirpath} (Exception)")
                print(f"[ERROR] Failed to read {preview_file}: {e}")
                continue
        else:
            preview_file = os.path.join(dirpath, "match_preview.json")
            try:
                with open(preview_file, "r", encoding="utf-8") as f:
                    data = json.load(f)
            except Exception as e:
                failed_count += 1
                failed_matches.append(f"{dirpath} (Exception)")
                print(f"[ERROR] Failed to read {preview_file}: {e}")
                continue

        start_time_utc = data.get("data", {}).get("startTimeUtc")
        match_id = data.get("metadata", {}).get("match_id")
        if not start_time_utc:
            print(f"{dirpath}: match_preview.json exists but startTimeUtc not found")

        if "match_data.json" not in filenames:
            if IS_HDFS:
                # user/{username}/bronze/match_data/league=.../season=.../stage_id=.../match_id=...
                segments = dirpath.strip("/").split("/")
                stage_path = "/".join(segments[4:7])
            else:
                # bronze/match_data/league=.../season=.../stage_id=.../match_id=...
                segments = dirpath.split(os.sep)
                stage_path = "/".join(segments[2:5])

            status = get_match_data(
                match_id=match_id,
                start_time_string=start_time_utc,
                stage_path=stage_path,
                driver=driver,
                is_hdfs=IS_HDFS
            )

            if status == MatchStatus.FAILED:
                failed_count += 1
                failed_matches.append(f"{match_id} ({stage_path})")
            elif status == MatchStatus.FETCHED:
                fixed_count += 1
                fixed_matches.append(f"{match_id} ({stage_path})")


print("\n=== Summary ===")
print(f"Successfully fixed: {fixed_count}")
print("Fixed matches:", fixed_matches)
print(f"Failed: {failed_count}")
print("Failed matches:", failed_matches)
# Out:
# WARNING: Could not find a script containing all required data for match 1076372 on page https://www.whoscored.com/matches/1076372/live
# WARNING: Could not find a script containing all required data for match 1722662 on page https://www.whoscored.com/matches/1722662/live
# WARNING: Could not find a script containing all required data for match 1722663 on page https://www.whoscored.com/matches/1722663/live
# WARNING: Could not find a script containing all required data for match 1722664 on page https://www.whoscored.com/matches/1722664/live
# WARNING: Could not find a script containing all required data for match 1722665 on page https://www.whoscored.com/matches/1722665/live
# SUCCESS: Wrote data for match 1492135
# SUCCESS: Wrote data for match 1492137
# SUCCESS: Wrote data for match 1492139
# SUCCESS: Wrote data for match 1492142
# SUCCESS: Wrote data for match 1492145
# SUCCESS: Wrote data for match 1492148
# SUCCESS: Wrote data for match 1492151
# SUCCESS: Wrote data for match 1492155
# SUCCESS: Wrote data for match 1492159
# SUCCESS: Wrote data for match 1492163
# SUCCESS: Wrote data for match 1492167
# SUCCESS: Wrote data for match 1492171
# SUCCESS: Wrote data for match 1492175
# SUCCESS: Wrote data for match 1492179
# SUCCESS: Wrote data for match 1492183
# SUCCESS: Wrote data for match 1492197
# SUCCESS: Wrote data for match 1492200
# SUCCESS: Wrote data for match 1492203
# SUCCESS: Wrote data for match 1492206
# SUCCESS: Wrote data for match 1492209
# SUCCESS: Wrote data for match 1492212
# SUCCESS: Wrote data for match 1492215
# SUCCESS: Wrote data for match 1492221
# SUCCESS: Wrote data for match 1492247
# SUCCESS: Wrote data for match 1492248
# SUCCESS: Wrote data for match 1492249
# SUCCESS: Wrote data for match 1492250
# SUCCESS: Wrote data for match 1492251
# SUCCESS: Wrote data for match 1492252
# SUCCESS: Wrote data for match 1492253
# SUCCESS: Wrote data for match 1492254
# SUCCESS: Wrote data for match 1492255
# SUCCESS: Wrote data for match 1492256
'1492254 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492255 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492256 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492292 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492294 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492301 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492302 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492303 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492304 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492305 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492306 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492307 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492308 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492309 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492310 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492311 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492312 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492313 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492314 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492315 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492316 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492317 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492318 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492319 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492320 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492321 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492322 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492323 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492324 (league=spain-laliga/season=2020-2021/stage_id=18851)', '1492325 (league=spain-laliga/season=2020-2021/stage_id=18851)']
# Failed: 5
# Failed matches: ['1076372 (league=france-ligue-1/season=2016-2017/stage_id=13768)', '1722662 (league=international-uefa-nations-league-c/season=2022-2023/stage_id=21377)', '1722663 (league=international-uefa-nations-league-c/season=2022-2023/stage_id=21377)', '1722664 (league=international-uefa-nations-league-c/season=2022-2023/stage_id=21377)', '1722665 (league=international-uefa-nations-league-c/season=2022-2023/stage_id=21377)']

# %%
league_mapping = {
    (247, 124, 2012): "international-european-championship",
}

if driver:
    driver.quit()
    driver = None

# Storing failed matches to try 1 more time
initial_failures = []

try: 
    for (region_id, tournament_id, start_year_after), league_name in league_mapping.items():
        print("="*50)
        print(f"STARTING LEAGUE: {league_name}")
        
        print("INFO: Starting a new browser session...")
        if not driver:
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

        season_ids, driver = get_season_ids(region_id, tournament_id, start_year_after, driver)
        print(f"Season_ids of {league_name}:", season_ids)

        for season_id in season_ids:
            print("\n" + "-"*20)
            print(f"INFO: Starting new session for Season ID: {season_id}")

            stage_ids, driver = get_stage_ids(region_id, tournament_id, season_id, driver)
            if not stage_ids:
                print(f"WARNING: No stages found for season {season_id}. Skipping.")
                continue

            for stage_id in stage_ids:
                stage_config = process_season_stages(region_id, tournament_id, season_id, stage_id, league_name, driver, is_hdfs=IS_HDFS)
                if not stage_config:
                    print(f"WARNING: Failed to process metadata for stage {stage_id}. Skipping to next stage.")
                    continue

                stage_path = stage_config["stage_path"]
                stage_name = stage_config["stage_name"]

                match_configs, driver = get_match_configs(stage_config, driver, is_hdfs=IS_HDFS)
                
                matches_count = len(match_configs)
                fetched_count = 0 # Successfully fetched matches
                already_exists_count = 0
                future_count = 0
                failed_count = 0

                for match_id, start_time_string in match_configs:
                    status = get_match_data(match_id, start_time_string, stage_path, driver, is_hdfs=IS_HDFS)
                    if status == MatchStatus.FETCHED:
                        fetched_count += 1
                    elif status == MatchStatus.ALREADY_EXISTS:
                        already_exists_count += 1
                    elif status == MatchStatus.FUTURE_MATCH:
                        future_count += 1
                    elif status == MatchStatus.FAILED:
                        failed_count += 1
                        initial_failures.append([match_id, start_time_string, stage_path])
                
                print(f"""
                Stage '{stage_name}' (ID: {stage_id}) summary:
                Total matches considered : {matches_count}
                Successfully fetched      : {fetched_count}
                Already existed           : {already_exists_count}
                Scheduled for future      : {future_count}
                Failed to fetch           : {failed_count}
                """)

            # Reset driver after every season
            driver = reset_driver(driver)

    # Retry loop for failed matches
    final_failures = []
    if initial_failures:
        print("\n" + "="*50)
        print(f"RETRYING {len(initial_failures)} FAILED MATCHES...")
        print("="*50)
        
        for match_id, start_time_string, stage_path in initial_failures:
            status = get_match_data(match_id, start_time_string, stage_path, driver)
            
            if status == MatchStatus.FAILED:
                print(f"  -> RETRY FAILED: Match {match_id} still failing.")
                final_failures.append((match_id, start_time_string, stage_path))
            else:
                print(f"  -> RETRY SUCCESS: Match {match_id} scraped successfully.")

    # Report
    print("\n" + "="*50)
    print("CRAWL COMPLETE.")
    if final_failures:
        print(f"The following {len(final_failures)} matches could not be scraped after all retries:")
        for match_info in final_failures:
            print(f"  - Match ID: {match_info[0]}")
    else:
        print("All matches were scraped successfully (or were already present).")
    print("="*50)

finally:
    # Make sure the final driver is always closed, even if there's an error
    if driver:
        print("INFO: Closing final browser session.")
        driver.quit()
# Out:
# ==================================================
# STARTING LEAGUE: international-european-championship
# INFO: Starting a new browser session...
# Season_ids of international-european-championship: ['9299', '7329', '4246', '3164']
#
# --------------------
# INFO: Starting new session for Season ID: 9299
# Start writing stage data for stage 21415
# SUCCESS: Wrote data for stage 21415 to HDFS bronze/stage_data/league=international-european-championship/season=2024/stage_id=21415/stage_info.json
# Start getting match_configs for stage 21415
# Found 15 matches for stage 21415
#
#                 Stage 'EURO Final Stage' (ID: 21415) summary:
#                 Total matches considered : 15
#                 Successfully fetched      : 0
#                 Already existed           : 15
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 23157
# SUCCESS: Wrote data for stage 23157 to HDFS bronze/stage_data/league=international-european-championship/season=2024/stage_id=23157/stage_info.json
# Start getting match_configs for stage 23157
# WARNING: No matches found for 2024-2024, retrying with 2025-2025
# Found 0 matches for stage 23157
#
#                 Stage 'EURO Grp. D' (ID: 23157) summary:
#                 Total matches considered : 0
#                 Successfully fetched      : 0
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 21399
# SUCCESS: Wrote data for stage 21399 to HDFS bronze/stage_data/league=international-european-championship/season=2024/stage_id=21399/stage_info.json
# Start getting match_configs for stage 21399
# Found 6 matches for stage 21399
#
#                 Stage 'EURO Grp. A' (ID: 21399) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 21400
# SUCCESS: Wrote data for stage 21400 to HDFS bronze/stage_data/league=international-european-championship/season=2024/stage_id=21400/stage_info.json
# Start getting match_configs for stage 21400
# Found 6 matches for stage 21400
#
#                 Stage 'EURO Grp. B' (ID: 21400) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 21403
# SUCCESS: Wrote data for stage 21403 to HDFS bronze/stage_data/league=international-european-championship/season=2024/stage_id=21403/stage_info.json
# Start getting match_configs for stage 21403
# Found 6 matches for stage 21403
#
#                 Stage 'EURO Grp. C' (ID: 21403) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 21401
# SUCCESS: Wrote data for stage 21401 to HDFS bronze/stage_data/league=international-european-championship/season=2024/stage_id=21401/stage_info.json
# Start getting match_configs for stage 21401
# Found 6 matches for stage 21401
#
#                 Stage 'EURO Grp. D' (ID: 21401) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 21402
# SUCCESS: Wrote data for stage 21402 to HDFS bronze/stage_data/league=international-european-championship/season=2024/stage_id=21402/stage_info.json
# Start getting match_configs for stage 21402
# Found 6 matches for stage 21402
#
#                 Stage 'EURO Grp. E' (ID: 21402) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 21404
# SUCCESS: Wrote data for stage 21404 to HDFS bronze/stage_data/league=international-european-championship/season=2024/stage_id=21404/stage_info.json
# Start getting match_configs for stage 21404
# Found 6 matches for stage 21404
#
#                 Stage 'EURO Grp. F' (ID: 21404) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 7329
# Start writing stage data for stage 16306
# SUCCESS: Wrote data for stage 16306 to HDFS bronze/stage_data/league=international-european-championship/season=2020/stage_id=16306/stage_info.json
# Start getting match_configs for stage 16306
# Found 15 matches for stage 16306
# SUCCESS: Wrote data for match 1551946
# SUCCESS: Wrote data for match 1551945
# SUCCESS: Wrote data for match 1553544
# SUCCESS: Wrote data for match 1553546
# SUCCESS: Wrote data for match 1553537
# SUCCESS: Wrote data for match 1553547
# SUCCESS: Wrote data for match 1553545
# SUCCESS: Wrote data for match 1553548
# SUCCESS: Wrote data for match 1559093
# SUCCESS: Wrote data for match 1559075
# SUCCESS: Wrote data for match 1559074
# SUCCESS: Wrote data for match 1559451
# SUCCESS: Wrote data for match 1563891
# SUCCESS: Wrote data for match 1565600
# SUCCESS: Wrote data for match 1569613
#
#                 Stage 'EURO Final Stage' (ID: 16306) summary:
#                 Total matches considered : 15
#                 Successfully fetched      : 15
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 16297
# SUCCESS: Wrote data for stage 16297 to HDFS bronze/stage_data/league=international-european-championship/season=2020/stage_id=16297/stage_info.json
# Start getting match_configs for stage 16297
# Found 6 matches for stage 16297
# SUCCESS: Wrote data for match 1434346
# SUCCESS: Wrote data for match 1434347
# SUCCESS: Wrote data for match 1434348
# SUCCESS: Wrote data for match 1434349
# SUCCESS: Wrote data for match 1434350
# SUCCESS: Wrote data for match 1434351
#
#                 Stage 'EURO Grp. A' (ID: 16297) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 6
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 16298
# SUCCESS: Wrote data for stage 16298 to HDFS bronze/stage_data/league=international-european-championship/season=2020/stage_id=16298/stage_info.json
# Start getting match_configs for stage 16298
# Found 6 matches for stage 16298
# SUCCESS: Wrote data for match 1434352
# SUCCESS: Wrote data for match 1434353
# SUCCESS: Wrote data for match 1434355
# SUCCESS: Wrote data for match 1434354
# SUCCESS: Wrote data for match 1434356
# SUCCESS: Wrote data for match 1434357
#
#                 Stage 'EURO Grp. B' (ID: 16298) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 6
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 16299
# SUCCESS: Wrote data for stage 16299 to HDFS bronze/stage_data/league=international-european-championship/season=2020/stage_id=16299/stage_info.json
# Start getting match_configs for stage 16299
# Found 6 matches for stage 16299
# SUCCESS: Wrote data for match 1513449
# SUCCESS: Wrote data for match 1434358
# SUCCESS: Wrote data for match 1513450
# SUCCESS: Wrote data for match 1434359
# SUCCESS: Wrote data for match 1434360
# SUCCESS: Wrote data for match 1513451
#
#                 Stage 'EURO Grp. C' (ID: 16299) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 6
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 16301
# SUCCESS: Wrote data for stage 16301 to HDFS bronze/stage_data/league=international-european-championship/season=2020/stage_id=16301/stage_info.json
# Start getting match_configs for stage 16301
# Found 6 matches for stage 16301
# SUCCESS: Wrote data for match 1434361
# SUCCESS: Wrote data for match 1513467
# SUCCESS: Wrote data for match 1434362
# SUCCESS: Wrote data for match 1513468
# SUCCESS: Wrote data for match 1513469
# SUCCESS: Wrote data for match 1434363
#
#                 Stage 'EURO Grp. D' (ID: 16301) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 6
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 16300
# SUCCESS: Wrote data for stage 16300 to HDFS bronze/stage_data/league=international-european-championship/season=2020/stage_id=16300/stage_info.json
# Start getting match_configs for stage 16300
# Found 6 matches for stage 16300
# SUCCESS: Wrote data for match 1513464
# SUCCESS: Wrote data for match 1434364
# SUCCESS: Wrote data for match 1513465
# SUCCESS: Wrote data for match 1434365
# SUCCESS: Wrote data for match 1434366
# SUCCESS: Wrote data for match 1513466
#
#                 Stage 'EURO Grp. E' (ID: 16300) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 6
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 16302
# SUCCESS: Wrote data for stage 16302 to HDFS bronze/stage_data/league=international-european-championship/season=2020/stage_id=16302/stage_info.json
# Start getting match_configs for stage 16302
# Found 6 matches for stage 16302
# SUCCESS: Wrote data for match 1513461
# SUCCESS: Wrote data for match 1434367
# SUCCESS: Wrote data for match 1513462
# SUCCESS: Wrote data for match 1434368
# SUCCESS: Wrote data for match 1434369
# SUCCESS: Wrote data for match 1513463
#
#                 Stage 'EURO Grp. F' (ID: 16302) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 6
#                 Already existed           : 0
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 4246
# Start writing stage data for stage 8987
# SUCCESS: Wrote data for stage 8987 to HDFS bronze/stage_data/league=international-european-championship/season=2016/stage_id=8987/stage_info.json
# Start getting match_configs for stage 8987
# Found 6 matches for stage 8987
#
#                 Stage 'EURO Grp. A' (ID: 8987) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 8988
# SUCCESS: Wrote data for stage 8988 to HDFS bronze/stage_data/league=international-european-championship/season=2016/stage_id=8988/stage_info.json
# Start getting match_configs for stage 8988
# Found 6 matches for stage 8988
#
#                 Stage 'EURO Grp. B' (ID: 8988) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 8989
# SUCCESS: Wrote data for stage 8989 to HDFS bronze/stage_data/league=international-european-championship/season=2016/stage_id=8989/stage_info.json
# Start getting match_configs for stage 8989
# Found 6 matches for stage 8989
#
#                 Stage 'EURO Grp. C' (ID: 8989) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 8990
# SUCCESS: Wrote data for stage 8990 to HDFS bronze/stage_data/league=international-european-championship/season=2016/stage_id=8990/stage_info.json
# Start getting match_configs for stage 8990
# Found 6 matches for stage 8990
#
#                 Stage 'EURO Grp. D' (ID: 8990) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 8991
# SUCCESS: Wrote data for stage 8991 to HDFS bronze/stage_data/league=international-european-championship/season=2016/stage_id=8991/stage_info.json
# Start getting match_configs for stage 8991
# Found 6 matches for stage 8991
#
#                 Stage 'EURO Grp. E' (ID: 8991) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 8992
# SUCCESS: Wrote data for stage 8992 to HDFS bronze/stage_data/league=international-european-championship/season=2016/stage_id=8992/stage_info.json
# Start getting match_configs for stage 8992
# Found 6 matches for stage 8992
#
#                 Stage 'EURO Grp. F' (ID: 8992) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 8994
# SUCCESS: Wrote data for stage 8994 to HDFS bronze/stage_data/league=international-european-championship/season=2016/stage_id=8994/stage_info.json
# Start getting match_configs for stage 8994
# Found 8 matches for stage 8994
#
#                 Stage 'EURO 1/8 Finals' (ID: 8994) summary:
#                 Total matches considered : 8
#                 Successfully fetched      : 0
#                 Already existed           : 8
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 8993
# SUCCESS: Wrote data for stage 8993 to HDFS bronze/stage_data/league=international-european-championship/season=2016/stage_id=8993/stage_info.json
# Start getting match_configs for stage 8993
# Found 4 matches for stage 8993
#
#                 Stage 'EURO Quarter Finals' (ID: 8993) summary:
#                 Total matches considered : 4
#                 Successfully fetched      : 0
#                 Already existed           : 4
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 8995
# SUCCESS: Wrote data for stage 8995 to HDFS bronze/stage_data/league=international-european-championship/season=2016/stage_id=8995/stage_info.json
# Start getting match_configs for stage 8995
# Found 2 matches for stage 8995
#
#                 Stage 'EURO Semi Finals' (ID: 8995) summary:
#                 Total matches considered : 2
#                 Successfully fetched      : 0
#                 Already existed           : 2
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 8996
# SUCCESS: Wrote data for stage 8996 to HDFS bronze/stage_data/league=international-european-championship/season=2016/stage_id=8996/stage_info.json
# Start getting match_configs for stage 8996
# Found 1 matches for stage 8996
#
#                 Stage 'EURO Final' (ID: 8996) summary:
#                 Total matches considered : 1
#                 Successfully fetched      : 0
#                 Already existed           : 1
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# --------------------
# INFO: Starting new session for Season ID: 3164
# Start writing stage data for stage 5980
# SUCCESS: Wrote data for stage 5980 to HDFS bronze/stage_data/league=international-european-championship/season=2012/stage_id=5980/stage_info.json
# Start getting match_configs for stage 5980
# Found 6 matches for stage 5980
#
#                 Stage 'EURO Grp. A' (ID: 5980) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 5981
# SUCCESS: Wrote data for stage 5981 to HDFS bronze/stage_data/league=international-european-championship/season=2012/stage_id=5981/stage_info.json
# Start getting match_configs for stage 5981
# Found 6 matches for stage 5981
#
#                 Stage 'EURO Grp. B' (ID: 5981) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 5982
# SUCCESS: Wrote data for stage 5982 to HDFS bronze/stage_data/league=international-european-championship/season=2012/stage_id=5982/stage_info.json
# Start getting match_configs for stage 5982
# Found 6 matches for stage 5982
#
#                 Stage 'EURO Grp. C' (ID: 5982) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 5983
# SUCCESS: Wrote data for stage 5983 to HDFS bronze/stage_data/league=international-european-championship/season=2012/stage_id=5983/stage_info.json
# Start getting match_configs for stage 5983
# Found 6 matches for stage 5983
#
#                 Stage 'EURO Grp. D' (ID: 5983) summary:
#                 Total matches considered : 6
#                 Successfully fetched      : 0
#                 Already existed           : 6
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 5975
# SUCCESS: Wrote data for stage 5975 to HDFS bronze/stage_data/league=international-european-championship/season=2012/stage_id=5975/stage_info.json
# Start getting match_configs for stage 5975
# Found 4 matches for stage 5975
#
#                 Stage 'EURO Quarter finals' (ID: 5975) summary:
#                 Total matches considered : 4
#                 Successfully fetched      : 0
#                 Already existed           : 4
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 5976
# SUCCESS: Wrote data for stage 5976 to HDFS bronze/stage_data/league=international-european-championship/season=2012/stage_id=5976/stage_info.json
# Start getting match_configs for stage 5976
# Found 2 matches for stage 5976
#
#                 Stage 'EURO Semi finals' (ID: 5976) summary:
#                 Total matches considered : 2
#                 Successfully fetched      : 0
#                 Already existed           : 2
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# Start writing stage data for stage 5978
# SUCCESS: Wrote data for stage 5978 to HDFS bronze/stage_data/league=international-european-championship/season=2012/stage_id=5978/stage_info.json
# Start getting match_configs for stage 5978
# Found 1 matches for stage 5978
#
#                 Stage 'EURO Final' (ID: 5978) summary:
#                 Total matches considered : 1
#                 Successfully fetched      : 0
#                 Already existed           : 1
#                 Scheduled for future      : 0
#                 Failed to fetch           : 0
#
# INFO: Starting a new browser session...
#
# ==================================================
# CRAWL COMPLETE.
# All matches were scraped successfully (or were already present).
# ==================================================
# INFO: Closing final browser session.

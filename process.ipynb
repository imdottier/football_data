# %%
from pyspark.sql import SparkSession

HDFS_WAREHOUSE_PATH = "hdfs://localhost:9000/user/dottier/spark-warehouse"

spark: SparkSession = SparkSession.builder \
                        .appName('Test Silver') \
                        .config("spark.sql.warehouse.dir", HDFS_WAREHOUSE_PATH) \
                        .config("spark.driver.memory", "8g") \
                        .config("spark.sql.shuffle.partitions", "400") \
                        .config("spark.jars.packages", "io.delta:delta-spark_2.12:3.3.0") \
                        .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
                        .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
                        .enableHiveSupport() \
                        .getOrCreate()

spark.sparkContext.setLogLevel("WARN")
logger = spark._jvm.org.apache.log4j
logger.LogManager.getLogger("org.apache.hadoop.hive.metastore.ObjectStore").setLevel(logger.Level.ERROR)
logger.LogManager.getLogger("org.apache.hadoop.hive.conf.HiveConf").setLevel(logger.Level.ERROR)
# Out:
# 25/09/06 05:21:26 WARN Utils: Your hostname, DESKTOP-9VM3SA1 resolves to a loopback address: 127.0.1.1; using 172.28.82.250 instead (on interface eth0)
# 25/09/06 05:21:26 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/dottier/.ivy2/cache
# The jars for the packages stored in: /home/dottier/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-e37ea06e-3141-4f51-8ec9-214eab08477f;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.3.0 in central
# 	found io.delta#delta-storage;3.3.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# :: resolution report :: resolve 107ms :: artifacts dl 5ms
# 	:: modules in use:
# 	io.delta#delta-spark_2.12;3.3.0 from central in [default]
# 	io.delta#delta-storage;3.3.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-e37ea06e-3141-4f51-8ec9-214eab08477f
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/4ms)
# 25/09/06 05:21:28 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
print(spark.sparkContext.master)
# Out:
# local[*]

# %%
print(spark.version)  # Spark version
print(spark.sparkContext.getConf().get("spark.scala.version")) # Scala version

# %%
spark._jsc.hadoopConfiguration().set("fs.defaultFS", "hdfs://localhost:9000")

# %%
print(spark._jsc.hadoopConfiguration().get("fs.defaultFS"))

# %%
spark.sql("CREATE DATABASE IF NOT EXISTS silver")
# Out:
# 25/09/03 18:26:04 WARN ObjectStore: Failed to get database silver, returning NoSuchObjectException
# 25/09/03 18:26:04 WARN ObjectStore: Failed to get database silver, returning NoSuchObjectException
# 25/09/03 18:26:04 WARN ObjectStore: Failed to get database global_temp, returning NoSuchObjectException
# 25/09/03 18:26:04 WARN ObjectStore: Failed to get database silver, returning NoSuchObjectException
# DataFrame[]

# %%
spark.sql("SHOW TABLES IN silver").show()
# Out:
# +---------+--------------------+-----------+
# |namespace|           tableName|isTemporary|
# +---------+--------------------+-----------+
# |   silver|         dim_players|      false|
# |   silver|          dim_stages|      false|
# |   silver|           dim_teams|      false|
# |   silver|   fct_match_summary|      false|
# |   silver|fct_player_match_...|      false|
# +---------+--------------------+-----------+

# %%
spark.sql("SHOW DATABASES").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# |   silver|
# +---------+

# %%
import re
from pyspark.sql.functions import col, udf
from pyspark.sql.types import StringType

def camel_to_snake(name: str) -> str:
    if name is None:
        return None
    return re.sub(r'(?<!^)(?=[A-Z])', '_', name).lower()

# %%
import re
import pandas as pd
from pyspark.sql.functions import pandas_udf
from pyspark.sql.types import StringType

# 1. The core logic remains the same, but it now operates on a Pandas Series.
def camel_to_snake_vectorized(series: pd.Series) -> pd.Series:
    # The .str accessor in Pandas applies the regex to the whole series at once.
    return series.str.replace(r'(?<!^)(?=[A-Z])', '_', regex=True).str.lower()

# 2. Register it as a Pandas UDF.
snake_case_pandas_udf = pandas_udf(camel_to_snake_vectorized, returnType=StringType())

# %%
# from pyspark.sql import DataFrame
# from pyspark.sql.functions import col, explode_outer
# from pyspark.sql.types import StructType, ArrayType

# # Recursively flattens a PySpark DataFrame
# def flatten_df(df: DataFrame, parent_prefix: str = "") -> DataFrame:
#     flat_cols = []
#     explode_cols = []
    
#     for field in df.schema.fields:
#         field_name = field.name
#         col_name = f"{parent_prefix}{field_name}" if parent_prefix else field_name
#         alias_name = camel_to_snake(col_name.replace(".", "_"))
#         data_type = field.dataType

#         if isinstance(data_type, StructType):
#             # Recurse into struct
#             for subfield in data_type.fields:
#                 sub_col_name = f"{col_name}.{subfield.name}"
#                 sub_alias = camel_to_snake(sub_col_name.replace(".", "_"))
#                 flat_cols.append(col(sub_col_name).alias(sub_alias))
        
#         elif isinstance(data_type, ArrayType) and isinstance(data_type.elementType, StructType):
#             # Explode arrays of structs
#             explode_cols.append((col_name, field_name))
        
#         else:
#             # Primitive column
#             flat_cols.append(col(col_name).alias(alias_name))
    
#     return df.select(flat_cols)

# %%
from pyspark.sql import DataFrame
from pyspark.sql.functions import col, explode_outer
from pyspark.sql.types import StructType, StringType

def flatten_df(df: DataFrame, cols_to_snake_case_values: set = None) -> DataFrame:
    if cols_to_snake_case_values is None:
        cols_to_snake_case_values = set()

    flat_cols = []
    
    def get_flat_cols(schema: StructType, prefix: str = ""):
        for field in schema.fields:
            full_col_name = f"{prefix}{field.name}"
            
            # Recurse into nested structs
            if isinstance(field.dataType, StructType):
                get_flat_cols(field.dataType, prefix=f"{full_col_name}.")
            else:
                # Create the final, clean snake_case alias
                alias_name = camel_to_snake(full_col_name.replace(".", "_"))
                
                # Check if this column's values should be cleaned
                if alias_name in cols_to_snake_case_values and isinstance(field.dataType, StringType):
                    flat_cols.append(
                        snake_case_pandas_udf(col(full_col_name)).alias(alias_name)
                    )
                else:
                    flat_cols.append(
                        col(full_col_name).alias(alias_name)
                    )

    # Start the recursion on the top-level schema
    get_flat_cols(df.schema)
    
    # Return the DataFrame with the flattened and aliased columns
    return df.select(flat_cols)

# %%
import os

BRONZE_PATH = "/user/dottier/bronze"
STAGE_PATH = os.path.join(BRONZE_PATH, "stage_data")
MATCH_PATH = os.path.join(BRONZE_PATH, "match_data")

# %%
from hdfs import InsecureClient, HdfsError
from datetime import datetime, timezone
import os

def read_last_crawl_time():
    client = InsecureClient("http://localhost:9870", user="dottier")
    file_path = os.path.join(BRONZE_PATH, "last_crawl_timestamp.txt")
    try:
        with client.read(file_path, encoding="utf-8") as f:
            last_crawl_str = f.read().strip()
            return datetime.strptime(last_crawl_str, "%Y-%m-%dT%H:%M:%SZ").replace(tzinfo=timezone.utc)
    except (FileNotFoundError, HdfsError):
        return datetime(1970, 1, 1, tzinfo=timezone.utc)
    
last_crawl_time = read_last_crawl_time()
print(last_crawl_time)
# Out:
# 2025-08-15 17:16:35+00:00

# %%
import os
import datetime
from datetime import datetime, timezone

def read_last_crawl_time():
    try:
        with open(os.path.join(BRONZE_PATH, 'last_crawl_timestamp.txt'), 'r') as f:
            last_crawl_str = f.read().strip()
            return datetime.strptime(last_crawl_str, "%Y-%m-%dT%H:%M:%SZ").replace(tzinfo=timezone.utc)
    except FileNotFoundError:
        return datetime(1970, 1, 1, tzinfo=timezone.utc)
    
last_crawl_time = read_last_crawl_time()
print(last_crawl_time)
# Out:
# 1970-01-01 00:00:00+00:00

# %%
def json_to_df(
    schema: StructType,
    crawled_after: datetime,
    path: str,
    glob_pattern: str | None = None
) -> DataFrame:
    reader = (
        spark.read
        .schema(schema)
        .option("modifiedAfter", crawled_after.strftime("%Y-%m-%d %H:%M:%S"))
    )

    if glob_pattern:
        reader = reader.option("pathGlobFilter", glob_pattern)
    
    return reader.json(path)

# %%
from pyspark.sql.functions import current_timestamp, date_format, lit
load_date_hour = date_format(current_timestamp(), "yyyy-MM-dd-HH")
print(lit(load_date_hour))
# Out:
# Column<'date_format(current_timestamp(), yyyy-MM-dd-HH)'>

# %%
from pyspark.sql import DataFrame
from pyspark.sql.functions import lit
from delta.tables import DeltaTable

# Create Delta table if not exists, else merge
def write_to_silver(
    df: DataFrame,
    table_name: str,
    primary_keys: list[str], # MERGE requires a list of keys to join on
    partition_by: list[str] | None = None,
    load_date_hour=None 
):
    full_table_name = f"silver.{table_name}"

    # partition by load_date_hour (yyyy-MM-dd-HH)
    df_to_write = df
    if partition_by and "load_date_hour" in partition_by and partition_by not in df.columns:
        df_to_write = df.withColumn("load_date_hour", lit(load_date_hour))

    # check if table exists in spark catalog
    if not spark.catalog.tableExists(full_table_name):
        # Create delta table
        print(f"Table '{full_table_name}' does not exist. Creating new table...")

        warehouse_path = spark.conf.get("spark.sql.warehouse.dir")
        table_path = f"{warehouse_path}/{full_table_name.replace('.', '.db/')}"

        writer = df_to_write.write \
            .mode("overwrite") \
            .format("delta") \
            .option("mergeSchema", "true")

        if partition_by:
            writer = writer.partitionBy(partition_by)
        
        writer.save(table_path)
        spark.sql(f"CREATE TABLE {full_table_name} USING DELTA LOCATION '{table_path}'")
        print("Table successfully created and registered.")

    else:
        # merge into table
        print(f"Table '{full_table_name}' exists. Merging new data...")
        
        delta_table = DeltaTable.forName(spark, full_table_name)
        merge_condition = " AND ".join([f"target.{key} = source.{key}" for key in primary_keys])
        
        (delta_table.alias("target")
            .merge(
                source=df_to_write.alias("source"),
                condition=merge_condition
            )
            .whenMatchedUpdateAll() 
            .whenNotMatchedInsertAll()
            .execute()
        )
        print("Merge complete.")

# %%
spark.sql("SHOW TABLES")
# Out:
# DataFrame[namespace: string, tableName: string, isTemporary: boolean]

# %%
from delta.tables import DeltaTable

def read_from_silver(table_name: str):
    full_table_name = f"silver.{table_name}"

    try:
        df = spark.read.table(full_table_name)
        print(f"Successfully read {full_table_name}")
        return df
    except Exception as e:
        print(f"Error reading {full_table_name}: {e}")
        raise

# %%
stage = read_from_silver("dim_stages")
stage.show(1000)
# Out:
# Successfully read silver.dim_stages
# 25/09/06 05:21:54 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +---------+-------------+-------------+--------------------+---------+-----------+--------------------+-------------------+--------------------+---------+--------+--------------+
# |region_id|  region_name|tournament_id|     tournament_name|season_id|season_name|          stage_name|         crawled_at|              league|   season|stage_id|load_date_hour|
# +---------+-------------+-------------+--------------------+---------+-----------+--------------------+-------------------+--------------------+---------+--------+--------------+
# |      247|International|          124|European Champion...|     3164|       2012| EURO Quarter finals|2025-09-05 07:06:28|international-eur...|     2012|    5975| 2025-09-05-12|
# |      247|International|          124|European Champion...|     4246|       2016|         EURO Grp. B|2025-09-05 07:04:27|international-eur...|     2016|    8988| 2025-09-05-12|
# |      247|International|           67| FIFA Club World Cup|    10539|       2025|FIFA Club World C...|2025-09-04 20:26:11|international-fif...|     2025|   23862| 2025-09-05-12|
# |      247|International|          686|UEFA Nations Leag...|     7216|  2018/2019|UEFA Nations Leag...|2025-09-05 05:46:12|international-uef...|2018-2019|   15951| 2025-09-05-12|
# |      250|       Europe|          751|European Champion...|    10118|       2023|EURO Qualificatio...|2025-09-04 20:40:19|europe-european-c...|     2023|   21409| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     5967|       2018|    World Cup Grp. B|2025-09-04 20:22:06|international-fif...|     2018|   12752| 2025-09-05-12|
# |      247|International|          124|European Champion...|     9299|       2024|         EURO Grp. B|2025-09-05 06:57:12|international-eur...|     2024|   21400| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     8869|  2022/2023|UEFA Nations Leag...|2025-09-04 21:44:03|international-uef...|2022-2023|   20392| 2025-09-05-12|
# |      247|International|          124|European Champion...|     9299|       2024|         EURO Grp. A|2025-09-05 06:57:05|international-eur...|     2024|   21399| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|     8943|  2021/2022|World Cup Qualifi...|2025-09-04 21:10:39|international-wor...|2021-2022|   19186| 2025-09-05-12|
# |      247|International|          124|European Champion...|     3164|       2012|         EURO Grp. A|2025-09-05 07:06:00|international-eur...|     2012|    5980| 2025-09-05-12|
# |      247|International|          686|UEFA Nations Leag...|     7216|  2018/2019|UEFA Nations Leag...|2025-09-05 05:46:24|international-uef...|2018-2019|   15953| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     9982|  2024/2025|UEFA Nations Leag...|2025-09-04 22:21:26|international-uef...|2024-2025|   22916| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     9980|  2024/2025|UEFA Nations Leag...|2025-09-04 21:36:00|international-uef...|2024-2025|   22906| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|     8943|  2021/2022|World Cup Qualifi...|2025-09-04 21:08:32|international-wor...|2021-2022|   19185| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     7215|  2018/2019|UEFA Nations Leag...|2025-09-04 22:36:32|international-uef...|2018-2019|   15948| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|    10555|  2025/2026|World Cup Qualifi...|2025-09-04 21:00:54|international-wor...|2025-2026|   23975| 2025-09-05-12|
# |      247|International|           67| FIFA Club World Cup|    10539|       2025|FIFA Club World C...|2025-09-04 20:25:55|international-fif...|     2025|   23869| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|    10555|  2025/2026|World Cup Qualifi...|2025-09-04 20:58:42|international-wor...|2025-2026|   23971| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|    10555|  2025/2026|World Cup Qualifi...|2025-09-04 21:03:53|international-wor...|2025-2026|   23978| 2025-09-05-12|
# |      247|International|          124|European Champion...|     4246|       2016|         EURO Grp. A|2025-09-05 07:04:21|international-eur...|     2016|    8987| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     3768|       2014|World Cup Quarter...|2025-09-04 20:24:54|international-fif...|     2014|    7566| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|     8943|  2021/2022|World Cup Qualifi...|2025-09-04 21:19:42|international-wor...|2021-2022|   19190| 2025-09-05-12|
# |      247|International|          124|European Champion...|     9299|       2024|    EURO Final Stage|2025-09-05 06:56:43|international-eur...|     2024|   21415| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     9664|  2023/2024|Champions League ...|2025-09-04 19:15:10|europe-champions-...|2023-2024|   22494| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     6842|  2017/2018|Champions League ...|2025-09-04 19:28:03|europe-champions-...|2017-2018|   15486| 2025-09-05-12|
# |      247|International|           67| FIFA Club World Cup|    10539|       2025|FIFA Club World C...|2025-09-04 20:26:05|international-fif...|     2025|   23861| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     5967|       2018|    World Cup Grp. C|2025-09-04 20:22:13|international-fif...|     2018|   12753| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     8741|  2021/2022|Europa League Grp. E|2025-09-04 19:40:24|europe-europa-league|2021-2022|   20110| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     8741|  2021/2022|Europa League Grp. F|2025-09-04 19:40:39|europe-europa-league|2021-2022|   20109| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     6349|  2016/2017|Champions League ...|2025-09-04 19:30:31|europe-champions-...|2016-2017|   14173| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6843|  2017/2018|Europa League Grp. D|2025-09-04 19:52:11|europe-europa-league|2017-2018|   15493| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6843|  2017/2018|Europa League Grp. I|2025-09-04 19:53:16|europe-europa-league|2017-2018|   15497| 2025-09-05-12|
# |      247|International|           67| FIFA Club World Cup|    10539|       2025|FIFA Club World C...|2025-09-04 20:26:41|international-fif...|     2025|   23866| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     8156|  2020/2021|UEFA Nations Leag...|2025-09-04 22:30:35|international-uef...|2020-2021|   18467| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     6349|  2016/2017|Champions League ...|2025-09-04 19:30:46|europe-champions-...|2016-2017|   14361| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7353|  2018/2019|Europa League Grp. D|2025-09-04 19:49:00|europe-europa-league|2018-2019|   16680| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     6349|  2016/2017|Champions League ...|2025-09-04 19:29:42|europe-champions-...|2016-2017|   14170| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     5967|       2018|     World Cup Final|2025-09-04 20:23:26|international-fif...|     2018|   12763| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     8178|  2020/2021|Europa League Grp. I|2025-09-04 19:43:35|europe-europa-league|2020-2021|   18989| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|    10456|  2024/2025|Champions League ...|2025-09-04 19:12:59|europe-champions-...|2024-2025|   24083| 2025-09-05-12|
# |      108|        Italy|            5|             Serie A|     9659|  2023/2024|             Serie A|2025-09-04 18:21:57|       italy-serie-a|2023-2024|   22143| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     7215|  2018/2019|UEFA Nations Leag...|2025-09-04 22:35:44|international-uef...|2018-2019|   15947| 2025-09-05-12|
# |      247|International|          124|European Champion...|     9299|       2024|         EURO Grp. C|2025-09-05 06:57:20|international-eur...|     2024|   21403| 2025-09-05-12|
# |      108|        Italy|            5|             Serie A|     9159|  2022/2023|Serie A Relegatio...|2025-09-04 18:22:46|       italy-serie-a|2022-2023|   22100| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7805|  2019/2020|Europa League Fin...|2025-09-04 19:47:37|europe-europa-league|2019-2020|   18066| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7353|  2018/2019|Europa League Fin...|2025-09-04 19:50:58|europe-europa-league|2018-2019|   16786| 2025-09-05-12|
# |      252|      England|            2|      Premier League|     5826|  2015/2016|      Premier League|2025-09-04 18:19:51|england-premier-l...|2015-2016|   12496| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     6842|  2017/2018|Champions League ...|2025-09-04 19:28:29|europe-champions-...|2017-2018|   15619| 2025-09-05-12|
# |      247|International|          124|European Champion...|     3164|       2012|          EURO Final|2025-09-05 07:06:45|international-eur...|     2012|    5978| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     5849|  2015/2016|Europa League Fin...|2025-09-04 20:19:24|europe-europa-league|2015-2016|   13186| 2025-09-05-12|
# |      250|       Europe|          751|European Champion...|    10295|  2022/2023|UEFA Nations Leag...|2025-09-04 20:55:40|europe-european-c...|2022-2023|   22714| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9778|  2023/2024|Europa League Fin...|2025-09-04 19:34:56|europe-europa-league|2023-2024|   22687| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     7213|  2018/2019|UEFA Nations Leag...|2025-09-04 21:54:15|international-uef...|2018-2019|   15941| 2025-09-05-12|
# |      247|International|           67| FIFA Club World Cup|    10539|       2025|FIFA Club World C...|2025-09-04 20:25:43|international-fif...|     2025|   24388| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     7804|  2019/2020|Champions League ...|2025-09-04 19:23:59|europe-champions-...|2019-2020|   18065| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     8623|  2021/2022|Champions League ...|2025-09-04 19:18:28|europe-champions-...|2021-2022|   20092| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     8154|  2020/2021|UEFA Nations Leag...|2025-09-04 21:48:54|international-uef...|2020-2021|   18460| 2025-09-05-12|
# |      247|International|          124|European Champion...|     7329|       2020|    EURO Final Stage|2025-09-05 06:58:07|international-eur...|     2020|   16306| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     8177|  2020/2021|Champions League ...|2025-09-04 19:21:42|europe-champions-...|2020-2021|   18979| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     8154|  2020/2021|UEFA Nations Leag...|2025-09-04 21:47:30|international-uef...|2020-2021|   18458| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     6349|  2016/2017|Champions League ...|2025-09-04 19:29:16|europe-champions-...|2016-2017|   14168| 2025-09-05-12|
# |      250|       Europe|          751|European Champion...|    10118|       2023|EURO Qualificatio...|2025-09-04 20:34:11|europe-european-c...|     2023|   21406| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     8872|  2022/2023|UEFA Nations Leag...|2025-09-04 22:24:26|international-uef...|2022-2023|   20398| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9778|  2023/2024|Europa League Grp. A|2025-09-04 19:35:09|europe-europa-league|2023-2024|   22510| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     9086|  2022/2023|Champions League ...|2025-09-04 19:17:20|europe-champions-...|2022-2023|   20967| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     8178|  2020/2021|Europa League Grp. B|2025-09-04 19:42:04|europe-europa-league|2020-2021|   18982| 2025-09-05-12|
# |      247|International|           67| FIFA Club World Cup|    10539|       2025|FIFA Club World C...|2025-09-04 20:26:48|international-fif...|     2025|   23867| 2025-09-05-12|
# |      247|International|          124|European Champion...|     7329|       2020|         EURO Grp. E|2025-09-05 07:02:38|international-eur...|     2020|   16300| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     9086|  2022/2023|Champions League ...|2025-09-04 19:16:55|europe-champions-...|2022-2023|   20964| 2025-09-05-12|
# |      247|International|           67| FIFA Club World Cup|    10539|       2025|FIFA Club World C...|2025-09-04 20:26:24|international-fif...|     2025|   23864| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9778|  2023/2024|Europa League Grp. H|2025-09-04 19:36:41|europe-europa-league|2023-2024|   22516| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     7352|  2018/2019|Champions League ...|2025-09-04 19:25:19|europe-champions-...|2018-2019|   16655| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     5848|  2015/2016|Champions League ...|2025-09-04 19:31:15|europe-champions-...|2015-2016|   12857| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7805|  2019/2020|Europa League Grp. K|2025-09-04 19:47:11|europe-europa-league|2019-2020|   17966| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     8178|  2020/2021|Europa League Grp. A|2025-09-04 19:41:52|europe-europa-league|2020-2021|   18981| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     8623|  2021/2022|Champions League ...|2025-09-04 19:18:17|europe-champions-...|2021-2022|   20089| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     8872|  2022/2023|UEFA Nations Leag...|2025-09-04 22:28:26|international-uef...|2022-2023|   21377| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9778|  2023/2024|Europa League Grp. C|2025-09-04 19:35:36|europe-europa-league|2023-2024|   22511| 2025-09-05-12|
# |      247|International|          684|UEFA Nations Leag...|     9981|  2024/2025|UEFA Nations Leag...|2025-09-04 22:01:09|international-uef...|2024-2025|   22912| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     5849|  2015/2016|Europa League Grp. D|2025-09-04 20:17:31|europe-europa-league|2015-2016|   12871| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7353|  2018/2019|Europa League Grp. A|2025-09-04 19:48:21|europe-europa-league|2018-2019|   16677| 2025-09-05-12|
# |      247|International|          686|UEFA Nations Leag...|     8871|  2022/2023|UEFA Nations Leag...|2025-09-05 05:44:53|international-uef...|2022-2023|   20396| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     3768|       2014|World Cup Semi Fi...|2025-09-04 20:25:01|international-fif...|     2014|    7567| 2025-09-05-12|
# |      247|International|          686|UEFA Nations Leag...|     8157|  2020/2021|UEFA Nations Leag...|2025-09-05 05:45:26|international-uef...|2020-2021|   18470| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6843|  2017/2018|Europa League Grp. B|2025-09-04 19:51:45|europe-europa-league|2017-2018|   15491| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6275|  2016/2017|Europa League Grp. D|2025-09-04 19:58:46|europe-europa-league|2016-2017|   14188| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     8177|  2020/2021|Champions League ...|2025-09-04 19:21:17|europe-champions-...|2020-2021|   18977| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7805|  2019/2020|Europa League Grp. G|2025-09-04 19:46:22|europe-europa-league|2019-2020|   17962| 2025-09-05-12|
# |      247|International|          124|European Champion...|     7329|       2020|         EURO Grp. F|2025-09-05 07:03:23|international-eur...|     2020|   16302| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     7213|  2018/2019|UEFA Nations Leag...|2025-09-04 21:55:06|international-uef...|2018-2019|   15942| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     7804|  2019/2020|Champions League ...|2025-09-04 19:23:33|europe-champions-...|2019-2020|   17943| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|    10555|  2025/2026|World Cup Qualifi...|2025-09-04 20:59:25|international-wor...|2025-2026|   23973| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     9982|  2024/2025|UEFA Nations Leag...|2025-09-04 22:17:28|international-uef...|2024-2025|   22914| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     5849|  2015/2016|Europa League Grp. H|2025-09-04 20:18:23|europe-europa-league|2015-2016|   12874| 2025-09-05-12|
# |      247|International|          124|European Champion...|     9299|       2024|         EURO Grp. F|2025-09-05 06:57:43|international-eur...|     2024|   21404| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     8213|       2022|    World Cup Grp. G|2025-09-04 20:21:28|international-fif...|     2022|   18655| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9778|  2023/2024|Europa League Grp. G|2025-09-04 19:36:29|europe-europa-league|2023-2024|   22515| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6275|  2016/2017|Europa League Grp. C|2025-09-04 19:57:28|europe-europa-league|2016-2017|   14184| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     8623|  2021/2022|Champions League ...|2025-09-04 19:19:09|europe-champions-...|2021-2022|   20094| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     9086|  2022/2023|Champions League ...|2025-09-04 19:16:41|europe-champions-...|2022-2023|   20968| 2025-09-05-12|
# |      247|International|          124|European Champion...|     9299|       2024|         EURO Grp. D|2025-09-05 06:57:30|international-eur...|     2024|   21401| 2025-09-05-12|
# |      247|International|          124|European Champion...|     9299|       2024|         EURO Grp. D|2025-09-05 06:56:53|international-eur...|     2024|   23157| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9778|  2023/2024|Europa League Grp. D|2025-09-04 19:35:47|europe-europa-league|2023-2024|   22513| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     8623|  2021/2022|Champions League ...|2025-09-04 19:19:33|europe-champions-...|2021-2022|   20090| 2025-09-05-12|
# |      247|International|          684|UEFA Nations Leag...|     8155|  2020/2021|UEFA Nations Leag...|2025-09-04 22:10:41|international-uef...|2020-2021|   18463| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     5848|  2015/2016|Champions League ...|2025-09-04 19:31:55|europe-champions-...|2015-2016|   12860| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     9664|  2023/2024|Champions League ...|2025-09-04 19:14:06|europe-champions-...|2023-2024|   22492| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     8178|  2020/2021|Europa League Grp. L|2025-09-04 19:44:14|europe-europa-league|2020-2021|   18992| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     5849|  2015/2016|Europa League Grp. B|2025-09-04 20:17:04|europe-europa-league|2015-2016|   12870| 2025-09-05-12|
# |      247|International|          684|UEFA Nations Leag...|     8155|  2020/2021|UEFA Nations Leag...|2025-09-04 22:12:03|international-uef...|2020-2021|   18464| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7353|  2018/2019|Europa League Grp. B|2025-09-04 19:48:33|europe-europa-league|2018-2019|   16678| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     8623|  2021/2022|Champions League ...|2025-09-04 19:18:43|europe-champions-...|2021-2022|   20091| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     7804|  2019/2020|Champions League ...|2025-09-04 19:23:47|europe-champions-...|2019-2020|   17944| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     7804|  2019/2020|Champions League ...|2025-09-04 19:22:30|europe-champions-...|2019-2020|   17938| 2025-09-05-12|
# |      247|International|          684|UEFA Nations Leag...|     8873|  2022/2023|UEFA Nations Leag...|2025-09-04 22:06:21|international-uef...|2022-2023|   20399| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|     8943|  2021/2022|World Cup Qualifi...|2025-09-04 21:12:41|international-wor...|2021-2022|   19187| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     9980|  2024/2025|UEFA Nations Leag...|2025-09-04 21:37:19|international-uef...|2024-2025|   22907| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     8869|  2022/2023|UEFA Nations Leag...|2025-09-04 21:41:35|international-uef...|2022-2023|   20390| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     8156|  2020/2021|UEFA Nations Leag...|2025-09-04 22:34:42|international-uef...|2020-2021|   19111| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     5849|  2015/2016|Europa League Grp. C|2025-09-04 20:17:19|europe-europa-league|2015-2016|   12876| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6843|  2017/2018|Europa League Grp. J|2025-09-04 19:53:27|europe-europa-league|2017-2018|   15501| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     8156|  2020/2021|UEFA Nations Leag...|2025-09-04 22:29:08|international-uef...|2020-2021|   18466| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     8177|  2020/2021|Champions League ...|2025-09-04 19:20:12|europe-champions-...|2020-2021|   18972| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     5967|       2018|    World Cup Grp. G|2025-09-04 20:22:42|international-fif...|     2018|   12757| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|     8943|  2021/2022|World Cup Qualifi...|2025-09-04 21:14:44|international-wor...|2021-2022|   19188| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9087|  2022/2023|Europa League Grp. A|2025-09-04 19:37:25|europe-europa-league|2022-2023|   20971| 2025-09-05-12|
# |      247|International|          684|UEFA Nations Leag...|     8155|  2020/2021|UEFA Nations Leag...|2025-09-04 22:07:52|international-uef...|2020-2021|   18461| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9087|  2022/2023|Europa League Grp. D|2025-09-04 19:38:04|europe-europa-league|2022-2023|   20973| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     5967|       2018|World Cup Semi Fi...|2025-09-04 20:23:13|international-fif...|     2018|   12761| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7805|  2019/2020|Europa League Grp. I|2025-09-04 19:46:45|europe-europa-league|2019-2020|   17964| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9087|  2022/2023|Europa League Grp. F|2025-09-04 19:38:30|europe-europa-league|2022-2023|   20977| 2025-09-05-12|
# |      247|International|          124|European Champion...|     4246|       2016|    EURO Semi Finals|2025-09-05 07:05:23|international-eur...|     2016|    8995| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7353|  2018/2019|Europa League Grp. G|2025-09-04 19:49:39|europe-europa-league|2018-2019|   16682| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     8213|       2022|    World Cup Grp. B|2025-09-04 20:20:51|international-fif...|     2022|   18650| 2025-09-05-12|
# |       74|       France|           22|             Ligue 1|     7814|  2019/2020|             Ligue 1|2025-09-04 18:31:05|      france-ligue-1|2019-2020|   17593| 2025-09-05-12|
# |      206|        Spain|            4|              LaLiga|     8681|  2021/2022|              LaLiga|2025-09-04 18:37:40|        spain-laliga|2021-2022|   19895| 2025-09-05-12|
# |      206|        Spain|            4|              LaLiga|     8321|  2020/2021|              LaLiga|2025-09-04 18:38:17|        spain-laliga|2020-2021|   18851| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|     8943|  2021/2022|World Cup Qualifi...|2025-09-04 21:22:30|international-wor...|2021-2022|   19191| 2025-09-05-12|
# |      247|International|          124|European Champion...|     4246|       2016|     EURO 1/8 Finals|2025-09-05 07:05:06|international-eur...|     2016|    8994| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|     8943|  2021/2022|World Cup Qualifi...|2025-09-04 21:25:37|international-wor...|2021-2022|   19192| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|     8943|  2021/2022|World Cup Qualifi...|2025-09-04 21:28:39|international-wor...|2021-2022|   19193| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|     8943|  2021/2022|World Cup Qualifi...|2025-09-04 21:16:46|international-wor...|2021-2022|   19189| 2025-09-05-12|
# |      250|       Europe|          751|European Champion...|    10118|       2023|EURO Qualificatio...|2025-09-04 20:51:45|europe-european-c...|     2023|   21414| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|    10555|  2025/2026|World Cup Qualifi...|2025-09-04 21:04:52|international-wor...|2025-2026|   23979| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|    10555|  2025/2026|World Cup Qualifi...|2025-09-04 20:58:11|international-wor...|2025-2026|   23969| 2025-09-05-12|
# |      250|       Europe|          751|European Champion...|    10118|       2023|EURO Qualificatio...|2025-09-04 20:46:06|europe-european-c...|     2023|   21412| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|    10555|  2025/2026|World Cup Qualifi...|2025-09-04 20:58:28|international-wor...|2025-2026|   23970| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|    10555|  2025/2026|World Cup Qualifi...|2025-09-04 20:57:24|international-wor...|2025-2026|   24262| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|    10555|  2025/2026|World Cup Qualifi...|2025-09-04 21:02:48|international-wor...|2025-2026|   23977| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|    10555|  2025/2026|World Cup Qualifi...|2025-09-04 20:57:45|international-wor...|2025-2026|   23968| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|    10555|  2025/2026|World Cup Qualifi...|2025-09-04 20:59:42|international-wor...|2025-2026|   23974| 2025-09-05-12|
# |      247|International|          686|UEFA Nations Leag...|     7216|  2018/2019|UEFA Nations Leag...|2025-09-05 05:47:12|international-uef...|2018-2019|   15955| 2025-09-05-12|
# |      250|       Europe|          751|European Champion...|    10118|       2023|EURO Qualificatio...|2025-09-04 20:32:00|europe-european-c...|     2023|   21405| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     9980|  2024/2025|UEFA Nations Leag...|2025-09-04 21:33:01|international-uef...|2024-2025|   23839| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|    10555|  2025/2026|World Cup Qualifi...|2025-09-04 21:01:50|international-wor...|2025-2026|   23976| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|    10555|  2025/2026|World Cup Qualifi...|2025-09-04 20:58:57|international-wor...|2025-2026|   23972| 2025-09-05-12|
# |      250|       Europe|          751|European Champion...|    10118|       2023|EURO Qualificatio...|2025-09-04 20:44:05|europe-european-c...|     2023|   21411| 2025-09-05-12|
# |      247|International|          684|UEFA Nations Leag...|     9981|  2024/2025|UEFA Nations Leag...|2025-09-04 21:59:50|international-uef...|2024-2025|   22911| 2025-09-05-12|
# |      247|International|          124|European Champion...|     4246|       2016| EURO Quarter Finals|2025-09-05 07:05:13|international-eur...|     2016|    8993| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     8154|  2020/2021|UEFA Nations Leag...|2025-09-04 21:51:42|international-uef...|2020-2021|   19105| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     3768|       2014|    World Cup grp. A|2025-09-04 20:23:50|international-fif...|     2014|    7557| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     8156|  2020/2021|UEFA Nations Leag...|2025-09-04 22:33:19|international-uef...|2020-2021|   18468| 2025-09-05-12|
# |      247|International|          124|European Champion...|     4246|       2016|         EURO Grp. F|2025-09-05 07:04:59|international-eur...|     2016|    8992| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7805|  2019/2020|Europa League Grp. F|2025-09-04 19:46:08|europe-europa-league|2019-2020|   17961| 2025-09-05-12|
# |      250|       Europe|          751|European Champion...|    10118|       2023|EURO Qualificatio...|2025-09-04 20:49:00|europe-european-c...|     2023|   21413| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     7213|  2018/2019|UEFA Nations Leag...|2025-09-04 21:53:27|international-uef...|2018-2019|   15940| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     3768|       2014|    World Cup grp. F|2025-09-04 20:24:26|international-fif...|     2014|    7562| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     6349|  2016/2017|Champions League ...|2025-09-04 19:29:04|europe-champions-...|2016-2017|   14167| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     8213|       2022|    World Cup Grp. E|2025-09-04 20:21:11|international-fif...|     2022|   18653| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     8623|  2021/2022|Champions League ...|2025-09-04 19:18:06|europe-champions-...|2021-2022|   20088| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     5849|  2015/2016|Europa League Grp. E|2025-09-04 20:17:42|europe-europa-league|2015-2016|   12872| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     6842|  2017/2018|Champions League ...|2025-09-04 19:27:36|europe-champions-...|2017-2018|   15489| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     7804|  2019/2020|Champions League ...|2025-09-04 19:22:44|europe-champions-...|2019-2020|   17939| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     5849|  2015/2016|Europa League Grp. L|2025-09-04 20:19:12|europe-europa-league|2015-2016|   12878| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7805|  2019/2020|Europa League Grp. L|2025-09-04 19:47:25|europe-europa-league|2019-2020|   17967| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7353|  2018/2019|Europa League Grp. L|2025-09-04 19:50:44|europe-europa-league|2018-2019|   16688| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     7804|  2019/2020|Champions League ...|2025-09-04 19:22:18|europe-champions-...|2019-2020|   17937| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7353|  2018/2019|Europa League Grp. H|2025-09-04 19:49:54|europe-europa-league|2018-2019|   16684| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     9664|  2023/2024|Champions League ...|2025-09-04 19:14:56|europe-champions-...|2023-2024|   22495| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     6842|  2017/2018|Champions League ...|2025-09-04 19:28:14|europe-champions-...|2017-2018|   15488| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     5849|  2015/2016|Europa League Grp. K|2025-09-04 20:19:01|europe-europa-league|2015-2016|   12880| 2025-09-05-12|
# |      247|International|           67| FIFA Club World Cup|    10539|       2025|FIFA Club World C...|2025-09-04 20:26:31|international-fif...|     2025|   23865| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9778|  2023/2024|Europa League Grp. F|2025-09-04 19:36:15|europe-europa-league|2023-2024|   22517| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     9086|  2022/2023|Champions League ...|2025-09-04 19:16:16|europe-champions-...|2022-2023|   20963| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     3768|       2014|    World Cup grp. C|2025-09-04 20:24:03|international-fif...|     2014|    7559| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     5849|  2015/2016|Europa League Grp. J|2025-09-04 20:18:46|europe-europa-league|2015-2016|   12877| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9087|  2022/2023|Europa League Grp. C|2025-09-04 19:37:52|europe-europa-league|2022-2023|   20978| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     5848|  2015/2016|Champions League ...|2025-09-04 19:31:30|europe-champions-...|2015-2016|   12858| 2025-09-05-12|
# |      250|       Europe|          751|European Champion...|    10118|       2023|EURO Qualificatio...|2025-09-04 20:42:14|europe-european-c...|     2023|   21410| 2025-09-05-12|
# |      247|International|          124|European Champion...|     3164|       2012|         EURO Grp. B|2025-09-05 07:06:06|international-eur...|     2012|    5981| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     8213|       2022|World Cup Final S...|2025-09-04 20:20:35|international-fif...|     2022|   18657| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     8869|  2022/2023|UEFA Nations Leag...|2025-09-04 21:45:12|international-uef...|2022-2023|   21378| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     8872|  2022/2023|UEFA Nations Leag...|2025-09-04 22:27:09|international-uef...|2022-2023|   20403| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     8872|  2022/2023|UEFA Nations Leag...|2025-09-04 22:25:50|international-uef...|2022-2023|   20397| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     9980|  2024/2025|UEFA Nations Leag...|2025-09-04 21:34:36|international-uef...|2024-2025|   22905| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     8872|  2022/2023|UEFA Nations Leag...|2025-09-04 22:23:00|international-uef...|2022-2023|   20395| 2025-09-05-12|
# |      247|International|          684|UEFA Nations Leag...|     9981|  2024/2025|UEFA Nations Leag...|2025-09-04 21:58:23|international-uef...|2024-2025|   22910| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     3768|       2014|    World Cup grp. B|2025-09-04 20:23:56|international-fif...|     2014|    7558| 2025-09-05-12|
# |      247|International|          721|World Cup Qualifi...|     8943|  2021/2022|World Cup Qualifi...|2025-09-04 21:06:16|international-wor...|2021-2022|   19177| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     5967|       2018|    World Cup Grp. A|2025-09-04 20:21:59|international-fif...|     2018|   12751| 2025-09-05-12|
# |      247|International|          684|UEFA Nations Leag...|     8873|  2022/2023|UEFA Nations Leag...|2025-09-04 22:05:00|international-uef...|2022-2023|   20402| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     8869|  2022/2023|UEFA Nations Leag...|2025-09-04 21:40:10|international-uef...|2022-2023|   20389| 2025-09-05-12|
# |      250|       Europe|          751|European Champion...|    10118|       2023|EURO Qualificatio...|2025-09-04 20:36:23|europe-european-c...|     2023|   21407| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     5967|       2018|World Cup Quarter...|2025-09-04 20:23:06|international-fif...|     2018|   12760| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     9982|  2024/2025|UEFA Nations Leag...|2025-09-04 22:18:57|international-uef...|2024-2025|   22913| 2025-09-05-12|
# |      247|International|          124|European Champion...|     7329|       2020|         EURO Grp. A|2025-09-05 06:59:55|international-eur...|     2020|   16297| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     9980|  2024/2025|UEFA Nations Leag...|2025-09-04 21:38:39|international-uef...|2024-2025|   22908| 2025-09-05-12|
# |      247|International|          124|European Champion...|     7329|       2020|         EURO Grp. B|2025-09-05 07:00:37|international-eur...|     2020|   16298| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     8869|  2022/2023|UEFA Nations Leag...|2025-09-04 21:42:52|international-uef...|2022-2023|   20391| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     7215|  2018/2019|UEFA Nations Leag...|2025-09-04 22:37:55|international-uef...|2018-2019|   15949| 2025-09-05-12|
# |      247|International|          124|European Champion...|     3164|       2012|         EURO Grp. C|2025-09-05 07:06:14|international-eur...|     2012|    5982| 2025-09-05-12|
# |      247|International|          686|UEFA Nations Leag...|     8871|  2022/2023|UEFA Nations Leag...|2025-09-05 05:44:38|international-uef...|2022-2023|   20394| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     9982|  2024/2025|UEFA Nations Leag...|2025-09-04 22:20:13|international-uef...|2024-2025|   22915| 2025-09-05-12|
# |      247|International|          124|European Champion...|     7329|       2020|         EURO Grp. C|2025-09-05 07:01:18|international-eur...|     2020|   16299| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     7213|  2018/2019|UEFA Nations Leag...|2025-09-04 21:55:56|international-uef...|2018-2019|   16804| 2025-09-05-12|
# |      247|International|           67| FIFA Club World Cup|    10539|       2025|FIFA Club World C...|2025-09-04 20:26:54|international-fif...|     2025|   23868| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     9664|  2023/2024|Champions League ...|2025-09-04 19:14:44|europe-champions-...|2023-2024|   22496| 2025-09-05-12|
# |      247|International|          683|UEFA Nations Leag...|     8154|  2020/2021|UEFA Nations Leag...|2025-09-04 21:46:02|international-uef...|2020-2021|   18457| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     8178|  2020/2021|Europa League Grp. K|2025-09-04 19:44:02|europe-europa-league|2020-2021|   18991| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9778|  2023/2024|Europa League Grp. B|2025-09-04 19:35:23|europe-europa-league|2023-2024|   22512| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     8213|       2022|    World Cup Grp. C|2025-09-04 20:20:57|international-fif...|     2022|   18651| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     6842|  2017/2018|Champions League ...|2025-09-04 19:26:47|europe-champions-...|2017-2018|   15482| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     5848|  2015/2016|Champions League ...|2025-09-04 19:31:42|europe-champions-...|2015-2016|   12859| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     9664|  2023/2024|Champions League ...|2025-09-04 19:13:52|europe-champions-...|2023-2024|   22489| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6843|  2017/2018|Europa League Grp. G|2025-09-04 19:52:50|europe-europa-league|2017-2018|   15498| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     8213|       2022|    World Cup Grp. H|2025-09-04 20:21:34|international-fif...|     2022|   18654| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     9664|  2023/2024|Champions League ...|2025-09-04 19:14:33|europe-champions-...|2023-2024|   22493| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     5849|  2015/2016|Europa League Grp. G|2025-09-04 20:18:09|europe-europa-league|2015-2016|   12875| 2025-09-05-12|
# |      247|International|          124|European Champion...|     4246|       2016|         EURO Grp. D|2025-09-05 07:04:42|international-eur...|     2016|    8990| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9087|  2022/2023|Europa League Grp. G|2025-09-04 19:38:41|europe-europa-league|2022-2023|   20976| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     5848|  2015/2016|Champions League ...|2025-09-04 19:32:19|europe-champions-...|2015-2016|   12862| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     6842|  2017/2018|Champions League ...|2025-09-04 19:26:58|europe-champions-...|2017-2018|   15483| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9087|  2022/2023|Europa League Grp. B|2025-09-04 19:37:39|europe-europa-league|2022-2023|   20972| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     8623|  2021/2022|Champions League ...|2025-09-04 19:18:55|europe-champions-...|2021-2022|   20095| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     5967|       2018|    World Cup Grp. F|2025-09-04 20:22:36|international-fif...|     2018|   12756| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6275|  2016/2017|Europa League Grp. B|2025-09-04 19:56:03|europe-europa-league|2016-2017|   14187| 2025-09-05-12|
# |      247|International|          124|European Champion...|     7329|       2020|         EURO Grp. D|2025-09-05 07:01:59|international-eur...|     2020|   16301| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6275|  2016/2017|Europa League Grp. K|2025-09-04 20:08:01|europe-europa-league|2016-2017|   14178| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     8213|       2022|    World Cup Grp. A|2025-09-04 20:20:42|international-fif...|     2022|   18649| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     8178|  2020/2021|Europa League Grp. C|2025-09-04 19:42:18|europe-europa-league|2020-2021|   18983| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     5848|  2015/2016|Champions League ...|2025-09-04 19:32:46|europe-champions-...|2015-2016|   12864| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     7352|  2018/2019|Champions League ...|2025-09-04 19:25:33|europe-champions-...|2018-2019|   16656| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7805|  2019/2020|Europa League Grp. B|2025-09-04 19:45:19|europe-europa-league|2019-2020|   17957| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7805|  2019/2020|Europa League Grp. H|2025-09-04 19:46:34|europe-europa-league|2019-2020|   17963| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     9086|  2022/2023|Champions League ...|2025-09-04 19:16:02|europe-champions-...|2022-2023|   20962| 2025-09-05-12|
# |      247|International|          684|UEFA Nations Leag...|     7214|  2018/2019|UEFA Nations Leag...|2025-09-04 22:16:16|international-uef...|2018-2019|   15946| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     8741|  2021/2022|Europa League Grp. D|2025-09-04 19:40:12|europe-europa-league|2021-2022|   20107| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     7353|  2018/2019|Europa League Grp. K|2025-09-04 19:50:31|europe-europa-league|2018-2019|   16686| 2025-09-05-12|
# |      247|International|          124|European Champion...|     3164|       2012|    EURO Semi finals|2025-09-05 07:06:38|international-eur...|     2012|    5976| 2025-09-05-12|
# |      247|International|          124|European Champion...|     3164|       2012|         EURO Grp. D|2025-09-05 07:06:21|international-eur...|     2012|    5983| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     8213|       2022|    World Cup Grp. F|2025-09-04 20:21:21|international-fif...|     2022|   18656| 2025-09-05-12|
# |      247|International|          684|UEFA Nations Leag...|     8873|  2022/2023|UEFA Nations Leag...|2025-09-04 22:04:07|international-uef...|2022-2023|   20401| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6275|  2016/2017|Europa League Grp. A|2025-09-04 19:54:35|europe-europa-league|2016-2017|   14186| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     6842|  2017/2018|Champions League ...|2025-09-04 19:27:10|europe-champions-...|2017-2018|   15485| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     5848|  2015/2016|Champions League ...|2025-09-04 19:32:34|europe-champions-...|2015-2016|   12863| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     8156|  2020/2021|UEFA Nations Leag...|2025-09-04 22:32:00|international-uef...|2020-2021|   18469| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9087|  2022/2023|Europa League Grp. E|2025-09-04 19:38:18|europe-europa-league|2022-2023|   20974| 2025-09-05-12|
# |      247|International|          124|European Champion...|     4246|       2016|         EURO Grp. C|2025-09-05 07:04:34|international-eur...|     2016|    8989| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     8213|       2022|    World Cup Grp. D|2025-09-04 20:21:04|international-fif...|     2022|   18652| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     5849|  2015/2016|Europa League Grp. I|2025-09-04 20:18:35|europe-europa-league|2015-2016|   12879| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     7352|  2018/2019|Champions League ...|2025-09-04 19:24:28|europe-champions-...|2018-2019|   16652| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     5967|       2018|    World Cup Grp. H|2025-09-04 20:22:49|international-fif...|     2018|   12758| 2025-09-05-12|
# ...
# |      250|       Europe|           12|    Champions League|     9086|  2022/2023|Champions League ...|2025-09-04 19:16:29|europe-champions-...|2022-2023|   20966| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     6349|  2016/2017|Champions League ...|2025-09-04 19:30:05|europe-champions-...|2016-2017|   14172| 2025-09-05-12|
# |      247|International|          686|UEFA Nations Leag...|     7216|  2018/2019|UEFA Nations Leag...|2025-09-05 05:46:38|international-uef...|2018-2019|   15954| 2025-09-05-12|
# |      247|International|          684|UEFA Nations Leag...|     7214|  2018/2019|UEFA Nations Leag...|2025-09-04 22:13:48|international-uef...|2018-2019|   15943| 2025-09-05-12|
# |      247|International|          685|UEFA Nations Leag...|     7215|  2018/2019|UEFA Nations Leag...|2025-09-04 22:39:15|international-uef...|2018-2019|   15950| 2025-09-05-12|
# |      247|International|          684|UEFA Nations Leag...|     9981|  2024/2025|UEFA Nations Leag...|2025-09-04 21:57:00|international-uef...|2024-2025|   22909| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     5849|  2015/2016|Europa League Grp. F|2025-09-04 20:17:57|europe-europa-league|2015-2016|   12873| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     5967|       2018|    World Cup Grp. E|2025-09-04 20:22:27|international-fif...|     2018|   12755| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     9086|  2022/2023|Champions League ...|2025-09-04 19:15:50|europe-champions-...|2022-2023|   20961| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9087|  2022/2023|Europa League Grp. H|2025-09-04 19:38:55|europe-europa-league|2022-2023|   20975| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6843|  2017/2018|Europa League Grp. F|2025-09-04 19:52:35|europe-europa-league|2017-2018|   15495| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6843|  2017/2018|Europa League Grp. L|2025-09-04 19:53:53|europe-europa-league|2017-2018|   15499| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6275|  2016/2017|Europa League Grp. J|2025-09-04 20:06:45|europe-europa-league|2016-2017|   14179| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     3768|       2014|World Cup Bronze ...|2025-09-04 20:25:07|international-fif...|     2014|    7568| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6843|  2017/2018|Europa League Fin...|2025-09-04 19:54:05|europe-europa-league|2017-2018|   15617| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     9664|  2023/2024|Champions League ...|2025-09-04 19:13:28|europe-champions-...|2023-2024|   22686| 2025-09-05-12|
# |      247|International|          686|UEFA Nations Leag...|     8157|  2020/2021|UEFA Nations Leag...|2025-09-05 05:45:38|international-uef...|2020-2021|   18471| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     5967|       2018|World Cup Bronze ...|2025-09-04 20:23:20|international-fif...|     2018|   12762| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     6275|  2016/2017|Europa League Fin...|2025-09-04 20:10:35|europe-europa-league|2016-2017|   14368| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     8178|  2020/2021|Europa League Fin...|2025-09-04 19:41:40|europe-europa-league|2020-2021|   19164| 2025-09-05-12|
# |      247|International|          684|UEFA Nations Leag...|     7214|  2018/2019|UEFA Nations Leag...|2025-09-04 22:14:40|international-uef...|2018-2019|   15944| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     8741|  2021/2022|Europa League Fin...|2025-09-04 19:39:23|europe-europa-league|2021-2022|   20266| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     7352|  2018/2019|Champions League ...|2025-09-04 19:26:11|europe-champions-...|2018-2019|   16651| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     5848|  2015/2016|Champions League ...|2025-09-04 19:32:58|europe-champions-...|2015-2016|   13185| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|     9087|  2022/2023|Europa League Fin...|2025-09-04 19:37:13|europe-europa-league|2022-2023|   20979| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     8623|  2021/2022|Champions League ...|2025-09-04 19:17:51|europe-champions-...|2021-2022|   20265| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|    10458|  2024/2025|Europa League Fin...|2025-09-04 19:34:05|europe-europa-league|2024-2025|   24084| 2025-09-05-12|
# |      250|       Europe|          751|European Champion...|    10295|  2022/2023|UEFA Nations Leag...|2025-09-04 20:54:58|europe-european-c...|2022-2023|   22715| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     8177|  2020/2021|Champions League ...|2025-09-04 19:20:01|europe-champions-...|2020-2021|   19130| 2025-09-05-12|
# |      250|       Europe|          751|European Champion...|    10295|  2022/2023|UEFA Nations Leag...|2025-09-04 20:56:21|europe-european-c...|2022-2023|   22712| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|     9086|  2022/2023|Champions League ...|2025-09-04 19:15:35|europe-champions-...|2022-2023|   20969| 2025-09-05-12|
# |      247|International|           36|      FIFA World Cup|     3768|       2014|     World Cup Final|2025-09-04 20:25:14|international-fif...|     2014|    7569| 2025-09-05-12|
# |      247|International|          686|UEFA Nations Leag...|     9983|  2024/2025|UEFA Nations Leag...|2025-09-05 05:44:10|international-uef...|2024-2025|   22918| 2025-09-05-12|
# |      247|International|          124|European Champion...|     4246|       2016|          EURO Final|2025-09-05 07:05:30|international-eur...|     2016|    8996| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|    10903|  2025/2026|    Champions League|2025-09-04 19:12:16|europe-champions-...|2025-2026|   24796| 2025-09-05-12|
# |      108|        Italy|            5|             Serie A|     7928|  2019/2020|             Serie A|2025-09-04 18:24:31|       italy-serie-a|2019-2020|   17835| 2025-09-05-12|
# |      206|        Spain|            4|              LaLiga|     7889|  2019/2020|              LaLiga|2025-09-04 19:08:44|        spain-laliga|2019-2020|   17702| 2025-09-05-12|
# |      252|      England|            2|      Premier League|     8228|  2020/2021|      Premier League|2025-09-04 18:16:48|england-premier-l...|2020-2021|   18685| 2025-09-05-12|
# |      250|       Europe|           12|    Champions League|    10456|  2024/2025|    Champions League|2025-09-04 19:12:44|europe-champions-...|2024-2025|   23663| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|    10458|  2024/2025|       Europa League|2025-09-04 19:34:20|europe-europa-league|2024-2025|   23665| 2025-09-05-12|
# |      252|      England|            2|      Premier League|    10743|  2025/2026|      Premier League|2025-09-04 18:13:45|england-premier-l...|2025-2026|   24533| 2025-09-05-12|
# |      206|        Spain|            4|              LaLiga|    10803|  2025/2026|              LaLiga|2025-09-04 18:34:23|        spain-laliga|2025-2026|   24622| 2025-09-05-12|
# |      108|        Italy|            5|             Serie A|    10732|  2025/2026|             Serie A|2025-09-04 18:20:29|       italy-serie-a|2025-2026|   24500| 2025-09-05-12|
# |      252|      England|            2|      Premier League|     8618|  2021/2022|      Premier League|2025-09-04 18:16:18|england-premier-l...|2021-2022|   19793| 2025-09-05-12|
# |      252|      England|            2|      Premier League|     6829|  2017/2018|      Premier League|2025-09-04 18:18:45|england-premier-l...|2017-2018|   15151| 2025-09-05-12|
# |      252|      England|            2|      Premier League|     6335|  2016/2017|      Premier League|2025-09-04 18:19:19|england-premier-l...|2016-2017|   13796| 2025-09-05-12|
# |      252|      England|            2|      Premier League|     7811|  2019/2020|      Premier League|2025-09-04 18:17:27|england-premier-l...|2019-2020|   17590| 2025-09-05-12|
# |      252|      England|            2|      Premier League|     9618|  2023/2024|      Premier League|2025-09-04 18:15:09|england-premier-l...|2023-2024|   22076| 2025-09-05-12|
# |       74|       France|           22|             Ligue 1|    10792|  2025/2026|             Ligue 1|2025-09-04 18:27:12|      france-ligue-1|2025-2026|   24609| 2025-09-05-12|
# |       81|      Germany|            3|          Bundesliga|    10720|  2025/2026|          Bundesliga|2025-09-04 18:07:23|  germany-bundesliga|2025-2026|   24478| 2025-09-05-12|
# |      252|      England|            2|      Premier League|     9075|  2022/2023|      Premier League|2025-09-04 18:15:42|england-premier-l...|2022-2023|   20934| 2025-09-05-12|
# |      252|      England|            2|      Premier League|    10316|  2024/2025|      Premier League|2025-09-04 18:14:39|england-premier-l...|2024-2025|   23400| 2025-09-05-12|
# |      206|        Spain|            4|              LaLiga|     6436|  2016/2017|              LaLiga|2025-09-04 19:10:39|        spain-laliga|2016-2017|   13955| 2025-09-05-12|
# |      108|        Italy|            5|             Serie A|     6461|  2016/2017|             Serie A|2025-09-04 18:26:03|       italy-serie-a|2016-2017|   14014| 2025-09-05-12|
# |       74|       France|           22|             Ligue 1|     9635|  2023/2024|             Ligue 1|2025-09-04 18:28:54|      france-ligue-1|2023-2024|   22105| 2025-09-05-12|
# |      108|        Italy|            5|             Serie A|     5970|  2015/2016|             Serie A|2025-09-04 18:26:38|       italy-serie-a|2015-2016|   12770| 2025-09-05-12|
# |       74|       France|           22|             Ligue 1|     8671|  2021/2022|             Ligue 1|2025-09-04 18:29:59|      france-ligue-1|2021-2022|   19866| 2025-09-05-12|
# |       81|      Germany|            3|          Bundesliga|     7405|  2018/2019|       1. Bundesliga|2025-09-04 18:11:20|  germany-bundesliga|2018-2019|   16427| 2025-09-05-12|
# |      108|        Italy|            5|             Serie A|    10375|  2024/2025|             Serie A|2025-09-04 18:21:22|       italy-serie-a|2024-2025|   23490| 2025-09-05-12|
# |      252|      England|            2|      Premier League|     7361|  2018/2019|      Premier League|2025-09-04 18:18:06|england-premier-l...|2018-2019|   16368| 2025-09-05-12|
# |      108|        Italy|            5|             Serie A|     9159|  2022/2023|             Serie A|2025-09-04 18:22:30|       italy-serie-a|2022-2023|   21087| 2025-09-05-12|
# |      250|       Europe|           30|       Europa League|    10904|  2025/2026|       Europa League|2025-09-04 19:33:31|europe-europa-league|2025-2026|   24798| 2025-09-05-12|
# |       74|       France|           22|             Ligue 1|    10329|  2024/2025|             Ligue 1|2025-09-04 18:28:15|      france-ligue-1|2024-2025|   23414| 2025-09-05-12|
# |       74|       France|           22|             Ligue 1|     5830|  2015/2016|             Ligue 1|2025-09-04 18:33:53|      france-ligue-1|2015-2016|   12501| 2025-09-05-12|
# |      206|        Spain|            4|              LaLiga|     5933|  2015/2016|    Primera Division|2025-09-04 19:11:34|        spain-laliga|2015-2016|   12647| 2025-09-05-12|
# |      108|        Italy|            5|             Serie A|     8330|  2020/2021|             Serie A|2025-09-04 18:23:50|       italy-serie-a|2020-2021|   18873| 2025-09-05-12|
# |       81|      Germany|            3|          Bundesliga|     9649|  2023/2024|          Bundesliga|2025-09-04 18:08:29|  germany-bundesliga|2023-2024|   22128| 2025-09-05-12|
# |      206|        Spain|            4|              LaLiga|     9682|  2023/2024|              LaLiga|2025-09-04 18:36:17|        spain-laliga|2023-2024|   22176| 2025-09-05-12|
# |       74|       France|           22|             Ligue 1|     6318|  2016/2017|             Ligue 1|2025-09-04 18:33:13|      france-ligue-1|2016-2017|   13768| 2025-09-05-12|
# |       81|      Germany|            3|          Bundesliga|     6902|  2017/2018|       1. Bundesliga|2025-09-04 18:11:59|  germany-bundesliga|2017-2018|   15243| 2025-09-05-12|
# |      108|        Italy|            5|             Serie A|     7468|  2018/2019|             Serie A|2025-09-04 18:25:08|       italy-serie-a|2018-2019|   16548| 2025-09-05-12|
# |      108|        Italy|            5|             Serie A|     6974|  2017/2018|             Serie A|2025-09-04 18:25:33|       italy-serie-a|2017-2018|   15404| 2025-09-05-12|
# |       81|      Germany|            3|          Bundesliga|     6392|  2016/2017|       1. Bundesliga|2025-09-04 18:12:38|  germany-bundesliga|2016-2017|   13872| 2025-09-05-12|
# |      206|        Spain|            4|              LaLiga|     9149|  2022/2023|              LaLiga|2025-09-04 18:37:00|        spain-laliga|2022-2023|   21073| 2025-09-05-12|
# |      206|        Spain|            4|              LaLiga|     6960|  2017/2018|              LaLiga|2025-09-04 19:10:02|        spain-laliga|2017-2018|   15375| 2025-09-05-12|
# |      206|        Spain|            4|              LaLiga|     7466|  2018/2019|              LaLiga|2025-09-04 19:09:28|        spain-laliga|2018-2019|   16546| 2025-09-05-12|
# |       81|      Germany|            3|          Bundesliga|     8279|  2020/2021|       1. Bundesliga|2025-09-04 18:10:14|  germany-bundesliga|2020-2021|   18762| 2025-09-05-12|
# |       81|      Germany|            3|          Bundesliga|     7872|  2019/2020|       1. Bundesliga|2025-09-04 18:10:44|  germany-bundesliga|2019-2020|   17682| 2025-09-05-12|
# |       74|       France|           22|             Ligue 1|     9129|  2022/2023|             Ligue 1|2025-09-04 18:29:26|      france-ligue-1|2022-2023|   21037| 2025-09-05-12|
# |       74|       France|           22|             Ligue 1|     6833|  2017/2018|             Ligue 1|2025-09-04 18:32:19|      france-ligue-1|2017-2018|   15155| 2025-09-05-12|
# |       81|      Germany|            3|          Bundesliga|     8667|  2021/2022|       1. Bundesliga|2025-09-04 18:09:44|  germany-bundesliga|2021-2022|   19862| 2025-09-05-12|
# |      206|        Spain|            4|              LaLiga|    10317|  2024/2025|              LaLiga|2025-09-04 18:35:42|        spain-laliga|2024-2025|   23401| 2025-09-05-12|
# |       81|      Germany|            3|          Bundesliga|    10365|  2024/2025|          Bundesliga|2025-09-04 18:07:57|  germany-bundesliga|2024-2025|   23471| 2025-09-05-12|
# |       74|       France|           22|             Ligue 1|     7344|  2018/2019|             Ligue 1|2025-09-04 18:31:41|      france-ligue-1|2018-2019|   16348| 2025-09-05-12|
# |      108|        Italy|            5|             Serie A|     8735|  2021/2022|             Serie A|2025-09-04 18:23:12|       italy-serie-a|2021-2022|   19982| 2025-09-05-12|
# |       81|      Germany|            3|          Bundesliga|     5870|  2015/2016|       1. Bundesliga|2025-09-04 18:13:13|  germany-bundesliga|2015-2016|   12559| 2025-09-05-12|
# |       81|      Germany|            3|          Bundesliga|     9120|  2022/2023|          Bundesliga|2025-09-04 18:09:06|  germany-bundesliga|2022-2023|   21026| 2025-09-05-12|
# |       74|       France|           22|             Ligue 1|     8185|  2020/2021|             Ligue 1|2025-09-04 18:30:31|      france-ligue-1|2020-2021|   18594| 2025-09-05-12|
# +---------+-------------+-------------+--------------------+---------+-----------+--------------------+-------------------+--------------------+---------+--------+--------------+

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType
from pyspark.sql.functions import asc, desc, col

stage_schemas = StructType([
    StructField("metadata", StructType([
        StructField("crawled_at", StringType(), True),
    ]), True),
    
    StructField("data", StructType([
        # Your original schema, now nested under the 'data' field
        StructField("regionId", IntegerType(), True),
        StructField("regionName", StringType(), True),
        StructField("tournamentId", IntegerType(), True),
        StructField("tournamentName", StringType(), True),
        StructField("seasonId", IntegerType(), True),
        StructField("seasonName", StringType(), True),
        StructField("stageName", StringType(), True)
    ]), True)
])

dim_stages_df = spark.read \
    .option("modifiedAfter", last_crawl_time) \
    .schema(stage_schemas) \
    .json(STAGE_PATH)

dim_stages_df = flatten_df(
    dim_stages_df
    .select(
        "data.*",
        "metadata.crawled_at",
        "league",
        "season",
        "stage_id"
    )
)

# %%
dim_stages_df.printSchema()
print(dim_stages_df.count())
dim_stages_df.show(truncate=False)
# Out:
# root
#  |-- region_id: integer (nullable = true)
#  |-- region_name: string (nullable = true)
#  |-- tournament_id: integer (nullable = true)
#  |-- tournament_name: string (nullable = true)
#  |-- season_id: integer (nullable = true)
#  |-- season_name: string (nullable = true)
#  |-- stage_name: string (nullable = true)
#  |-- crawled_at: string (nullable = true)
#  |-- league: string (nullable = true)
#  |-- season: string (nullable = true)
#  |-- stage_id: integer (nullable = true)
# 426
# +---------+-----------+-------------+----------------+---------+-----------+----------------+-------------------+-----------------------+---------+--------+
# |region_id|region_name|tournament_id|tournament_name |season_id|season_name|stage_name      |crawled_at         |league                 |season   |stage_id|
# +---------+-----------+-------------+----------------+---------+-----------+----------------+-------------------+-----------------------+---------+--------+
# |250      |Europe     |12           |Champions League|10903    |2025/2026  |Champions League|2025-09-04 19:12:16|europe-champions-league|2025-2026|24796   |
# |108      |Italy      |5            |Serie A         |7928     |2019/2020  |Serie A         |2025-09-04 18:24:31|italy-serie-a          |2019-2020|17835   |
# |206      |Spain      |4            |LaLiga          |7889     |2019/2020  |LaLiga          |2025-09-04 19:08:44|spain-laliga           |2019-2020|17702   |
# |252      |England    |2            |Premier League  |8228     |2020/2021  |Premier League  |2025-09-04 18:16:48|england-premier-league |2020-2021|18685   |
# |250      |Europe     |12           |Champions League|10456    |2024/2025  |Champions League|2025-09-04 19:12:44|europe-champions-league|2024-2025|23663   |
# |250      |Europe     |30           |Europa League   |10458    |2024/2025  |Europa League   |2025-09-04 19:34:20|europe-europa-league   |2024-2025|23665   |
# |252      |England    |2            |Premier League  |10743    |2025/2026  |Premier League  |2025-09-04 18:13:45|england-premier-league |2025-2026|24533   |
# |206      |Spain      |4            |LaLiga          |10803    |2025/2026  |LaLiga          |2025-09-04 18:34:23|spain-laliga           |2025-2026|24622   |
# |108      |Italy      |5            |Serie A         |10732    |2025/2026  |Serie A         |2025-09-04 18:20:29|italy-serie-a          |2025-2026|24500   |
# |252      |England    |2            |Premier League  |8618     |2021/2022  |Premier League  |2025-09-04 18:16:18|england-premier-league |2021-2022|19793   |
# |252      |England    |2            |Premier League  |6829     |2017/2018  |Premier League  |2025-09-04 18:18:45|england-premier-league |2017-2018|15151   |
# |252      |England    |2            |Premier League  |6335     |2016/2017  |Premier League  |2025-09-04 18:19:19|england-premier-league |2016-2017|13796   |
# |252      |England    |2            |Premier League  |7811     |2019/2020  |Premier League  |2025-09-04 18:17:27|england-premier-league |2019-2020|17590   |
# |252      |England    |2            |Premier League  |9618     |2023/2024  |Premier League  |2025-09-04 18:15:09|england-premier-league |2023-2024|22076   |
# |74       |France     |22           |Ligue 1         |10792    |2025/2026  |Ligue 1         |2025-09-04 18:27:12|france-ligue-1         |2025-2026|24609   |
# |81       |Germany    |3            |Bundesliga      |10720    |2025/2026  |Bundesliga      |2025-09-04 18:07:23|germany-bundesliga     |2025-2026|24478   |
# |252      |England    |2            |Premier League  |9075     |2022/2023  |Premier League  |2025-09-04 18:15:42|england-premier-league |2022-2023|20934   |
# |252      |England    |2            |Premier League  |10316    |2024/2025  |Premier League  |2025-09-04 18:14:39|england-premier-league |2024-2025|23400   |
# |206      |Spain      |4            |LaLiga          |6436     |2016/2017  |LaLiga          |2025-09-04 19:10:39|spain-laliga           |2016-2017|13955   |
# |108      |Italy      |5            |Serie A         |6461     |2016/2017  |Serie A         |2025-09-04 18:26:03|italy-serie-a          |2016-2017|14014   |
# +---------+-----------+-------------+----------------+---------+-----------+----------------+-------------------+-----------------------+---------+--------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import current_timestamp, date_format, lit
JOB_RUN_DATE = date_format(current_timestamp(), "yyyy-MM-dd-HH")

# %%
write_to_silver(
    df=dim_stages_df,
    table_name="dim_stages",
    primary_keys=["stage_id"],
    partition_by=["load_date_hour"],
    load_date_hour=JOB_RUN_DATE
)
# Out:
# Table 'silver.dim_stages' does not exist. Creating new table...
# Table successfully created and registered.
# 25/09/05 12:05:46 WARN HiveExternalCatalog: Couldn't find corresponding Hive SerDe for data source provider delta. Persisting data source table `spark_catalog`.`silver`.`dim_stages` into Hive metastore in Spark SQL specific format, which is NOT compatible with Hive.

# %% [markdown]
# - Dimension Team Table

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType
from pyspark.sql.functions import col, expr

team_schema = StructType([
    StructField("data", StructType([
        StructField("homeTeamId", IntegerType(), False),
        StructField("homeTeamName", StringType(), False),
        StructField("homeTeamCountryName", StringType(), False),
        StructField("awayTeamId", IntegerType(), False),
        StructField("awayTeamName", StringType(), False),
        StructField("awayTeamCountryName", StringType(), False),
    ]), True)
])

dim_teams_df = json_to_df(
    schema=team_schema,
    crawled_after=last_crawl_time,
    path=MATCH_PATH,
    glob_pattern="*match_preview.json"
)

home_teams_df = dim_teams_df.select(
    col("data.homeTeamId").alias("team_id"),
    col("data.homeTeamName").alias("team_name"),
    col("data.homeTeamCountryName").alias("country_name")
)

away_teams_df = dim_teams_df.select(
    col("data.awayTeamId").alias("team_id"),
    col("data.awayTeamName").alias("team_name"),
    col("data.awayTeamCountryName").alias("country_name")
)

dim_teams_df = home_teams_df.union(away_teams_df).dropDuplicates(["team_id"])

# %%
print(dim_teams_df.count())
# Out:
# [Stage 246:=================================================>(1554 + 14) / 1568]
# 389

# %%
dim_teams_df.printSchema()
dim_teams_df.show(10)
# Out:
# root
#  |-- team_id: integer (nullable = true)
#  |-- team_name: string (nullable = true)
#  |-- country_name: string (nullable = true)
# [Stage 252:=================================================>(1548 + 16) / 1568]
# +-------+-----------------+------------+
# |team_id|        team_name|country_name|
# +-------+-----------------+------------+
# |     15|          Chelsea|     England|
# |     16|       Sunderland|     England|
# |     23|        Newcastle|     England|
# |     27|          Watford|     England|
# |     31|          Everton|     England|
# |     37|    Bayern Munich|     Germany|
# |     39|       Schalke 04|     Germany|
# |     41|    VfB Stuttgart|     Germany|
# |     44|Borussia Dortmund|     Germany|
# |     52|      Real Madrid|       Spain|
# +-------+-----------------+------------+
# only showing top 10 rows

# %%
write_to_silver(
    df=dim_teams_df,
    table_name="dim_teams",
    primary_keys=["team_id"],
    partition_by=["load_date_hour"],
    load_date_hour=JOB_RUN_DATE
)
# Out:
# Table 'silver.dim_teams' does not exist. Creating new table...
# Table successfully created and registered.
# 25/09/05 12:06:32 WARN HiveExternalCatalog: Couldn't find corresponding Hive SerDe for data source provider delta. Persisting data source table `spark_catalog`.`silver`.`dim_teams` into Hive metastore in Spark SQL specific format, which is NOT compatible with Hive.

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, TimestampType
from pyspark.sql.functions import desc, col, regexp_extract

match_preview_schema = StructType([
    StructField("metadata", StructType([
        StructField("crawled_at", StringType(), True),
    ]), True),

    StructField("data", StructType([
        StructField(("homeTeamId"), IntegerType(), True),
        StructField(("awayTeamId"), IntegerType(), True),
        StructField(("startTimeUtc"), TimestampType(), True)
    ]), True)
])

match_preview_df = json_to_df(
    schema=match_preview_schema,
    crawled_after=last_crawl_time,
    path=MATCH_PATH,
    glob_pattern="*match_preview.json"
)

match_preview_df = flatten_df(
    match_preview_df
    .select(
        "match_id",
        "stage_id",
        "data.*",
        "metadata.crawled_at"
    )
)

# %%
print(match_preview_df.count())
match_preview_df.printSchema()
# Out:
# [Stage 352:================================================>   (738 + 16) / 784]
# 25081
# root
#  |-- match_id: integer (nullable = true)
#  |-- stage_id: integer (nullable = true)
#  |-- home_team_id: integer (nullable = true)
#  |-- away_team_id: integer (nullable = true)
#  |-- start_time_utc: timestamp (nullable = true)
#  |-- crawled_at: string (nullable = true)

# %%
match_preview_df.orderBy(
    # col("stage_id").asc(),
    col("match_id").desc()
).show()
# Out:
# [Stage 355:==============================================>     (705 + 16) / 784]
# +--------+--------+------------+------------+-------------------+-------------------+
# |match_id|stage_id|home_team_id|away_team_id|     start_time_utc|         crawled_at|
# +--------+--------+------------+------------+-------------------+-------------------+
# | 1946663|   24798|         446|         128|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946662|   24798|         446|         395|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946661|   24798|         446|         223|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946660|   24798|         446|         306|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946659|   24798|         140|         493|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946658|   24798|         140|         401|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946657|   24798|         140|         994|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946656|   24798|         140|          54|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946655|   24798|         128|         140|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946654|   24798|         128|         174|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946653|   24798|         128|         228|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946652|   24798|         128|         297|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946651|   24798|         874|          41|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946650|   24798|         874|        1202|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946649|   24798|         874|         288|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946648|   24798|         874|          24|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946647|   24798|         493|         685|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946646|   24798|         493|        9449|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946645|   24798|         493|         579|2025-09-24 19:00:00|2025-08-30 15:17:29|
# | 1946644|   24798|         493|         684|2025-09-24 19:00:00|2025-08-30 15:17:29|
# +--------+--------+------------+------------+-------------------+-------------------+
# only showing top 20 rows

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType
from pyspark.sql.functions import desc, col, regexp_extract, split, regexp_extract

match_data_schema = StructType([
    StructField("matchCentreData", StructType([
        StructField(("score"), StringType(), False),
        StructField(("htScore"), StringType(), False),
        StructField(("ftScore"), StringType(), False),
        StructField(("etScore"), StringType(), False),
        StructField(("pkScore"), StringType(), False),
    ]))
])

number_pattern = r"(\d+)"

match_data_df = json_to_df(
    schema=match_data_schema,
    crawled_after=last_crawl_time,
    path=MATCH_PATH,
    glob_pattern="*match_data.json"
)

# Convert from score string (3 : 2) to home score (3) and away score (2)
match_data_df = match_data_df.select(
    col("match_id"),
    regexp_extract(split(col("matchCentreData.score"), ":").getItem(0), number_pattern, 1).cast("integer").alias("home_score"),
    regexp_extract(split(col("matchCentreData.score"), ":").getItem(1), number_pattern, 1).cast("integer").alias("away_score"),
    regexp_extract(split(col("matchCentreData.htScore"), ":").getItem(0), number_pattern, 1).cast("integer").alias("home_ht_score"),
    regexp_extract(split(col("matchCentreData.htScore"), ":").getItem(1), number_pattern, 1).cast("integer").alias("away_ht_score"),
    regexp_extract(split(col("matchCentreData.ftScore"), ":").getItem(0), number_pattern, 1).cast("integer").alias("home_ft_score"),
    regexp_extract(split(col("matchCentreData.ftScore"), ":").getItem(1), number_pattern, 1).cast("integer").alias("away_ft_score"),
    regexp_extract(split(col("matchCentreData.etScore"), ":").getItem(0), number_pattern, 1).cast("integer").alias("home_et_score"),
    regexp_extract(split(col("matchCentreData.etScore"), ":").getItem(1), number_pattern, 1).cast("integer").alias("away_et_score"),
    regexp_extract(split(col("matchCentreData.pkScore"), ":").getItem(0), number_pattern, 1).cast("integer").alias("home_pk_score"),
    regexp_extract(split(col("matchCentreData.pkScore"), ":").getItem(1), number_pattern, 1).cast("integer").alias("away_pk_score"),
    col("stage_id")
)

# %%
match_data_df.printSchema()
# print(match_data_df.count())
match_data_df.show()
# Out:
# root
#  |-- match_id: integer (nullable = true)
#  |-- home_score: integer (nullable = true)
#  |-- away_score: integer (nullable = true)
#  |-- home_ht_score: integer (nullable = true)
#  |-- away_ht_score: integer (nullable = true)
#  |-- home_ft_score: integer (nullable = true)
#  |-- away_ft_score: integer (nullable = true)
#  |-- home_et_score: integer (nullable = true)
#  |-- away_et_score: integer (nullable = true)
#  |-- home_pk_score: integer (nullable = true)
#  |-- away_pk_score: integer (nullable = true)
#  |-- stage_id: integer (nullable = true)
#
# +--------+----------+----------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+--------+
# |match_id|home_score|away_score|home_ht_score|away_ht_score|home_ft_score|away_ft_score|home_et_score|away_et_score|home_pk_score|away_pk_score|stage_id|
# +--------+----------+----------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+--------+
# | 1872043|         2|         0|            0|            0|            2|            0|            2|            0|            5|            4|   23839|
# | 1789439|         2|         1|            1|            1|            2|            1|            2|            1|            3|            2|   22686|
# | 1694396|         2|         3|            1|            2|            2|            3|            2|            3|            3|            5|   20979|
# | 1604536|         2|         0|            2|            0|            2|            0|            2|            0|            3|            2|   20266|
# | 1809759|         1|         1|            0|            1|            1|            1|            1|            1|            3|            4|   22686|
# | 1891173|         1|         0|            1|            0|            1|            0|            1|            0|            2|            4|   24083|
# | 1697767|         1|         1|            0|            0|            0|            0|            1|            1|            4|            2|   18657|
# | 1559093|         1|         1|            0|            1|            1|            1|            1|            1|            1|            3|   16306|
# | 1832774|         0|         0|            0|            0|            0|            0|            0|            0|            3|            5|   21415|
# | 1551945|         2|         1|            0|            0|            0|            0|            2|            1|         NULL|         NULL|   16306|
# | 1627572|         1|         1|            0|            0|            0|            1|            1|            0|         NULL|         NULL|   20266|
# | 1891199|         0|         2|            0|            1|            0|            2|            0|            2|            3|            2|   24084|
# | 1630508|         2|         3|            0|            1|            1|            3|            2|            0|         NULL|         NULL|   20265|
# | 1809772|         1|         0|            0|            0|            1|            0|            1|            0|            4|            2|   22687|
# | 1891177|         0|         1|            0|            1|            0|            1|            0|            1|            1|            4|   24083|
# | 1694394|         2|         1|            0|            0|            1|            0|            2|            1|            4|            5|   20979|
# | 1697297|         1|         1|            1|            0|            1|            1|            1|            1|            1|            3|   18657|
# | 1811958|         0|         0|            0|            0|            0|            0|            0|            0|            4|            2|   22712|
# | 1553537|         3|         5|            1|            1|            3|            3|            0|            5|         NULL|         NULL|   16306|
# | 1630522|         3|         1|            2|            0|            2|            1|            3|            0|         NULL|         NULL|   20266|
# +--------+----------+----------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+--------+
# only showing top 20 rows

# %%
match_data_df.filter(col("away_pk_score").isNotNull()).show()

# %%
match_data_df.filter(col("home_pk_score").isNotNull()).show()

# %%
fct_match_summary_df = match_preview_df.join(
    other=match_data_df,
    on=["match_id", "stage_id"],
    how="left_outer")

# %%
print(fct_match_summary_df.count())
fct_match_summary_df.printSchema()

fct_match_summary_df.orderBy(
    col("match_id")
).show(10)
# Out:
# 25081
# root
#  |-- match_id: integer (nullable = true)
#  |-- stage_id: integer (nullable = true)
#  |-- home_team_id: integer (nullable = true)
#  |-- away_team_id: integer (nullable = true)
#  |-- start_time_utc: timestamp (nullable = true)
#  |-- crawled_at: string (nullable = true)
#  |-- home_score: integer (nullable = true)
#  |-- away_score: integer (nullable = true)
#  |-- home_ht_score: integer (nullable = true)
#  |-- away_ht_score: integer (nullable = true)
#  |-- home_ft_score: integer (nullable = true)
#  |-- away_ft_score: integer (nullable = true)
#  |-- home_et_score: integer (nullable = true)
#  |-- away_et_score: integer (nullable = true)
#  |-- home_pk_score: integer (nullable = true)
#  |-- away_pk_score: integer (nullable = true)
# +--------+--------+------------+------------+-------------------+-------------------+----------+----------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |match_id|stage_id|home_team_id|away_team_id|     start_time_utc|         crawled_at|home_score|away_score|home_ht_score|away_ht_score|home_ft_score|away_ft_score|home_et_score|away_et_score|home_pk_score|away_pk_score|
# +--------+--------+------------+------------+-------------------+-------------------+----------+----------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |  566036|    5980|         342|         323|2012-06-08 16:00:00|2025-08-30 14:58:11|         1|         1|            1|            0|            1|            1|         NULL|         NULL|         NULL|         NULL|
# |  566037|    5980|         326|         332|2012-06-08 18:45:00|2025-08-30 14:58:11|         4|         1|            2|            0|            4|            1|         NULL|         NULL|         NULL|         NULL|
# |  566038|    5980|         323|         332|2012-06-12 16:00:00|2025-08-30 14:58:11|         1|         2|            0|            2|            1|            2|         NULL|         NULL|         NULL|         NULL|
# |  566039|    5980|         342|         326|2012-06-12 18:45:00|2025-08-30 14:58:11|         1|         1|            0|            1|            1|            1|         NULL|         NULL|         NULL|         NULL|
# |  566040|    5980|         332|         342|2012-06-16 18:45:00|2025-08-30 14:58:11|         1|         0|            0|            0|            1|            0|         NULL|         NULL|         NULL|         NULL|
# |  566041|    5980|         323|         326|2012-06-16 18:45:00|2025-08-30 14:58:11|         1|         0|            1|            0|            1|            0|         NULL|         NULL|         NULL|         NULL|
# |  566042|    5981|         335|         425|2012-06-09 16:00:00|2025-08-30 14:58:30|         0|         1|            0|            1|            0|            1|         NULL|         NULL|         NULL|         NULL|
# |  566043|    5981|         336|         340|2012-06-09 18:45:00|2025-08-30 14:58:30|         1|         0|            0|            0|            1|            0|         NULL|         NULL|         NULL|         NULL|
# |  566044|    5981|         425|         340|2012-06-13 16:00:00|2025-08-30 14:58:30|         2|         3|            1|            2|            2|            3|         NULL|         NULL|         NULL|         NULL|
# |  566045|    5982|         338|         343|2012-06-10 16:00:00|2025-08-30 14:58:50|         1|         1|            0|            0|            1|            1|         NULL|         NULL|         NULL|         NULL|
# +--------+--------+------------+------------+-------------------+-------------------+----------+----------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# only showing top 10 rows

# %%
write_to_silver(
    df=fct_match_summary_df,
    table_name="fct_match_summary",
    primary_keys=["match_id"],
    partition_by="load_date_hour",
    load_date_hour=JOB_RUN_DATE
)
# Out:
# Table 'silver.fct_match_summary' does not exist. Creating new table...
# Table successfully created and registered.
# 25/09/05 12:08:11 WARN HiveExternalCatalog: Couldn't find corresponding Hive SerDe for data source provider delta. Persisting data source table `spark_catalog`.`silver`.`fct_match_summary` into Hive metastore in Spark SQL specific format, which is NOT compatible with Hive.

# %%
# from pyspark.sql.types import StructType, StructField, IntegerType, StringType
# from pyspark.sql.functions import col, expr

# team_stage_schema = StructType([
#     StructField("homeTeamId", IntegerType(), False),
#     StructField("awayTeamId", IntegerType(), False),
# ])

# fct_team_stage_participation_df = spark.read \
#     .schema(team_stage_schema) \
#     .option("multiLine", True) \
#     .option("pathGlobFilter", "*match_preview.json") \
#     .json(MATCH_PATH)

# # or select home_df and away_df then join
# fct_team_stage_participation_df = fct_team_stage_participation_df.select(
#     expr("stack(2, homeTeamId, awayTeamId) as (team_id)"),
#     col("stage_id")
# ).distinct()

# %%
# print(fct_team_stage_participation_df.count())
# fct_team_stage_participation_df.printSchema()
# fct_team_stage_participation_df.show()

# %%
# (
#     fct_team_stage_participation_df
#     .write
#     .mode("append")
#     .format("delta")
#     .save(f"{SILVER_PATH}/fct_team_stage_partcipation")
# )

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, ArrayType
from pyspark.sql.functions import col, expr, explode

player_schema = StructType([
    StructField("matchCentreData", StructType([
        StructField("home", StructType([
            StructField("players", ArrayType(
                StructType([
                    StructField("playerId", IntegerType(), False),
                    StructField("name", StringType(), False)
                ])
            ))
        ])),
        StructField("away", StructType([
            StructField("players", ArrayType(
                StructType([
                    StructField("playerId", IntegerType(), False),
                    StructField("name", StringType(), False)
                ])
            ))
        ]))
    ]))
])

dim_players_df = json_to_df(
    schema=player_schema,
    crawled_after=last_crawl_time,
    path=MATCH_PATH,
    glob_pattern="*match_data.json"
)

home_players_df = (
    dim_players_df
    .select(
        explode("matchCentreData.home.players").alias("player")
    )
    .select(
        "player.playerId",
        "player.name"
    )
)

away_players_df = (
    dim_players_df
    .select(
        explode("matchCentreData.away.players").alias("player")
    )
    .select(
        "player.playerId",
        "player.name"
    )
)

dim_players_df = home_players_df.union(away_players_df)

dim_players_df = dim_players_df.select(
    col("playerId").alias("player_id"),
    col("name").alias("player_name")
).dropDuplicates(["player_id"])

# %%
print(dim_players_df.count())
dim_players_df.printSchema()
dim_players_df.show()
# Out:
# ERROR:root:KeyboardInterrupt while sending command.           (200 + 16) / 1706]
# Traceback (most recent call last):
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/socket.py", line 718, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# [Stage 815:=======>                                           (239 + 16) / 1706]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 print(dim_players_df.count())
#       2 dim_players_df.printSchema()
#       3 dim_players_df.show()
#
# File ~/big_data/venv/lib/python3.11/site-packages/pyspark/sql/dataframe.py:1240, in DataFrame.count(self)
#    1217 def count(self) -> int:
#    1218     """Returns the number of rows in this :class:`DataFrame`.
#    1219
#    1220     .. versionadded:: 1.3.0
#    (...)   1238     3
#    1239     """
# -> 1240     return int(self._jdf.count())
#
# File ~/big_data/venv/lib/python3.11/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File ~/big_data/venv/lib/python3.11/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File ~/big_data/venv/lib/python3.11/site-packages/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File /usr/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# KeyboardInterrupt:
# [Stage 815:============>                                      (409 + 16) / 1706]

# %%
write_to_silver(dim_players_df, "dim_players")

# %%
view = dim_players_df.filter(col("player_name").contains("Mus"))
view.show()

# %%
def extract_side(df: DataFrame, side):
    return df.select(
        explode(f"matchCentreData.{side}.players").alias("player"),
        col(f"matchCentreData.{side}.teamId").alias("team_id"),
        col("match_id"),
        col("stage_id")
    )
    # .withColumnRenamed(
    #     "player.playerId", "player_id"
    # ).withColumnRenamed(
    #     "player.shirtNo", "player_id"
    # ).withColumnRenamed(
    #     "player.playerId", "player_id"
    # )

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, ArrayType, BooleanType
from pyspark.sql.functions import col, expr, explode

player_match_schema = StructType([
    StructField("matchCentreData", StructType([
        StructField("home", StructType([
            StructField("teamId", IntegerType(), False),
            StructField("players", ArrayType(
                StructType([
                    StructField("playerId", IntegerType(), False),
                    StructField("name", StringType(), False),
                    StructField("shirtNo", IntegerType(), False),
                    StructField("isFirstEleven", BooleanType(), False),
                    StructField("position", StringType(), False),
                ])
            ), True)
        ]), True),
        StructField("away", StructType([
            StructField("teamId", IntegerType(), False),
            StructField("players", ArrayType(
                StructType([
                    StructField("playerId", IntegerType(), False),
                    StructField("name", StringType(), False),
                    StructField("shirtNo", IntegerType(), False),
                    StructField("isFirstEleven", BooleanType(), False),
                    StructField("position", StringType(), False),
                ])
            ), True)
        ]), True)
    ]))
])

fct_player_match_participation_df = json_to_df(
    schema=player_match_schema,
    crawled_after=last_crawl_time,
    path=MATCH_PATH,
    glob_pattern="*match_data.json"
)

home_pm_df = extract_side(fct_player_match_participation_df, "home")
away_pm_df = extract_side(fct_player_match_participation_df, "away")
joined_pm_df = home_pm_df.union(away_pm_df)

flatten_pm_df = (
    joined_pm_df.select(
        col("match_id"),
        col("team_id"),
        col("player.playerId").alias("player_id"),
        col("player.name").alias("player_name"),
        col("player.shirtNo").alias("shirt_no"),
        col("player.isFirstEleven").alias("is_starting_eleven"),
        col("player.position").alias("position")
    )
)

fct_player_match_participation_df = (
    flatten_pm_df
    .drop("player_name")
    .fillna(False, ["is_starting_eleven"])
)

# %%
fct_player_match_participation_df.count()
# Out:
# 922314

# %%
# Construct dim_players_df from fct_player_match_participation_df
dim_players_df = (
    flatten_pm_df.select(
        "player_id",
        "player_name",
    )
).dropDuplicates(["player_id"])

# %%
print(fct_player_match_participation_df.count())
fct_player_match_participation_df.printSchema()
fct_player_match_participation_df.show()
# Out:
# 922314
# root
#  |-- match_id: integer (nullable = true)
#  |-- team_id: integer (nullable = true)
#  |-- player_id: integer (nullable = true)
#  |-- shirt_no: integer (nullable = true)
#  |-- is_starting_eleven: boolean (nullable = false)
#  |-- position: string (nullable = true)
#
# +--------+-------+---------+--------+------------------+--------+
# |match_id|team_id|player_id|shirt_no|is_starting_eleven|position|
# +--------+-------+---------+--------+------------------+--------+
# | 1872043|    341|   141646|      16|              true|      GK|
# | 1872043|    341|   301019|       5|              true|      DR|
# | 1872043|    341|   327721|       4|              true|      DC|
# | 1872043|    341|   361822|      17|              true|      DC|
# | 1872043|    341|   303115|      22|              true|      DL|
# | 1872043|    341|   353423|       8|              true|     DMC|
# | 1872043|    341|   369570|      13|              true|     DMC|
# | 1872043|    341|   299513|       7|              true|     AMR|
# | 1872043|    341|   371281|      11|              true|     AMC|
# | 1872043|    341|   425366|      20|              true|     AML|
# | 1872043|    341|   300713|      10|              true|      FW|
# | 1872043|    341|   333542|      12|             false|     Sub|
# | 1872043|    341|   369109|       6|             false|     Sub|
# | 1872043|    341|   433183|       9|             false|     Sub|
# | 1872043|    341|   444679|      18|             false|     Sub|
# | 1872043|    341|    89925|       3|             false|     Sub|
# | 1872043|    341|   105198|       1|             false|     Sub|
# | 1872043|    341|   116609|      14|             false|     Sub|
# | 1872043|    341|   259648|       2|             false|     Sub|
# | 1872043|    341|   301869|      21|             false|     Sub|
# +--------+-------+---------+--------+------------------+--------+
# only showing top 20 rows

# %%
print(dim_players_df.count())
dim_players_df.printSchema()
dim_players_df.show()
# Out:
# 18822
# root
#  |-- player_id: integer (nullable = true)
#  |-- player_name: string (nullable = true)
# [Stage 548:==================================================>(1850 + 6) / 1856]
# +---------+------------------+
# |player_id|       player_name|
# +---------+------------------+
# |     1019|         Wes Brown|
# |     1212|   Faryd Mondragón|
# |     2180|       Joseph Yobo|
# |     2235|     Lars Jacobsen|
# |     2247|    Daniele Bonera|
# |     2479|    Leon Andreasen|
# |     2778|   Giampiero Pinzi|
# |     2842|    Emre Belozoglu|
# |     3841|       John O'Shea|
# |     4368| Sergio Pellissier|
# |     4773|   Steffen Hofmann|
# |     5480|    Jermaine Jones|
# |     5759|    Markus Feulner|
# |     6040|    Lukas Podolski|
# |     6128|  Steven Whittaker|
# |     6145|    Angelo Palombo|
# |     6176|José Antonio Reyes|
# |     6301|      Julien Cardy|
# |     6319|       David Villa|
# |     6695|      Jonas Olsson|
# +---------+------------------+
# only showing top 20 rows

# %%
write_to_silver(
    df=dim_players_df,
    table_name="dim_players",
    primary_keys=["player_id"],
    partition_by=["load_date_hour"],
    load_date_hour=JOB_RUN_DATE
)
# Out:
# Table 'silver.dim_players' does not exist. Creating new table...
# Table successfully created and registered.
# 25/09/05 12:10:01 WARN HiveExternalCatalog: Couldn't find corresponding Hive SerDe for data source provider delta. Persisting data source table `spark_catalog`.`silver`.`dim_players` into Hive metastore in Spark SQL specific format, which is NOT compatible with Hive.

# %%
write_to_silver(
    df=fct_player_match_participation_df,
    table_name="fct_player_match_participation",
    primary_keys=["player_id", "match_id"],
    partition_by=["load_date_hour"],
    load_date_hour=JOB_RUN_DATE
)

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, FloatType, ArrayType, BooleanType
from pyspark.sql.functions import col, explode_outer, asc, desc, row_number, monotonically_increasing_id, explode
from pyspark.sql.window import Window

match_event_schema = StructType([
    StructField("matchCentreData", StructType([
        StructField("home", StructType([
            StructField("teamId", IntegerType(), False),
            StructField("formations", ArrayType(
                StructType([
                    StructField("formationName", StringType(), False),
                    StructField("playerIds", ArrayType(IntegerType()), False)
                ])
            ), True)
        ]), True),
        StructField("away", StructType([
            StructField("teamId", IntegerType(), False),
            StructField("formations", ArrayType(
                StructType([
                    StructField("formationName", StringType(), False),
                    StructField("playerIds", ArrayType(IntegerType()), False)
                ])
            ), True)
        ]), True)
    ]))
])

fct_match_events_df = json_to_df(
    schema=match_event_schema,
    crawled_after=last_crawl_time,
    path=MATCH_PATH,
    glob_pattern="*match_data.json"
)

# # repartition before exploding for low shuffle cost later
# num_partitions = 200
# fct_match_events_df = fct_match_events_df.repartition(num_partitions, "match_id")

# exploding column "event"
fct_match_events_df = fct_match_events_df.withColumn("event", explode_outer(col("matchCentreData.events"))).drop("matchCentreData")

# Since event_id is unique for each team per match
# We create an unique _match_id to preserve the original event order of every match
fct_match_events_df = fct_match_events_df.withColumn(
    "surrogate_event_id", monotonically_increasing_id()
)
w = Window.partitionBy("match_id").orderBy("surrogate_event_id")
fct_match_events_df = fct_match_events_df.withColumn("_event_id", row_number().over(w))

base_match_events_df = (
    flatten_df(
        fct_match_events_df.select(
            col("surrogate_event_id"),
            col("match_id"),
            col("_event_id"),
            "event.*",
            col("league"),
            col("season"),
            col("stage_id")
        )
    )
)

exploded_match_events_df = base_match_events_df.select(
    col("surrogate_event_id"),
    explode(col("satisfied_events_types")).alias("event_type_id")
)

# fct_match_events_df = fct_match_events_df.orderBy(
#     asc("match_id"),
#     asc("_event_id")
# )

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, FloatType, ArrayType, BooleanType
from pyspark.sql.functions import col, explode_outer, asc, desc, row_number, monotonically_increasing_id, explode, transform, filter, regexp_replace, lower, when, arrays_zip
from pyspark.sql.window import Window

match_formations_schema = StructType([
    StructField("matchCentreData", StructType([
        StructField("home", StructType([
            StructField("teamId", IntegerType(), False),
            StructField("formations", ArrayType(
                StructType([
                    StructField("formationName", StringType(), True),
                    StructField("playerIds", ArrayType(IntegerType(), True), True),
                    StructField("formationSlots", ArrayType(IntegerType(), True), True),
                    StructField("startMinuteExpanded", IntegerType(), True)
                ])
            ), True)
        ]), True),
        StructField("away", StructType([
            StructField("teamId", IntegerType(), False),
            StructField("formations", ArrayType(
                StructType([
                    StructField("formationName", StringType(), True),
                    StructField("playerIds", ArrayType(IntegerType(), True), True),
                    StructField("formationSlots", ArrayType(IntegerType(), True), True),
                    StructField("startMinuteExpanded", IntegerType(), True)
                ])
            ), True)
        ]), True)
    ]))
])

fct_match_formations_df = json_to_df(
    schema=match_formations_schema,
    crawled_after=last_crawl_time,
    path=MATCH_PATH,
    glob_pattern="*match_data.json"
)


home_formations = fct_match_formations_df.select(
    explode(f"matchCentreData.home.formations").alias("formation"),
    col(f"matchCentreData.home.teamId").alias("team_id"),
    col("match_id"),
    col("stage_id")
)
away_formations = fct_match_formations_df.select(
    explode(f"matchCentreData.away.formations").alias("formation"),
    col(f"matchCentreData.away.teamId").alias("team_id"),
    col("match_id"),
    col("stage_id")
)

joined_formations = home_formations.union(away_formations)

# # exploding column "formations"
# fct_match_formations_df = joined_formations.withColumn(
#     "formation",
#     explode_outer(col("formations"))
# ).drop("formations")

granular_player_slots_df = (
    joined_formations
    .withColumn("player_slot_pairs", arrays_zip(
        col("formation.formationSlots"), 
        col("formation.playerIds")
    ))
    .withColumn("player_slot", explode("player_slot_pairs"))
    .select(
        col("match_id"),
        col("stage_id"),
        col("team_id"),
        col("formation.formationName").alias("formation_name"),
        col("formation.startMinuteExpanded").alias("start_minute"),
        col("player_slot.playerIds").alias("player_id"),
        col("player_slot.formationSlots").alias("slot_id")
    )
    .filter(col("slot_id") > 0) # Only keep players on the pitch
)

# %%
granular_player_slots_df.filter(col("formation_name") == "532").select("match_id").show()
# Out:
# +--------+
# |match_id|
# +--------+
# | 1699239|
# | 1699239|
# | 1699239|
# | 1699239|
# | 1699239|
# | 1699239|
# | 1699239|
# | 1699239|
# | 1699239|
# | 1699239|
# | 1699239|
# | 1829434|
# | 1829434|
# | 1829434|
# | 1829434|
# | 1829434|
# | 1829434|
# | 1829434|
# | 1829434|
# | 1829434|
# +--------+
# only showing top 20 rows

# %%
from pyspark.sql import functions as sf
# granular_player_slots_df.filter(col("start_minute") == 0).select(sf.count_distinct("formation_name", "slot_id")).show()
granular_player_slots_df.filter(col("start_minute") == 0).dropDuplicates(["formation_name", "slot_id"]).filter(col("slot_id") == 1).show(25)
# Out:
# [Stage 652:>                                                        (0 + 1) / 1]
# +--------+--------+-------+--------------+------------+---------+-------+
# |match_id|stage_id|team_id|formation_name|start_minute|player_id|slot_id|
# +--------+--------+-------+--------------+------------+---------+-------+
# | 1811958|   22712|    413|          3142|           0|   401633|      1|
# | 1809772|   22687|    249|          3511|           0|   145427|      1|
# | 1627572|   20266|     45|           343|           0|    66424|      1|
# | 1697767|   18657|    337|           433|           0|   119120|      1|
# | 1604536|   20266|    288|          3421|           0|   296521|      1|
# | 1694396|   20979|    248|           442|           0|   260770|      1|
# | 1789439|   22686|     63|           352|           0|    76662|      1|
# | 1872043|   23839|    341|          4231|           0|   141646|      1|
# | 1809759|   22686|    167|          4141|           0|   121774|      1|
# | 1697443|   18657|    335|          3412|           0|   252239|      1|
# | 1096711|    8996|    340|          4132|           0|    23089|      1|
# | 1088528|    8993|    342|          4411|           0|    20973|      1|
# | 1888138|   24084|    130|          4312|           0|    34550|      1|
# | 1910411|   23869|    167|          4321|           0|   121774|      1|
# | 1644001|   21037|    613|           541|           0|    19545|      1|
# | 1644018|   21037|    614|           532|           0|   288896|      1|
# | 1643786|   21037|    248|          4222|           0|   260770|      1|
# | 1741283|   22105|    314|           451|           0|    34008|      1|
# | 1640811|   20934|     26|         41212|           0|   114147|      1|
# | 1560035|   19895|     52|          4240|           0|    73798|      1|
# | 1743507|   22128|   1147|          343d|           0|   115570|      1|
# | 1729365|   22076|    167|          3241|           0|   121774|      1|
# | 1824980|   23414|    217|          3331|           0|   302839|      1|
# +--------+--------+-------+--------------+------------+---------+-------+

# %%
from pyspark.sql.functions import col, first, broadcast

enriched_slots_df = granular_player_slots_df.join(
    broadcast(fct_player_match_participation_df),
    ["match_id", "player_id"],
    "inner" # Use inner join because we only care about players with known starting positions
)

golden_matches_df = (
    enriched_slots_df
    .filter(col("start_minute") == 0)
    .select("formation_name", "match_id")
    .dropDuplicates(["formation_name"])
)

formation_slot_mapping_df = (
    enriched_slots_df
    # Filter 1: Only keep starting players
    .filter(col("start_minute") == 0)
    # Filter 2: Only keep data from our "golden matches"
    .join(
        broadcast(golden_matches_df),
        ["formation_name", "match_id"],
        "inner"
    )
    # Now, aggregate to build the final map
    .groupBy("formation_name", "slot_id")
    .agg(first("position").alias("inferred_position"))
    .orderBy("formation_name", "slot_id")
)

# %%
# Assume you have already built your mapping.
# 'formation_slot_mapping_df' is the DataFrame with columns:
# ["formation_name", "slot_id", "inferred_position"]

# --- Step 1: Get the PRIMARY position for every player in every match ---
# We need to find the first formation/slot each player was in for each match.
# This correctly handles starters (start_minute=0) and subs (start_minute > 0).

from pyspark.sql.window import Window
from pyspark.sql.functions import row_number, col

# Define a window to partition by match and player, ordering by when they came on
window_spec = Window.partitionBy("match_id", "player_id").orderBy(col("start_minute").asc())

# 'granular_player_slots_df' is the big DataFrame with all players from all formation periods
player_first_appearance_df = (
    granular_player_slots_df
    .withColumn("appearance_rank", row_number().over(window_spec))
    .filter(col("appearance_rank") == 1) # Keep only the first row for each player in each match
    .select("match_id", "player_id", "formation_name", "slot_id")
)


# --- Step 2: Join with your mapping to get the position string ---
# This is the final join that brings it all together.

final_player_positions_df = player_first_appearance_df.join(
    formation_slot_mapping_df,
    ["formation_name", "slot_id"],
    "left" # Use a left join to see if any positions are unmapped
).select(
    col("match_id"),
    col("player_id"),
    col("inferred_position").alias("position") # Rename the column to your final desired name
)


# --- Final Output ---
# This is the table you wanted.
print("Final Player Positions Table:")
display(final_player_positions_df)

# You would then write this to your final Delta table
# final_player_positions_df.write.mode("overwrite").saveAsTable("workspace.gold.player_match_positions")

# %%
final_player_positions_df.filter(
    col("match_id") == 1697443
).show(50)

# final_player_positions_df.printSchema()

# %%
from pyspark.sql.functions import first

# Assume you have a DataFrame 'player_match_participation_df'
# with columns: match_id, player_id, team_id, position (the known starting position)

# --- Join the granular slot data with the known starting positions ---
# We only care about the starting period (start_minute = 0)
starting_slots_df = granular_player_slots_df.filter(
    col("start_minute") == 0
).dropDuplicates(["formation_name", "slot_id"])

# Join to get the known position string
mapping_builder_df = starting_slots_df.join(
    fct_player_match_participation_df,
    ["match_id", "team_id", "player_id"],
    how="left"
)

formation_slot_mapping_df = mapping_builder_df.select(
    "formation_name",
    "slot_id",
    "position",
)

player_match_position_df = granular_player_slots_df.join(
    formation_slot_mapping_df,
    on=["formation_name", "slot_id"],
)

fct_player_match_participation_df = (
    fct_player_match_participation_df
    .join(
        player_match_position_df,
        on=["match_id", "team_id", "player_id"],
    )
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 8
#       1 from pyspark.sql.functions import first
#       3 # Assume you have a DataFrame 'player_match_participation_df'
#       4 # with columns: match_id, player_id, team_id, position (the known starting position)
#       5
#       6 # --- Join the granular slot data with the known starting positions ---
#       7 # We only care about the starting period (start_minute = 0)
# ----> 8 starting_slots_df = granular_player_slots_df.filter(
#       9     col("start_minute") == 0
#      10 ).dropDuplicates(["formation_name", "slot_id"])
#      12 # Join to get the known position string
#      13 mapping_builder_df = starting_slots_df.join(
#      14     fct_player_match_participation_df,
#      15     ["match_id", "team_id", "player_id"],
#      16     how="left"
#      17 )
#
# NameError: name 'granular_player_slots_df' is not defined

# %%
granular_player_slots_df.printSchema()
# Out:
# root
#  |-- match_id: integer (nullable = true)
#  |-- stage_id: integer (nullable = true)
#  |-- team_id: integer (nullable = true)
#  |-- formation_name: string (nullable = true)
#  |-- start_minute: integer (nullable = true)
#  |-- player_id: integer (nullable = true)
#  |-- slot_id: integer (nullable = true)

# %%
"""
Now since we don't have the mapping (formation + slot_id) -> played_position,  
we have to build it from existing data

The source data only shows Sub position for players not in the starting lineup,  
so this block purpose is to build actual position for them. You can modify this  
to consider Sub a real position like what Whoscored did
"""
from pyspark.sql.functions import col, first, broadcast
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number

# Get all distinct formation_name + slot_id to build mapping
# from starting lineups (start_min = 0)
formation_starter_slots_df = granular_player_slots_df.filter(
    col("start_minute") == 0
).dropDuplicates(
    ["formation_name", "slot_id"]
)

formation_starter_slots_df.cache()
print(formation_starter_slots_df.count())

# Join the existing data
# to the original fct_player_match_participation table with registered positions
mapping_builder_df = (
    broadcast(formation_starter_slots_df)
    .join(
        fct_player_match_participation_df,
        ["match_id", "player_id", "team_id"],
    )
)

print(mapping_builder_df.count())

mapping_builder_df = mapping_builder_df.select(
    "formation_name",
    "slot_id",
    "position"
)

import json

rows = [row.asDict() for row in mapping_builder_df.collect()]
print(json.dumps(rows, indent=2))
# Out:
# 253
# 253
# [Stage 184:=================================================>(1837 + 16) / 1856]
# [
#   {
#     "formation_name": "4231",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "4231",
#     "slot_id": 2,
#     "position": "DR"
#   },
#   {
#     "formation_name": "4231",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4231",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4231",
#     "slot_id": 3,
#     "position": "DL"
#   },
#   {
#     "formation_name": "4231",
#     "slot_id": 8,
#     "position": "DMC"
#   },
#   {
#     "formation_name": "4231",
#     "slot_id": 4,
#     "position": "DMC"
#   },
#   {
#     "formation_name": "4231",
#     "slot_id": 7,
#     "position": "AMR"
#   },
#   {
#     "formation_name": "4231",
#     "slot_id": 10,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "4231",
#     "slot_id": 11,
#     "position": "AML"
#   },
#   {
#     "formation_name": "4231",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "352",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "352",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "352",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "352",
#     "slot_id": 4,
#     "position": "DC"
#   },
#   {
#     "formation_name": "352",
#     "slot_id": 2,
#     "position": "DMR"
#   },
#   {
#     "formation_name": "352",
#     "slot_id": 3,
#     "position": "DML"
#   },
#   {
#     "formation_name": "352",
#     "slot_id": 11,
#     "position": "MC"
#   },
#   {
#     "formation_name": "352",
#     "slot_id": 7,
#     "position": "MC"
#   },
#   {
#     "formation_name": "352",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "352",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "352",
#     "slot_id": 10,
#     "position": "FW"
#   },
#   {
#     "formation_name": "442",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "442",
#     "slot_id": 2,
#     "position": "DR"
#   },
#   {
#     "formation_name": "442",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "442",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "442",
#     "slot_id": 3,
#     "position": "DL"
#   },
#   {
#     "formation_name": "442",
#     "slot_id": 7,
#     "position": "MR"
#   },
#   {
#     "formation_name": "442",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "442",
#     "slot_id": 4,
#     "position": "MC"
#   },
#   {
#     "formation_name": "442",
#     "slot_id": 11,
#     "position": "ML"
#   },
#   {
#     "formation_name": "442",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "442",
#     "slot_id": 10,
#     "position": "FW"
#   },
#   {
#     "formation_name": "3421",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "3421",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3421",
#     "slot_id": 4,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3421",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3421",
#     "slot_id": 2,
#     "position": "DMR"
#   },
#   {
#     "formation_name": "3421",
#     "slot_id": 3,
#     "position": "DML"
#   },
#   {
#     "formation_name": "3421",
#     "slot_id": 7,
#     "position": "MC"
#   },
#   {
#     "formation_name": "3421",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "3421",
#     "slot_id": 11,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "3421",
#     "slot_id": 10,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "3421",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "4141",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "4141",
#     "slot_id": 2,
#     "position": "DR"
#   },
#   {
#     "formation_name": "4141",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4141",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4141",
#     "slot_id": 3,
#     "position": "DL"
#   },
#   {
#     "formation_name": "4141",
#     "slot_id": 4,
#     "position": "DMC"
#   },
#   {
#     "formation_name": "4141",
#     "slot_id": 7,
#     "position": "MR"
#   },
#   {
#     "formation_name": "4141",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "4141",
#     "slot_id": 10,
#     "position": "MC"
#   },
#   {
#     "formation_name": "4141",
#     "slot_id": 11,
#     "position": "ML"
#   },
#   {
#     "formation_name": "4141",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "433",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "433",
#     "slot_id": 2,
#     "position": "DR"
#   },
#   {
#     "formation_name": "433",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "433",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "433",
#     "slot_id": 3,
#     "position": "DL"
#   },
#   {
#     "formation_name": "433",
#     "slot_id": 7,
#     "position": "MC"
#   },
#   {
#     "formation_name": "433",
#     "slot_id": 4,
#     "position": "MC"
#   },
#   {
#     "formation_name": "433",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "433",
#     "slot_id": 10,
#     "position": "FWR"
#   },
#   {
#     "formation_name": "433",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "433",
#     "slot_id": 11,
#     "position": "FWL"
#   },
#   {
#     "formation_name": "343",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "343",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "343",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "343",
#     "slot_id": 4,
#     "position": "DC"
#   },
#   {
#     "formation_name": "343",
#     "slot_id": 2,
#     "position": "DMR"
#   },
#   {
#     "formation_name": "343",
#     "slot_id": 3,
#     "position": "DML"
#   },
#   {
#     "formation_name": "343",
#     "slot_id": 7,
#     "position": "MC"
#   },
#   {
#     "formation_name": "343",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "343",
#     "slot_id": 10,
#     "position": "FWR"
#   },
#   {
#     "formation_name": "343",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "343",
#     "slot_id": 11,
#     "position": "FWL"
#   },
#   {
#     "formation_name": "3511",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "3511",
#     "slot_id": 4,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3511",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3511",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3511",
#     "slot_id": 2,
#     "position": "DMR"
#   },
#   {
#     "formation_name": "3511",
#     "slot_id": 3,
#     "position": "DML"
#   },
#   {
#     "formation_name": "3511",
#     "slot_id": 11,
#     "position": "MC"
#   },
#   {
#     "formation_name": "3511",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "3511",
#     "slot_id": 7,
#     "position": "MC"
#   },
#   {
#     "formation_name": "3511",
#     "slot_id": 10,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "3511",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "3142",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "3142",
#     "slot_id": 4,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3142",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3142",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3142",
#     "slot_id": 8,
#     "position": "DMC"
#   },
#   {
#     "formation_name": "3142",
#     "slot_id": 2,
#     "position": "MR"
#   },
#   {
#     "formation_name": "3142",
#     "slot_id": 11,
#     "position": "MC"
#   },
#   {
#     "formation_name": "3142",
#     "slot_id": 7,
#     "position": "MC"
#   },
#   {
#     "formation_name": "3142",
#     "slot_id": 3,
#     "position": "ML"
#   },
#   {
#     "formation_name": "3142",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "3142",
#     "slot_id": 10,
#     "position": "FW"
#   },
#   {
#     "formation_name": "3412",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "3412",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3412",
#     "slot_id": 4,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3412",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3412",
#     "slot_id": 2,
#     "position": "MR"
#   },
#   {
#     "formation_name": "3412",
#     "slot_id": 7,
#     "position": "MC"
#   },
#   {
#     "formation_name": "3412",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "3412",
#     "slot_id": 3,
#     "position": "ML"
#   },
#   {
#     "formation_name": "3412",
#     "slot_id": 9,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "3412",
#     "slot_id": 11,
#     "position": "FW"
#   },
#   {
#     "formation_name": "3412",
#     "slot_id": 10,
#     "position": "FW"
#   },
#   {
#     "formation_name": "4132",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "4132",
#     "slot_id": 2,
#     "position": "DR"
#   },
#   {
#     "formation_name": "4132",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4132",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4132",
#     "slot_id": 3,
#     "position": "DL"
#   },
#   {
#     "formation_name": "4132",
#     "slot_id": 4,
#     "position": "DMC"
#   },
#   {
#     "formation_name": "4132",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "4132",
#     "slot_id": 11,
#     "position": "MC"
#   },
#   {
#     "formation_name": "4132",
#     "slot_id": 7,
#     "position": "MC"
#   },
#   {
#     "formation_name": "4132",
#     "slot_id": 10,
#     "position": "FW"
#   },
#   {
#     "formation_name": "4132",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "4312",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "4312",
#     "slot_id": 2,
#     "position": "DR"
#   },
#   {
#     "formation_name": "4312",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4312",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4312",
#     "slot_id": 3,
#     "position": "DL"
#   },
#   {
#     "formation_name": "4312",
#     "slot_id": 11,
#     "position": "MC"
#   },
#   {
#     "formation_name": "4312",
#     "slot_id": 4,
#     "position": "MC"
#   },
#   {
#     "formation_name": "4312",
#     "slot_id": 7,
#     "position": "MC"
#   },
#   {
#     "formation_name": "4312",
#     "slot_id": 8,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "4312",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "4312",
#     "slot_id": 10,
#     "position": "FW"
#   },
#   {
#     "formation_name": "4411",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "4411",
#     "slot_id": 2,
#     "position": "DR"
#   },
#   {
#     "formation_name": "4411",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4411",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4411",
#     "slot_id": 3,
#     "position": "DL"
#   },
#   {
#     "formation_name": "4411",
#     "slot_id": 7,
#     "position": "MR"
#   },
#   {
#     "formation_name": "4411",
#     "slot_id": 4,
#     "position": "MC"
#   },
#   {
#     "formation_name": "4411",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "4411",
#     "slot_id": 11,
#     "position": "ML"
#   },
#   {
#     "formation_name": "4411",
#     "slot_id": 10,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "4411",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "4321",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "4321",
#     "slot_id": 2,
#     "position": "DR"
#   },
#   {
#     "formation_name": "4321",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4321",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4321",
#     "slot_id": 3,
#     "position": "DL"
#   },
#   {
#     "formation_name": "4321",
#     "slot_id": 7,
#     "position": "MC"
#   },
#   {
#     "formation_name": "4321",
#     "slot_id": 4,
#     "position": "MC"
#   },
#   {
#     "formation_name": "4321",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "4321",
#     "slot_id": 11,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "4321",
#     "slot_id": 10,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "4321",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "541",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "541",
#     "slot_id": 2,
#     "position": "DR"
#   },
#   {
#     "formation_name": "541",
#     "slot_id": 4,
#     "position": "DC"
#   },
#   {
#     "formation_name": "541",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "541",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "541",
#     "slot_id": 3,
#     "position": "DL"
#   },
#   {
#     "formation_name": "541",
#     "slot_id": 7,
#     "position": "MR"
#   },
#   {
#     "formation_name": "541",
#     "slot_id": 10,
#     "position": "MC"
#   },
#   {
#     "formation_name": "541",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "541",
#     "slot_id": 11,
#     "position": "ML"
#   },
#   {
#     "formation_name": "541",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "532",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "532",
#     "slot_id": 2,
#     "position": "DR"
#   },
#   {
#     "formation_name": "532",
#     "slot_id": 4,
#     "position": "DC"
#   },
#   {
#     "formation_name": "532",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "532",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "532",
#     "slot_id": 3,
#     "position": "DL"
#   },
#   {
#     "formation_name": "532",
#     "slot_id": 7,
#     "position": "MC"
#   },
#   {
#     "formation_name": "532",
#     "slot_id": 11,
#     "position": "MC"
#   },
#   {
#     "formation_name": "532",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "532",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "532",
#     "slot_id": 10,
#     "position": "FW"
#   },
#   {
#     "formation_name": "4222",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "4222",
#     "slot_id": 2,
#     "position": "DR"
#   },
#   {
#     "formation_name": "4222",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4222",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4222",
#     "slot_id": 3,
#     "position": "DL"
#   },
#   {
#     "formation_name": "4222",
#     "slot_id": 4,
#     "position": "DMC"
#   },
#   {
#     "formation_name": "4222",
#     "slot_id": 8,
#     "position": "DMC"
#   },
#   {
#     "formation_name": "4222",
#     "slot_id": 11,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "4222",
#     "slot_id": 7,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "4222",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "4222",
#     "slot_id": 10,
#     "position": "FW"
#   },
#   {
#     "formation_name": "451",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "451",
#     "slot_id": 2,
#     "position": "DR"
#   },
#   {
#     "formation_name": "451",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "451",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "451",
#     "slot_id": 3,
#     "position": "DL"
#   },
#   {
#     "formation_name": "451",
#     "slot_id": 7,
#     "position": "MR"
#   },
#   {
#     "formation_name": "451",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "451",
#     "slot_id": 4,
#     "position": "MC"
#   },
#   {
#     "formation_name": "451",
#     "slot_id": 10,
#     "position": "MC"
#   },
#   {
#     "formation_name": "451",
#     "slot_id": 11,
#     "position": "ML"
#   },
#   {
#     "formation_name": "451",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "41212",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "41212",
#     "slot_id": 2,
#     "position": "DR"
#   },
#   {
#     "formation_name": "41212",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "41212",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "41212",
#     "slot_id": 3,
#     "position": "DL"
#   },
#   {
#     "formation_name": "41212",
#     "slot_id": 4,
#     "position": "DMC"
#   },
#   {
#     "formation_name": "41212",
#     "slot_id": 11,
#     "position": "MC"
#   },
#   {
#     "formation_name": "41212",
#     "slot_id": 7,
#     "position": "MC"
#   },
#   {
#     "formation_name": "41212",
#     "slot_id": 8,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "41212",
#     "slot_id": 10,
#     "position": "FW"
#   },
#   {
#     "formation_name": "41212",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "4240",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "4240",
#     "slot_id": 2,
#     "position": "DR"
#   },
#   {
#     "formation_name": "4240",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4240",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "4240",
#     "slot_id": 3,
#     "position": "DL"
#   },
#   {
#     "formation_name": "4240",
#     "slot_id": 4,
#     "position": "DMC"
#   },
#   {
#     "formation_name": "4240",
#     "slot_id": 8,
#     "position": "DMC"
#   },
#   {
#     "formation_name": "4240",
#     "slot_id": 7,
#     "position": "AMR"
#   },
#   {
#     "formation_name": "4240",
#     "slot_id": 9,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "4240",
#     "slot_id": 10,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "4240",
#     "slot_id": 11,
#     "position": "AML"
#   },
#   {
#     "formation_name": "343d",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "343d",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "343d",
#     "slot_id": 4,
#     "position": "DC"
#   },
#   {
#     "formation_name": "343d",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "343d",
#     "slot_id": 8,
#     "position": "DMC"
#   },
#   {
#     "formation_name": "343d",
#     "slot_id": 2,
#     "position": "MC"
#   },
#   {
#     "formation_name": "343d",
#     "slot_id": 3,
#     "position": "MC"
#   },
#   {
#     "formation_name": "343d",
#     "slot_id": 7,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "343d",
#     "slot_id": 10,
#     "position": "FWR"
#   },
#   {
#     "formation_name": "343d",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "343d",
#     "slot_id": 11,
#     "position": "FWL"
#   },
#   {
#     "formation_name": "3241",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "3241",
#     "slot_id": 4,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3241",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3241",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3241",
#     "slot_id": 2,
#     "position": "DMC"
#   },
#   {
#     "formation_name": "3241",
#     "slot_id": 3,
#     "position": "DMC"
#   },
#   {
#     "formation_name": "3241",
#     "slot_id": 10,
#     "position": "AMR"
#   },
#   {
#     "formation_name": "3241",
#     "slot_id": 8,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "3241",
#     "slot_id": 7,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "3241",
#     "slot_id": 11,
#     "position": "AML"
#   },
#   {
#     "formation_name": "3241",
#     "slot_id": 9,
#     "position": "FW"
#   },
#   {
#     "formation_name": "3331",
#     "slot_id": 1,
#     "position": "GK"
#   },
#   {
#     "formation_name": "3331",
#     "slot_id": 6,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3331",
#     "slot_id": 5,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3331",
#     "slot_id": 4,
#     "position": "DC"
#   },
#   {
#     "formation_name": "3331",
#     "slot_id": 8,
#     "position": "MC"
#   },
#   {
#     "formation_name": "3331",
#     "slot_id": 2,
#     "position": "MC"
#   },
#   {
#     "formation_name": "3331",
#     "slot_id": 3,
#     "position": "MC"
#   },
#   {
#     "formation_name": "3331",
#     "slot_id": 10,
#     "position": "AMR"
#   },
#   {
#     "formation_name": "3331",
#     "slot_id": 7,
#     "position": "AMC"
#   },
#   {
#     "formation_name": "3331",
#     "slot_id": 11,
#     "position": "AML"
#   },
#   {
#     "formation_name": "3331",
#     "slot_id": 9,
#     "position": "FW"
#   }
# ]

# %%
formation_starter_slots_df.unpersist()
# Out:
# DataFrame[match_id: int, stage_id: int, team_id: int, formation_name: string, start_minute: int, player_id: int, slot_id: int]

# %%
from pyspark.sql import Row

print(len(rows))

mapping_position_df = spark.createDataFrame([Row(**row) for row in rows])

mapping_position_df.show()
mapping_position_df.select("formation_name").distinct().show(23)
# Out:
# 165

# %%
import os
import json
from pyspark.sql.functions import col, first, broadcast, row_number
from pyspark.sql.window import Window
from pyspark.sql import Row

mapping_file = "mapping/formation_slot_mapping.json"

if not os.path.exists(mapping_file):
    print(f"{mapping_file} doesn't exist. Creating...")
    # Get all distinct formation_name + slot_id to build mapping
    formation_starter_slots_df = (
        granular_player_slots_df
        .filter(col("start_minute") == 0)
        .dropDuplicates(["formation_name", "slot_id"])
    )

    print(formation_starter_slots_df.count())

    # Join the existing data to fct_player_match_participation table with registered positions
    mapping_position_df = (
        broadcast(formation_starter_slots_df)
        .join(
            fct_player_match_participation_df,
            ["match_id", "player_id", "team_id"],
        )
        .select("formation_name", "slot_id", "position")
    )

    # Store position_mapping table to json file
    rows = [row.asDict() for row in mapping_position_df.collect()]
    os.makedirs(os.path.dirname(mapping_file), exist_ok=True)
    with open(mapping_file, "w", encoding="utf-8") as f:
        json.dump(rows, f, indent=2)

    print(f"Successfully written mapping_position_df to file {mapping_file}")

else:
    print(f"Reading mapping_position_df from file {mapping_file}")
    with open(mapping_file, "r", encoding="utf-8") as f:
        rows = json.load(f)
    
    mapping_position_df = spark.createDataFrame([Row(**row) for row in rows])
    mapping_position_df.show()
# Out:
# Reading mapping_position_df from file mapping/formation_slot_mapping.json
# [Stage 656:>                                                        (0 + 1) / 1]
# +--------------+-------+--------+
# |formation_name|slot_id|position|
# +--------------+-------+--------+
# |          4231|      1|      GK|
# |          4231|      2|      DR|
# |          4231|      5|      DC|
# |          4231|      6|      DC|
# |          4231|      3|      DL|
# |          4231|      8|     DMC|
# |          4231|      4|     DMC|
# |          4231|      7|     AMR|
# |          4231|     10|     AMC|
# |          4231|     11|     AML|
# |          4231|      9|      FW|
# |           352|      1|      GK|
# |           352|      5|      DC|
# |           352|      6|      DC|
# |           352|      4|      DC|
# |           352|      2|     DMR|
# |           352|      3|     DML|
# |           352|     11|      MC|
# |           352|      7|      MC|
# |           352|      8|      MC|
# +--------------+-------+--------+
# only showing top 20 rows

# %%
# Take the first position of a player in a match as their played_position (appearance_rank = 1)
window_spec = Window.partitionBy("match_id", "player_id").orderBy(col("start_minute").asc())

player_primary_slot_df = (
    granular_player_slots_df
    .withColumn("appearance_rank", row_number().over(window_spec))
    .filter(col("appearance_rank") == 1)
    .select("match_id", "player_id", "team_id", "formation_name", "slot_id")
)

# join to get position data from mapping
player_final_position_df = player_primary_slot_df.join(
    broadcast(mapping_position_df),
    ["formation_name", "slot_id"],
    "left"
).select("match_id", "player_id", "team_id", "position")


# join back to final fct_player_match_participation table
enriched_fct_player_match_participation_df = (
    fct_player_match_participation_df
    .join(
        player_final_position_df,
        ["match_id", "player_id", "team_id"],
        "left"
    ).select(
        "match_id",
        "team_id",
        "player_id",
        "is_starting_eleven",
        "shirt_no",
        fct_player_match_participation_df.position
    )
)

# %%
enriched_fct_player_match_participation_df.printSchema()
enriched_fct_player_match_participation_df.show()
# Out:
# root
#  |-- match_id: integer (nullable = true)
#  |-- team_id: integer (nullable = true)
#  |-- player_id: integer (nullable = true)
#  |-- is_starting_eleven: boolean (nullable = false)
#  |-- shirt_no: integer (nullable = true)
#  |-- position: string (nullable = true)
# [Stage 275:>                                                      (0 + 16) / 16]
# +--------+-------+---------+------------------+--------+--------+
# |match_id|team_id|player_id|is_starting_eleven|shirt_no|position|
# +--------+-------+---------+------------------+--------+--------+
# |  566045|    338|     2987|             false|      23|     Sub|
# |  566045|    338|     4056|             false|       9|     Sub|
# |  566045|    338|     8040|              true|      10|     FWR|
# |  566045|    338|    14102|              true|      21|      FW|
# |  566050|    331|       88|              true|      10|      FW|
# |  566050|    338|     2302|              true|       8|      MC|
# |  566050|    338|     9484|             false|      12|     Sub|
# |  566050|    338|    13361|             false|      19|     Sub|
# |  566057|    462|     9674|              true|       9|      DR|
# |  789613|    409|     4871|             false|      14|     Sub|
# |  789613|    409|    17108|             false|      18|     Sub|
# |  789613|    409|    36399|              true|       8|     DMC|
# |  789613|    863|    66194|              true|       8|      MR|
# |  789613|    863|    91434|              true|      22|      DR|
# |  789657|    339|    10209|              true|       3|      DL|
# |  789657|    339|    19582|             false|      18|     Sub|
# |  789657|    326|    39013|             false|      10|     Sub|
# |  789657|    339|   124688|             false|      17|     Sub|
# |  843548|    336|     6292|             false|      17|     Sub|
# |  843548|    409|     6683|              true|      13|      DC|
# +--------+-------+---------+------------------+--------+--------+
# only showing top 20 rows

# %%
write_to_silver(
    df=enriched_fct_player_match_participation_df,
    table_name="fct_player_match_participation",
    primary_keys=["match_id", "team_id", "player_id"],
    partition_by=["load_date_hour"],
    load_date_hour=JOB_RUN_DATE
)
# Out:
# Table 'silver.fct_player_match_participation' does not exist. Creating new table...
# Table successfully created and registered.
# 25/09/05 12:13:16 WARN HiveExternalCatalog: Couldn't find corresponding Hive SerDe for data source provider delta. Persisting data source table `spark_catalog`.`silver`.`fct_player_match_participation` into Hive metastore in Spark SQL specific format, which is NOT compatible with Hive.

# %%
# # Assume 'new_granular_player_slots_df' contains ONLY today's new data from Auto Loader

# # --- Step 1: Read the pre-built, complete mapping table ---
# formation_map = spark.read.table("gold.dim_formation_slot_map").cache()

# # --- Step 2: Find the primary slot for players in the NEW matches ---
# window_spec = Window.partitionBy("match_id", "player_id").orderBy(col("start_minute").asc())
# new_player_primary_slots_df = (
#     new_granular_player_slots_df
#     .withColumn("appearance_rank", row_number().over(window_spec))
#     .filter(col("appearance_rank") == 1)
#     .select("match_id", "player_id", "team_id", "formation_name", "slot_id")
# )

# # --- Step 3: Join the NEW data with the COMPLETE map ---
# new_player_positions_df = new_player_primary_slots_df.join(
#     broadcast(formation_map),
#     ["formation_name", "slot_id"],
#     "left"
# ).select("match_id", "player_id", "team_id", "played_position")

# # --- Step 4: MERGE the new, enriched data into the final Gold table ---
# # Assume 'new_player_positions_df' is now joined with all other new participation facts
# new_enriched_participation_df.createOrReplaceTempView("daily_updates")

# spark.sql("""
#     MERGE INTO gold.fct_player_match_participation AS target
#     USING daily_updates AS source
#     ON target.match_id = source.match_id AND target.player_id = source.player_id
#     WHEN NOT MATCHED THEN INSERT *
# """)

# %%
from pyspark.sql.functions import countDistinct

# joined_formations.agg(countDistinct("formation.formationName")).show()

joined_formations.select(
    "formation.formationName"
).distinct().show(25)

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, FloatType, ArrayType, BooleanType
from pyspark.sql.functions import col, explode_outer, asc, desc, row_number, monotonically_increasing_id, explode, transform, filter, regexp_replace, lower, when
from pyspark.sql.window import Window

match_event_schema = StructType([
    StructField("matchCentreData", StructType([
        StructField("events", ArrayType(
            StructType([
                StructField("eventId", IntegerType(), False),
                StructField("minute", IntegerType(), False),
                StructField("second", IntegerType(), False),
                StructField("teamId", IntegerType(), False),
                StructField("playerId", IntegerType(), False),
                StructField("x", FloatType(), False),
                StructField("y", FloatType(), False),
                StructField("endX", FloatType(), True),
                StructField("endY", FloatType(), True),
                StructField("period", StructType([
                    StructField("value", IntegerType(), False),
                    StructField("displayName", StringType(), False),
                ])),
                StructField("type", StructType([
                    StructField("displayName", StringType(), False),
                ])),
                StructField("outcomeType", StructType([
                    StructField("value", IntegerType(), False),
                ])),
                StructField("qualifiers", ArrayType(
                    StructType([
                        StructField("type", StructType([
                            StructField("value", IntegerType(), False),
                            StructField("displayName", StringType(), False),
                        ])),
                        StructField("value", StringType(), True)
                    ])
                ), True),
                StructField("satisfiedEventsTypes", ArrayType(IntegerType()), True)
            ])
        ), False)
    ]))
])

fct_match_events_df = json_to_df(
    schema=match_event_schema,
    crawled_after=last_crawl_time,
    path=MATCH_PATH,
    glob_pattern="*match_data.json"
)

# exploding column "event"
fct_match_events_df = fct_match_events_df.withColumn("event", explode_outer(col("matchCentreData.events"))).drop("matchCentreData")

# Explode and filter qualifiers to get qualifiers mapping
# Example: "StandingSave" -> 178
qualifier_mapping_df = (
    fct_match_events_df
    .select("event.qualifiers")
    .filter(col("qualifiers").isNotNull())
    
    # Keep only qualifiers without values
    .select(explode("qualifiers").alias("q"))
    .filter(col("q.value").isNull())
    
    # remove dups
    .select(
        col("q.type.value").alias("qualifier_id"),
        col("q.type.displayName").alias("qualifier_name_raw")
    )
    .distinct()
    
    # to snake_case
    .withColumn(
        "qualifier_name",
        lower(regexp_replace(col("qualifier_name_raw"), r"([a-z])([A-Z])", r"$1_$2"))
    )
    .select("qualifier_name", "qualifier_id")
)


fct_match_events_df = fct_match_events_df.withColumn(
    "qualifiers_display_names",
    transform(
        # Filter the array to keep only flags
        filter(
            col("event.qualifiers"),
            lambda q: q.value.isNull()
        ),
        # Transform the filtered array to get the names
        lambda q: lower(
            regexp_replace(q.type.displayName, r"([a-z])([A-Z])", r"$1_$2")
        )
    )
).withColumn(
    "qualifiers_values",
    transform(
        filter(
            col("event.qualifiers"),
            lambda q: q.value.isNull()
        ),
        lambda q: (q.type.value)
    )
).withColumn(
    "event",
    col("event").dropFields("qualifiers")
)

# Since event_id is unique for each team per match
# We create an unique _event_id to preserve the original event order of every match
fct_match_events_df = fct_match_events_df.withColumn(
    "surrogate_event_id", monotonically_increasing_id()
)
w = Window.partitionBy("match_id").orderBy("surrogate_event_id")
fct_match_events_df = fct_match_events_df.withColumn("_event_id", row_number().over(w))

df_to_flatten = fct_match_events_df.select(
    col("surrogate_event_id"),
    col("match_id"),
    col("_event_id"),
    "event.*",
    col("qualifiers_display_names"),
    col("qualifiers_values"),
    col("league"),
    col("season"),
    col("stage_id")
)

# convert text to snake case
categorical_cols_to_clean = {
    "period_display_name",
    "type_display_name"
}

base_match_events_df = flatten_df(
    df_to_flatten, categorical_cols_to_clean
)

base_match_events_df = flatten_df(
    df_to_flatten, categorical_cols_to_clean
).withColumn(
    "is_successful", when(col("outcome_type_value") == 1, True).otherwise(False)
).drop(
    "outcome_type_value", "surrogate_event_id"
)


# exploded_match_events_df = base_match_events_df.select(
#     col("surrogate_event_id"),
#     explode(col("satisfied_events_types")).alias("event_type_id")
# )

# fct_match_events_df = fct_match_events_df.orderBy(
#     asc("match_id"),
#     asc("_event_id")
# )
# Out:
# 25/09/05 20:30:30 WARN SharedInMemoryCache: Evicting cached table partition metadata from memory due to size constraints (spark.sql.hive.filesourcePartitionFileCacheSize = 262144000 bytes). This may impact query planning performance.

# %%
write_to_silver(qualifier_mapping_df, "qualifier_mapping")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 write_to_silver(qualifier_mapping_df, "qualifier_mapping")
#
# TypeError: write_to_silver() missing 1 required positional argument: 'primary_keys'

# %%
import json
from pyspark.sql import Row

def get_event_type_mapping():
    event_type_mapping_file = "mapping/event_type_mapping.json"

    print(f"Reading mapping_event_type_df from file {event_type_mapping_file}")
    with open(event_type_mapping_file, "r", encoding="utf-8") as f:
        event_type_rows = json.load(f)
    
    # need the reversed
    mapping_event_type_df = spark.createDataFrame([Row(event_type_id=id, event_type=camel_to_snake(name)) for name, id in event_type_rows.items()])
    return mapping_event_type_df

mapping_event_type_df = get_event_type_mapping()
mapping_event_type_df.show(10)
# Out:
# Reading mapping_event_type_df from file mapping/event_type_mapping.json
# +-------------+------------------+
# |event_type_id|        event_type|
# +-------------+------------------+
# |            0| shot_six_yard_box|
# |            1| shot_penalty_area|
# |            2|   shot_obox_total|
# |            3|    shot_open_play|
# |            4|      shot_counter|
# |            5|    shot_set_piece|
# |            6|shot_direct_corner|
# |            7|   shot_off_target|
# |            8|      shot_on_post|
# |            9|    shot_on_target|
# +-------------+------------------+
# only showing top 10 rows

# %%
from pyspark.sql import Row
import pyspark.sql.functions as sf

str_to_num_mapping_rows = [Row(event_type_value=camel_to_snake(v), event_type_id=k) for k, v in global_mapping.items()]
num_to_str_mapping_rows = [Row(event_type_id=k, event_type=camel_to_snake(v)) for k, v in global_mapping.items()]

global_mapping_df = spark.createDataFrame(num_to_str_mapping_rows)
global_mapping_df.show(10)

# %%
from pyspark.sql.functions import col

# Count total rows
total_rows = base_match_events_df.count()
half_rows = total_rows // 2

df_first_half, df_second_half = base_match_events_df.randomSplit([0.5, 0.5], seed=42)

# %%
from pyspark.sql import functions as sf

# Lookup map for converting array of ids into value
lookup_map_df = mapping_event_type_df.groupBy().agg(
    sf.map_from_entries(
        sf.collect_list(sf.struct("event_type_id", "event_type"))
    ).alias("map")
)

fct_match_events_df = (
    base_match_events_df.crossJoin(lookup_map_df)
    .withColumn(
        "satisfied_events_types_names",
        sf.transform(
            "satisfied_events_types",
            lambda x: sf.element_at(sf.col("map"), x)
        )
    )
    .drop("map")
)

# %%
from helpers.expression_helpers import CONFIG, get_select_expressions

fct_me_select_expressions = get_select_expressions(layer="silver_layer", table_name="fct_match_events")
fct_match_events_df.select(*fct_me_select_expressions)
# Out:
# DataFrame[match_id: int, _event_id: int, event_id: int, team_id: int, player_id: int, minute: int, second: int, period_value: int, period_display_name: string, type_display_name: string, is_successful: boolean, x: float, y: float, end_x: float, end_y: float, qualifiers_display_names: array<string>, satisfied_events_types_names: array<string>, qualifiers_values: array<int>, satisfied_events_types: array<int>, league: string, season: string, stage_id: int]

# %%
fct_match_events_df.count()
# Out:
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/socket.py", line 718, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 fct_match_events_df.count()
#
# File ~/big_data/venv/lib/python3.11/site-packages/pyspark/sql/dataframe.py:1240, in DataFrame.count(self)
#    1217 def count(self) -> int:
#    1218     """Returns the number of rows in this :class:`DataFrame`.
#    1219
#    1220     .. versionadded:: 1.3.0
#    (...)   1238     3
#    1239     """
# -> 1240     return int(self._jdf.count())
#
# File ~/big_data/venv/lib/python3.11/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File ~/big_data/venv/lib/python3.11/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File ~/big_data/venv/lib/python3.11/site-packages/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File /usr/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# KeyboardInterrupt:
# [Stage 74:>                                                      (0 + 16) / 928]

# %%
fct_match_events_df.show(truncate=False)
# Out:
# 25/09/05 16:18:29 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Traceback (most recent call last):5:> (0 + 0) / 928][Stage 76:>  (0 + 0) / 16]
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/socket.py", line 718, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/dottier/big_data/venv/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 199, in manager
#     while sock.recv(1024):
#           ^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 fct_match_events_df.show(truncate=False)
#
# File ~/big_data/venv/lib/python3.11/site-packages/pyspark/sql/dataframe.py:947, in DataFrame.show(self, n, truncate, vertical)
#     887 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
#     888     """Prints the first ``n`` rows to the console.
#     889
#     890     .. versionadded:: 1.3.0
#    (...)    945     name | Bob
#     946     """
# --> 947     print(self._show_string(n, truncate, vertical))
#
# File ~/big_data/venv/lib/python3.11/site-packages/pyspark/sql/dataframe.py:978, in DataFrame._show_string(self, n, truncate, vertical)
#     969 except ValueError:
#     970     raise PySparkTypeError(
#     971         error_class="NOT_BOOL",
#     972         message_parameters={
#    (...)    975         },
#     976     )
# --> 978 return self._jdf.showString(n, int_truncate, vertical)
#
# File ~/big_data/venv/lib/python3.11/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File ~/big_data/venv/lib/python3.11/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File ~/big_data/venv/lib/python3.11/site-packages/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File /usr/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# KeyboardInterrupt:
# [Stage 74:(16 + 16) / 928][Stage 75:> (0 + 0) / 928][Stage 76:>  (0 + 0) / 16]
# [Stage 74:(64 + 16) / 928][Stage 75:> (0 + 0) / 928][Stage 76:>  (0 + 0) / 16]

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number, col

# Define a window over the DataFrame
w = Window.orderBy("match_id", "event_id")  # or surrogate_event_id if available

# Add row index
df_with_index = fct_match_events_df.withColumn("row_idx", row_number().over(w))

total_rows = df_with_index.count()
half_rows = total_rows // 2

df_first_half = df_with_index.filter(col("row_idx") <= half_rows).drop("row_idx")
df_second_half = df_with_index.filter(col("row_idx") > half_rows).drop("row_idx")

# %%
write_to_silver(
    df=df_first_half,
    table_name="fct_match_events",
    primary_keys=["match_id", "team_id", "event_id"],
    partition_by=["load_date_hour"],
    load_date_hour=JOB_RUN_DATE
)
# Out:
# Table 'silver.fct_match_events' does not exist. Creating new table...
# 25/09/05 20:41:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/09/05 20:41:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/09/05 20:41:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/09/05 20:41:33 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 25/09/05 20:43:57 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/09/05 20:43:57 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/09/05 20:43:57 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/09/05 20:43:57 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/09/05 20:43:57 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/09/05 20:43:57 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# [Stage 82:>                                                       (0 + 16) / 56]

# %%
write_to_silver(
    df=df_second_half,
    table_name="fct_match_events",
    primary_keys=["match_id", "team_id", "event_id"],
    partition_by=["load_date_hour"],
    load_date_hour=JOB_RUN_DATE
)

# %%
write_to_silver(
    df=fct_match_events_df,
    table_name="fct_match_events",
    primary_keys=["match_id", "team_id", "event_id"],
    partition_by=["load_date_hour"],
    load_date_hour=JOB_RUN_DATE
)
# Out:
# Table 'silver.fct_match_events' does not exist. Creating new table...
# 25/09/05 16:46:50 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 76:>                                                       (0 + 16) / 56]

# %%
from pyspark.sql.functions import max as spark_max, min as spark_min

fct_match_events_df.filter(
    col("match_id") == 1834247
).orderBy(
    col("_event_id").asc(),
).show(n=20)

# %% [markdown]
# Check if match event mapping matches global_mapping

# %%
# think this is not really needed but can't hurt to check just in case
from pyspark.sql.types import StructType, StructField, MapType, StringType, IntegerType, MapType
from pyspark.sql.functions import broadcast

mapping_path = "/home/dottier/big_data/bronze/match_data"

mapping_schema = StructType([
    StructField("matchCentreEventTypeJson", MapType(StringType(), IntegerType()), True)
])

mapping_df = spark.read \
    .schema(mapping_schema) \
    .option("multiLine", True) \
    .option("pathGlobFilter", "*match_data.json") \
    .json(mapping_path)


exploded_mapping_df = mapping_df.select(
    "match_id", "league", "season", "stage_id",
    explode("matchCentreEventTypeJson").alias("event_type", "event_type_id")
)
exploded_mapping_df.printSchema()

joined = exploded_mapping_df.join(
    broadcast(global_mapping_df),
    exploded_mapping_df["event_type"] == global_mapping_df["event_type"],
    how="left"
).select(
    exploded_mapping_df["*"],
    global_mapping_df["event_type_id"].alias("global_value")
)

mismatches = joined.filter(
    (col("event_type_id") != col("global_value")) | col("global_value").isNull()
)

if mismatches.limit(1).count() > 0:
    mismatches.show(truncate=False)
    raise ValueError("❌ Found mismatches in matchCentreEventTypeJson")
else:
    print("✅ All matchCentreEventTypeJson match the global mapping.")

# %%
from pyspark.sql import functions as sf

# make it a list of tuple
df = spark.createDataFrame([("4 : 1",), ("2 : 1",), ("5 : 0",)], ["score"])
df.show()

df.select(sf.regexp_extract(sf.split(sf.col("score"), ":").getItem(0))).show()

# %%
from pyspark.sql import functions as sf

# make it a list of tuple
df = spark.createDataFrame([(1, 2, 3, 4), (5, 6, 7, 8)], ["val1", "val2", "val3", "val4"])
df.show()


# flattened_df = df.select(sf.explode(sf.array("val1", "val2")).alias("value"), sf.col("val3"))
# flattened_df.show()

# %%
from pyspark.sql import functions as sf

# make it a list of tuple
df = spark.createDataFrame([([1, 2, 3],), ([4, 5, 6],)], ["val1"])
df.show()


# flattened_df = df.select(sf.explode(sf.array("val1", "val2")).alias("value"), sf.col("val3"))
# flattened_df.show()

# %%
map_df = spark.createDataFrame([(1, 'a'), (2, 'b'), (3, 'c'),
                                (4, 'd'), (5, 'e'), (6, 'f')], ["key", "val"])
map_df.show()

# %%
from pyspark.sql import functions as sf

# map_df: (key:int, val:string)
# df: val1: array<int>

# 1) Aggregate map_df into a single-row map column
lookup_map_df = map_df.groupBy().agg(
    sf.map_from_entries(sf.collect_list(sf.struct("key", "val"))).alias("m")
)

lookup_map_df.show()

# 2) Cross join once to make the map available, then transform the array
result_df = (
    df.crossJoin(sf.broadcast(lookup_map_df))
      .withColumn("val1", sf.transform("val1", lambda x: sf.element_at(sf.col("m"), x)))
      .select(df['*'])
)

result_df.show(truncate=False)

# %%
def mapping(key):
    return global_mapping.get(key, -1)

print(mapping(1))

# %%
from pyspark.sql.functions import transform, lit
df.select(transform("val1", lambda x: lit(global_mapping[x]))).show()

# %%
import json

base_path = "/home/dottier/big_data/bronze/season_data/league=germany_bundesliga/season=2023_2024/season_info.json"

with open(base_path, "r", encoding="utf-8") as f:
    json_object = json.load(f)
    print(json_object)

# %%
from pyspark.sql import functions as F

mapping = {0: "a", 1: "b", 2: "c"}

# Your DataFrame has a column "nums" like: [0, 1, 2]
df = spark.createDataFrame(
    [([0, 1, 2],), ([1, 0],)],
    ["nums"]
)

# Transform each element in the array
df = df.withColumn(
    "letters",
    F.expr(f"transform(nums, x -> '{mapping[0]}' if x = 0 else '{mapping[1]}' if x = 1 else '{mapping[2]}')")
)

df.show(truncate=False)

# %%
from pyspark.sql import Row
import pyspark.sql.functions as sf

mapping_rows = [Row(event_type_id=k, event_type=v) for k, v in global_mapping.items()]

global_mapping_df = spark.createDataFrame(mapping_rows)
global_mapping_df = global_mapping_df.groupBy().agg(
    sf.map_from_entries(sf.collect_list(sf.struct("event_type_id", "event_type"))).alias("map")
)

fct_match_events_df = (
    fct_match_events_df
    .crossJoin(sf.broadcast(global_mapping_df))
    .withColumn("satisfied_events_types", sf.transform("satisfied_events_types", lambda x: sf.element_at(sf.col("map"), x)))
    .drop("map")
)

# %%
fct_match_events = read_from_silver("fct_match_events")

# %%
events_for_join = fct_match_events_df.select(
    "match_id",
    "_event_id",
    "minute",
    "second",
    "type_display_name",
    "outcome_type_display_name",
    "player_id",
    "team_id",
    "qualifiers_list"
)

event1 = events_for_join.alias("event1")
event2 = events_for_join.alias("event2")

join_conditions = [
    col("event1.match_id") == col("event2.match_id"), # Must be in the same match
    col("event1.minute") == col("event2.minute"),
    col("event1.second") == col("event2.second"),
    col("event1.team_id") < col("event2.team_id"),
    col("event1._event_id") < col("event2._event_id")
]

event_pairs_df = event1.join(event2, on=join_conditions, how="inner")

print(event_pairs_df.count())
event_pairs_df.show()

# %%
from pyspark.sql.functions import lag, col
from pyspark.sql.window import Window

# Define a window that partitions by match and orders by our _event_id
# This puts the events in the sequence we want to test.
window_spec = Window.partitionBy("match_id").orderBy("_event_id")

# Create columns for the minute and second of the *previous* event
events_with_previous_time = fct_match_events.withColumn(
    "previous_minute", lag("minute").over(window_spec)
).withColumn(
    "previous_second", lag("second").over(window_spec)
).withColumn(
    "previous_period", lag("period_value").over(window_spec)
)

# Now, find the rows where the time goes "backwards".
# This is our alarm for incorrect ordering.
ordering_errors = events_with_previous_time.filter(
    (col("minute") < col("previous_minute")) | 
    ((col("minute") == col("previous_minute")) & (col("second") < col("previous_second")))
).filter(
    col("previous_period") == col("period_value")
)

# The assertion is a simple count.
error_count = ordering_errors.count()

if error_count > 0:
    print(f"DATA QUALITY FAILED: Found {error_count} events that are out of chronological order!")
    # Show the specific events that broke the rule
    ordering_errors.select(
        "match_id", "_event_id", "minute", "second", "previous_minute", "previous_second"
    ).show()
else:
    print("DATA QUALITY PASSED: Event order is chronologically correct.")

# %%
from pyspark.sql.functions import array_contains, col

fct_match_events.filter(
    col("match_id") == 959673
    # (col("_event_id") == 1) &
    # (col("type_display_name") != "Start") &
    # (col("second").isNotNull())
    # (array_contains(col("qualifiers_list"), "redCard"))
).orderBy(
    "_event_id"
).show(n=10000)
